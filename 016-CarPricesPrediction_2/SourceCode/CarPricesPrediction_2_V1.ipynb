# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import plotly.express as px
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD, Adam,  RMSprop, Nadam
from tensorflow.keras.layers import Dense, Flatten,  LSTM, GRU, LeakyReLU, Dropout, Bidirectional

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import  MinMaxScaler, PowerTransformer, RobustScaler

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import (
    AdaBoostRegressor,
    BaggingRegressor,
    ExtraTreesRegressor,
    GradientBoostingRegressor, 
    HistGradientBoostingRegressor,
    RandomForestRegressor,
    StackingRegressor,
)
from xgboost import XGBRegressor

from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

from pycaret.regression import RegressionExperiment

# %% [markdown]
# # 2. Load Data

# %%
data = pd.read_csv('../Dataset/cardata.csv').drop_duplicates()
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [299 rows x 9 columns]

# %% [markdown]
# # 3. Initial Analysis

# %% [markdown]
# ### 3.1. Metadata

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    int32
#  1   Year           299 non-null    int64
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Kms_Driven     299 non-null    int64
#  5   Fuel_Type      299 non-null    int32
#  6   Seller_Type    299 non-null    int32
#  7   Transmission   299 non-null    int32
#  8   Owner          299 non-null    int64
# dtypes: float64(2), int32(4), int64(3)
# memory usage: 18.7 KB

# %%
data.describe().transpose()
# Out:
#                count          mean           std      min       25%       50%  \
# Car_Name       299.0     62.464883     25.624966     0.00     46.50     69.00
# Year           299.0   2013.615385      2.896868  2003.00   2012.00   2014.00
# Selling_Price  299.0      4.589632      4.984240     0.10      0.85      3.51
# Present_Price  299.0      7.541037      8.567887     0.32      1.20      6.10
# Kms_Driven     299.0  36916.752508  39015.170352   500.00  15000.00  32000.00
# Fuel_Type      299.0      1.792642      0.422297     0.00      2.00      2.00
# Seller_Type    299.0      0.354515      0.479168     0.00      0.00      0.00
# Transmission   299.0      0.869565      0.337346     0.00      1.00      1.00
# Owner          299.0      0.043478      0.248720     0.00      0.00      0.00
#
#                     75%       max
# Car_Name          82.00      97.0
# Year            2016.00    2018.0
# Selling_Price      6.00      35.0
# Present_Price      9.84      92.6
# Kms_Driven     48883.50  500000.0
# Fuel_Type          2.00       2.0
# Seller_Type        1.00       1.0
# Transmission       1.00       1.0
# Owner              0.00       3.0

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
print(f'Number of duplicates data : {data.duplicated().sum()}')
# Out:
# Number of duplicates data : 2

# %% [markdown]
# ### 3.2. Columns Processing

# %%
data['Present_Price'].min()
# Out:
# 0.32

# %%
numerical_columns = [column_name for column_name in data.columns if data[column_name].dtype != 'object']
categorical_columns = [column_name for column_name in data.columns if data[column_name].dtype == 'object']
print(f'Numerical Columns   : {numerical_columns}')
print(f'Categorical Columns : {categorical_columns}')
# Out:
# Numerical Columns   : ['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']
# Categorical Columns : []

# %%
def change_columns_to_numerical(data):
    LE = LabelEncoder()

    for column in categorical_columns:
        data[column] = LE.fit_transform(data[column])
        data[column] = data[column].astype(int)
        # print(f'{column} : {LE.classes_}') 
    return data

data = change_columns_to_numerical(data)

# %% [markdown]
# ### 3.3. EDA

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 7))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data = data, x = column, ax=axes[row, col], bw_adjust=.1) \
        .set_title("Distribusi nilai kolom " + column)
    

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# num_cols = 3
# num_rows = math.ceil(len(numerical_columns) / num_cols)

# fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10))

# for i, column in enumerate(numerical_columns):
#     row = i // num_cols
#     col = i % num_cols
#     sns.kdeplot(data=data, x=column, hue="Owner", 
#                 fill=True, alpha=.2, palette="YlOrRd", 
#                 common_norm=False, ax=axes[row, col],
#                 warn_singular=False)\
#         .set_title(column)

# for i in range(len(numerical_columns), num_rows * num_cols):
#     row = i // num_cols
#     col = i % num_cols
#     axes[row, col].axis('off')

# plt.tight_layout()
# plt.show()

# %%
sns.pairplot(data)

# %%
plt.subplots(figsize = (20,4))
ax = sns.countplot(data = data, x = 'cut', palette='YlOrBr')
ax.bar_label(ax.containers[0])

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))
for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.boxplot(x=data[column], ax=axes[row, col], palette="Oranges").set_title(column)
    
for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# Q1 = data['text_len'].quantile(0.25)
# Q3 = data['text_len'].quantile(1.)

# print(Q1)
# print(Q3)

# data = data[(data['text_len'] > Q1) & (data['text_len'] < Q3)]

# fig, axes = plt.subplots(figsize=(25, 2))
# sns.boxplot(x = data['text_len'], palette="Oranges")

# sns.stripplot(x=data['text_len'], data=data,
#               size=4, color=".3", linewidth=0, palette="crest", hue=data['text_len'])

# %% [markdown]
# ### 3.4. Data Correlation

# %%
corr_data = data.corr().round(2)

mask = np.zeros_like(corr_data)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(25, 10))
# sns.heatmap(corr_data, annot=True, mask=mask, cmap='RdBu')
sns.heatmap(corr_data, annot=True, cmap='RdBu')
plt.title("Correlation Matrix", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ### 4.1. Features Selections

# %%
### Pearson Correlation
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    print(str(len(cor_feature)), 'selected features')
    print(cor_feature)
    return cor_feature

### Chi-Squared
def chi_squared_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_feats)
    chi_selector.fit(X_norm, Y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    print(str(len(chi_feature)), 'selected features')
    print(chi_feature)
    return chi_feature

### Recursive Feature Elimination
def recursive_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
    rfe_selector.fit(X_norm, Y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    print(str(len(rfe_feature)), 'selected features')
    print(rfe_feature)
    return rfe_feature

### Lasso: SelectFromModel
def lasso_elimination(X, Y, num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
    embeded_lr_selector.fit(X_norm, Y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    print(str(len(embeded_lr_feature)), 'selected features')
    print(embeded_lr_feature)
    return embeded_lr_feature

### LightGBM: SelectFromModel
def LGBMC_elimination(X, Y, num_feats):
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
                reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

    embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
    embeded_lgb_selector.fit(X, Y)
    embeded_lgb_support = embeded_lgb_selector.get_support()
    embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    print(str(len(embeded_lgb_feature)), 'selected features')
    print(embeded_lgb_feature)
    return embeded_lgb_feature

### Tree-based: SelectFromModel
def RFC_elimination (X, Y, num_feats):
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
    embeded_rf_selector.fit(X, Y)

    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    print(str(len(embeded_rf_feature)), 'selected features')
    print(embeded_rf_feature)
    return embeded_rf_feature

# %%
X = data.drop(columns=['Potability'])
Y = data['Potability']

num_feats = 10

selected_feature = cor_selector(X, Y,num_feats)
# selected_feature = chi_squared_elimination(X, Y,num_feats)
# selected_feature = recursive_elimination(X, Y,num_feats)
# selected_feature = lasso_elimination(X, Y, num_feats)
# selected_feature = LGBMC_elimination(X, Y, num_feats)
# selected_feature = RFC_elimination(X, Y, num_feats)

X = data[selected_feature]
Y = data['Credit_Score']


print(Counter(Y))
undersample = RandomUnderSampler()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = to_categorical(Y)

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# 10 selected features
# ['Monthly_Balance', 'Num_Bank_Accounts', 'Credit_History_Age', 'Num_Credit_Card', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Interest_Rate', 'Num_Credit_Inquiries', 'Credit_Mix']
# Counter({0: 53174, 2: 28998, 1: 17828})
# Counter({0: 17828, 1: 17828, 2: 17828})
# (37545, 10)
# (10590, 10)
# (5349, 10)

# %% [markdown]
# ### 4.2. Data Splitting

# %%
X = data.drop(columns=['Selling_Price'])
Y = data['Selling_Price']

# print(Counter(Y))
# undersample = RandomUnderSampler()
# X, Y = undersample.fit_resample(X, Y)
# print(Counter(Y))

# scaler = MinMaxScaler(feature_range=(0,1))
# scaler = RobustScaler()
# X_scaled = scaler.fit_transform(X)
# scaler = PowerTransformer(method='yeo-johnson', standardize=True)
# X = scaler.fit_transform(X_scaled)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (209, 8) (209,)
# (60, 8) (60,)
# (30, 8) (30,)

# %% [markdown]
# # 5. Neural Network Algoritms

# %%
def DNN_Model():
    model = Sequential()
    model.add(Dense(1024, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001), input_shape=(X_train.shape[1],)))
    # model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(Dropout(0.5))
    model.add(Dense(1))
    
    return model

def LSTM_Model():
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    # model.add(LSTM(64))
    model.add(Dense(32, activation='relu'))
    # model.add(Dropout(0.2))
    # model.add(Dropout(0.5))
    # model.add(Dense(16, activation='relu'))
    model.add(Dense(1))
    return model

def GRU_Model():
    model = Sequential()
    model.add((GRU(128, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True, input_shape = (X_train.shape[1],1))))
    # model.add(GRU(64, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True))
    model.add((GRU(128, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True)))
    # model.add(Dense(128, activation='relu'))
    # model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    return model

# model = DNN_Model()
# model = LSTM_Model()
model = GRU_Model()

model.summary()

# opt = SGD(learning_rate=0.01, momentum=0.9)
opt = Adam(learning_rate = 0.000_01)

model.compile(loss='mse', optimizer=opt, metrics=['mse'])
# model.compile(loss='mae', optimizer = opt, metrics=['mae'])
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_14 (GRU)                (None, 8, 128)            50304
#
#  gru_15 (GRU)                (None, 128)               99072
#
#  dense_26 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 149,505
# Trainable params: 149,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epoch = 2000
batch_size = 32

history = model.fit(X_train, y_train, verbose=2,
                    batch_size = batch_size, epochs = num_epoch, 
                    validation_data = (X_test, y_test))
# Out:
# Epoch 1/2000
# 7/7 - 0s - loss: 1.5800 - mse: 1.5800 - val_loss: 6.6866 - val_mse: 6.6866 - 232ms/epoch - 33ms/step
# Epoch 2/2000
# 7/7 - 0s - loss: 1.6387 - mse: 1.6387 - val_loss: 6.6000 - val_mse: 6.6000 - 63ms/epoch - 9ms/step
# Epoch 3/2000
# 7/7 - 0s - loss: 1.7435 - mse: 1.7435 - val_loss: 6.5994 - val_mse: 6.5994 - 58ms/epoch - 8ms/step
# Epoch 4/2000
# 7/7 - 0s - loss: 1.5902 - mse: 1.5902 - val_loss: 6.7431 - val_mse: 6.7431 - 60ms/epoch - 9ms/step
# Epoch 5/2000
# 7/7 - 0s - loss: 1.6037 - mse: 1.6037 - val_loss: 6.5933 - val_mse: 6.5933 - 55ms/epoch - 8ms/step
# Epoch 6/2000
# 7/7 - 0s - loss: 1.6103 - mse: 1.6103 - val_loss: 6.5902 - val_mse: 6.5902 - 62ms/epoch - 9ms/step
# Epoch 7/2000
# 7/7 - 0s - loss: 1.5967 - mse: 1.5967 - val_loss: 6.6000 - val_mse: 6.6000 - 56ms/epoch - 8ms/step
# Epoch 8/2000
# 7/7 - 0s - loss: 1.6007 - mse: 1.6007 - val_loss: 6.6364 - val_mse: 6.6364 - 59ms/epoch - 8ms/step
# Epoch 9/2000
# 7/7 - 0s - loss: 1.7139 - mse: 1.7139 - val_loss: 6.5958 - val_mse: 6.5958 - 61ms/epoch - 9ms/step
# Epoch 10/2000
# 7/7 - 0s - loss: 1.8079 - mse: 1.8079 - val_loss: 6.5792 - val_mse: 6.5792 - 58ms/epoch - 8ms/step
# Epoch 11/2000
# 7/7 - 0s - loss: 1.8833 - mse: 1.8833 - val_loss: 6.7948 - val_mse: 6.7948 - 56ms/epoch - 8ms/step
# Epoch 12/2000
# 7/7 - 0s - loss: 1.6960 - mse: 1.6960 - val_loss: 6.8977 - val_mse: 6.8977 - 61ms/epoch - 9ms/step
# Epoch 13/2000
# 7/7 - 0s - loss: 1.8197 - mse: 1.8197 - val_loss: 6.7202 - val_mse: 6.7202 - 57ms/epoch - 8ms/step
# Epoch 14/2000
# 7/7 - 0s - loss: 1.6870 - mse: 1.6870 - val_loss: 6.6988 - val_mse: 6.6988 - 57ms/epoch - 8ms/step
# Epoch 15/2000
# 7/7 - 0s - loss: 1.6176 - mse: 1.6176 - val_loss: 6.6204 - val_mse: 6.6204 - 58ms/epoch - 8ms/step
# Epoch 16/2000
# 7/7 - 0s - loss: 1.5601 - mse: 1.5601 - val_loss: 6.6247 - val_mse: 6.6247 - 93ms/epoch - 13ms/step
# Epoch 17/2000
# 7/7 - 0s - loss: 1.5989 - mse: 1.5989 - val_loss: 6.6145 - val_mse: 6.6145 - 60ms/epoch - 9ms/step
# Epoch 18/2000
# 7/7 - 0s - loss: 1.5590 - mse: 1.5590 - val_loss: 6.6080 - val_mse: 6.6080 - 58ms/epoch - 8ms/step
# Epoch 19/2000
# 7/7 - 0s - loss: 1.5660 - mse: 1.5660 - val_loss: 6.6239 - val_mse: 6.6239 - 56ms/epoch - 8ms/step
# Epoch 20/2000
# 7/7 - 0s - loss: 1.6555 - mse: 1.6555 - val_loss: 6.5844 - val_mse: 6.5844 - 56ms/epoch - 8ms/step
# Epoch 21/2000
# 7/7 - 0s - loss: 1.5810 - mse: 1.5810 - val_loss: 6.5975 - val_mse: 6.5975 - 62ms/epoch - 9ms/step
# Epoch 22/2000
# 7/7 - 0s - loss: 1.5496 - mse: 1.5496 - val_loss: 6.5757 - val_mse: 6.5757 - 70ms/epoch - 10ms/step
# Epoch 23/2000
# 7/7 - 0s - loss: 1.5579 - mse: 1.5579 - val_loss: 6.5595 - val_mse: 6.5595 - 54ms/epoch - 8ms/step
# Epoch 24/2000
# 7/7 - 0s - loss: 1.6126 - mse: 1.6126 - val_loss: 6.5492 - val_mse: 6.5492 - 58ms/epoch - 8ms/step
# Epoch 25/2000
# 7/7 - 0s - loss: 1.5830 - mse: 1.5830 - val_loss: 6.5911 - val_mse: 6.5911 - 54ms/epoch - 8ms/step
# Epoch 26/2000
# 7/7 - 0s - loss: 1.5633 - mse: 1.5633 - val_loss: 6.5490 - val_mse: 6.5490 - 56ms/epoch - 8ms/step
# Epoch 27/2000
# 7/7 - 0s - loss: 1.5554 - mse: 1.5554 - val_loss: 6.5224 - val_mse: 6.5224 - 56ms/epoch - 8ms/step
# Epoch 28/2000
# 7/7 - 0s - loss: 1.5800 - mse: 1.5800 - val_loss: 6.6418 - val_mse: 6.6418 - 56ms/epoch - 8ms/step
# Epoch 29/2000
# 7/7 - 0s - loss: 1.5829 - mse: 1.5829 - val_loss: 6.5085 - val_mse: 6.5085 - 54ms/epoch - 8ms/step
# Epoch 30/2000
# 7/7 - 0s - loss: 1.6016 - mse: 1.6016 - val_loss: 6.5030 - val_mse: 6.5030 - 56ms/epoch - 8ms/step
# Epoch 31/2000
# 7/7 - 0s - loss: 1.5742 - mse: 1.5742 - val_loss: 6.4894 - val_mse: 6.4894 - 60ms/epoch - 9ms/step
# Epoch 32/2000
# 7/7 - 0s - loss: 1.5560 - mse: 1.5560 - val_loss: 6.4996 - val_mse: 6.4996 - 61ms/epoch - 9ms/step
# Epoch 33/2000
# 7/7 - 0s - loss: 1.5412 - mse: 1.5412 - val_loss: 6.5807 - val_mse: 6.5807 - 61ms/epoch - 9ms/step
# Epoch 34/2000
# 7/7 - 0s - loss: 1.5670 - mse: 1.5670 - val_loss: 6.4780 - val_mse: 6.4780 - 64ms/epoch - 9ms/step
# Epoch 35/2000
# 7/7 - 0s - loss: 1.6074 - mse: 1.6074 - val_loss: 6.5016 - val_mse: 6.5016 - 61ms/epoch - 9ms/step
# Epoch 36/2000
# 7/7 - 0s - loss: 1.7394 - mse: 1.7394 - val_loss: 6.6076 - val_mse: 6.6076 - 60ms/epoch - 9ms/step
# Epoch 37/2000
# 7/7 - 0s - loss: 1.8074 - mse: 1.8074 - val_loss: 6.5763 - val_mse: 6.5763 - 62ms/epoch - 9ms/step
# Epoch 38/2000
# 7/7 - 0s - loss: 1.7194 - mse: 1.7194 - val_loss: 6.6289 - val_mse: 6.6289 - 59ms/epoch - 8ms/step
# Epoch 39/2000
# 7/7 - 0s - loss: 1.6086 - mse: 1.6086 - val_loss: 6.6788 - val_mse: 6.6788 - 60ms/epoch - 9ms/step
# Epoch 40/2000
# 7/7 - 0s - loss: 1.5907 - mse: 1.5907 - val_loss: 6.5408 - val_mse: 6.5408 - 59ms/epoch - 8ms/step
# Epoch 41/2000
# 7/7 - 0s - loss: 1.7569 - mse: 1.7569 - val_loss: 6.6961 - val_mse: 6.6961 - 55ms/epoch - 8ms/step
# Epoch 42/2000
# 7/7 - 0s - loss: 1.5298 - mse: 1.5298 - val_loss: 6.7908 - val_mse: 6.7908 - 73ms/epoch - 10ms/step
# Epoch 43/2000
# 7/7 - 0s - loss: 1.6620 - mse: 1.6620 - val_loss: 6.5260 - val_mse: 6.5260 - 59ms/epoch - 8ms/step
# Epoch 44/2000
# 7/7 - 0s - loss: 1.5556 - mse: 1.5556 - val_loss: 6.5053 - val_mse: 6.5053 - 57ms/epoch - 8ms/step
# Epoch 45/2000
# 7/7 - 0s - loss: 1.5407 - mse: 1.5407 - val_loss: 6.5365 - val_mse: 6.5365 - 60ms/epoch - 9ms/step
# Epoch 46/2000
# 7/7 - 0s - loss: 1.6637 - mse: 1.6637 - val_loss: 6.4966 - val_mse: 6.4966 - 67ms/epoch - 10ms/step
# Epoch 47/2000
# 7/7 - 0s - loss: 1.7906 - mse: 1.7906 - val_loss: 6.5617 - val_mse: 6.5617 - 67ms/epoch - 10ms/step
# Epoch 48/2000
# 7/7 - 0s - loss: 1.6261 - mse: 1.6261 - val_loss: 6.8204 - val_mse: 6.8204 - 63ms/epoch - 9ms/step
# Epoch 49/2000
# 7/7 - 0s - loss: 1.5978 - mse: 1.5978 - val_loss: 6.7328 - val_mse: 6.7328 - 56ms/epoch - 8ms/step
# Epoch 50/2000
# 7/7 - 0s - loss: 1.8720 - mse: 1.8720 - val_loss: 6.5670 - val_mse: 6.5670 - 55ms/epoch - 8ms/step
# Epoch 51/2000
# 7/7 - 0s - loss: 1.5257 - mse: 1.5257 - val_loss: 6.8736 - val_mse: 6.8736 - 56ms/epoch - 8ms/step
# Epoch 52/2000
# 7/7 - 0s - loss: 1.8005 - mse: 1.8005 - val_loss: 6.6171 - val_mse: 6.6171 - 58ms/epoch - 8ms/step
# Epoch 53/2000
# 7/7 - 0s - loss: 1.6473 - mse: 1.6473 - val_loss: 6.5721 - val_mse: 6.5721 - 60ms/epoch - 9ms/step
# Epoch 54/2000
# 7/7 - 0s - loss: 1.5383 - mse: 1.5383 - val_loss: 6.5162 - val_mse: 6.5162 - 102ms/epoch - 15ms/step
# Epoch 55/2000
# 7/7 - 0s - loss: 1.5615 - mse: 1.5615 - val_loss: 6.5045 - val_mse: 6.5045 - 65ms/epoch - 9ms/step
# Epoch 56/2000
# 7/7 - 0s - loss: 1.5707 - mse: 1.5707 - val_loss: 6.5132 - val_mse: 6.5132 - 60ms/epoch - 9ms/step
# Epoch 57/2000
# 7/7 - 0s - loss: 1.5623 - mse: 1.5623 - val_loss: 6.5241 - val_mse: 6.5241 - 64ms/epoch - 9ms/step
# Epoch 58/2000
# 7/7 - 0s - loss: 1.5035 - mse: 1.5035 - val_loss: 6.4976 - val_mse: 6.4976 - 62ms/epoch - 9ms/step
# Epoch 59/2000
# 7/7 - 0s - loss: 1.6005 - mse: 1.6005 - val_loss: 6.4979 - val_mse: 6.4979 - 54ms/epoch - 8ms/step
# Epoch 60/2000
# 7/7 - 0s - loss: 1.5602 - mse: 1.5602 - val_loss: 6.4553 - val_mse: 6.4553 - 55ms/epoch - 8ms/step
# Epoch 61/2000
# 7/7 - 0s - loss: 1.5628 - mse: 1.5628 - val_loss: 6.4340 - val_mse: 6.4340 - 55ms/epoch - 8ms/step
# Epoch 62/2000
# 7/7 - 0s - loss: 1.5668 - mse: 1.5668 - val_loss: 6.4319 - val_mse: 6.4319 - 56ms/epoch - 8ms/step
# Epoch 63/2000
# 7/7 - 0s - loss: 1.5905 - mse: 1.5905 - val_loss: 6.4429 - val_mse: 6.4429 - 54ms/epoch - 8ms/step
# Epoch 64/2000
# 7/7 - 0s - loss: 1.7373 - mse: 1.7373 - val_loss: 6.5201 - val_mse: 6.5201 - 54ms/epoch - 8ms/step
# Epoch 65/2000
# 7/7 - 0s - loss: 1.7513 - mse: 1.7513 - val_loss: 6.4791 - val_mse: 6.4791 - 57ms/epoch - 8ms/step
# Epoch 66/2000
# 7/7 - 0s - loss: 1.8964 - mse: 1.8964 - val_loss: 6.4913 - val_mse: 6.4913 - 54ms/epoch - 8ms/step
# Epoch 67/2000
# 7/7 - 0s - loss: 2.0015 - mse: 2.0015 - val_loss: 7.1515 - val_mse: 7.1515 - 56ms/epoch - 8ms/step
# Epoch 68/2000
# 7/7 - 0s - loss: 2.0569 - mse: 2.0569 - val_loss: 6.7223 - val_mse: 6.7223 - 52ms/epoch - 7ms/step
# Epoch 69/2000
# 7/7 - 0s - loss: 1.8538 - mse: 1.8538 - val_loss: 6.7542 - val_mse: 6.7542 - 60ms/epoch - 9ms/step
# Epoch 70/2000
# 7/7 - 0s - loss: 1.7611 - mse: 1.7611 - val_loss: 7.0558 - val_mse: 7.0558 - 64ms/epoch - 9ms/step
# Epoch 71/2000
# 7/7 - 0s - loss: 1.9024 - mse: 1.9024 - val_loss: 6.6827 - val_mse: 6.6827 - 59ms/epoch - 8ms/step
# Epoch 72/2000
# 7/7 - 0s - loss: 1.7349 - mse: 1.7349 - val_loss: 6.7324 - val_mse: 6.7324 - 56ms/epoch - 8ms/step
# Epoch 73/2000
# 7/7 - 0s - loss: 1.6145 - mse: 1.6145 - val_loss: 6.7594 - val_mse: 6.7594 - 57ms/epoch - 8ms/step
# Epoch 74/2000
# 7/7 - 0s - loss: 1.6023 - mse: 1.6023 - val_loss: 6.6589 - val_mse: 6.6589 - 55ms/epoch - 8ms/step
# Epoch 75/2000
# 7/7 - 0s - loss: 1.7803 - mse: 1.7803 - val_loss: 6.6465 - val_mse: 6.6465 - 60ms/epoch - 9ms/step
# Epoch 76/2000
# 7/7 - 0s - loss: 2.0090 - mse: 2.0090 - val_loss: 6.8890 - val_mse: 6.8890 - 57ms/epoch - 8ms/step
# Epoch 77/2000
# 7/7 - 0s - loss: 1.7989 - mse: 1.7989 - val_loss: 6.7814 - val_mse: 6.7814 - 58ms/epoch - 8ms/step
# Epoch 78/2000
# 7/7 - 0s - loss: 1.6313 - mse: 1.6313 - val_loss: 6.6804 - val_mse: 6.6804 - 55ms/epoch - 8ms/step
# Epoch 79/2000
# 7/7 - 0s - loss: 1.5842 - mse: 1.5842 - val_loss: 6.6337 - val_mse: 6.6337 - 62ms/epoch - 9ms/step
# Epoch 80/2000
# 7/7 - 0s - loss: 1.5547 - mse: 1.5547 - val_loss: 6.6150 - val_mse: 6.6150 - 66ms/epoch - 9ms/step
# Epoch 81/2000
# 7/7 - 0s - loss: 1.5513 - mse: 1.5513 - val_loss: 6.6144 - val_mse: 6.6144 - 60ms/epoch - 9ms/step
# Epoch 82/2000
# 7/7 - 0s - loss: 1.6289 - mse: 1.6289 - val_loss: 6.5238 - val_mse: 6.5238 - 65ms/epoch - 9ms/step
# Epoch 83/2000
# 7/7 - 0s - loss: 1.5578 - mse: 1.5578 - val_loss: 6.5397 - val_mse: 6.5397 - 63ms/epoch - 9ms/step
# Epoch 84/2000
# 7/7 - 0s - loss: 1.5714 - mse: 1.5714 - val_loss: 6.4631 - val_mse: 6.4631 - 65ms/epoch - 9ms/step
# Epoch 85/2000
# 7/7 - 0s - loss: 1.5703 - mse: 1.5703 - val_loss: 6.4613 - val_mse: 6.4613 - 65ms/epoch - 9ms/step
# Epoch 86/2000
# 7/7 - 0s - loss: 1.6071 - mse: 1.6071 - val_loss: 6.4532 - val_mse: 6.4532 - 61ms/epoch - 9ms/step
# Epoch 87/2000
# 7/7 - 0s - loss: 1.5813 - mse: 1.5813 - val_loss: 6.5373 - val_mse: 6.5373 - 62ms/epoch - 9ms/step
# Epoch 88/2000
# 7/7 - 0s - loss: 1.5778 - mse: 1.5778 - val_loss: 6.4465 - val_mse: 6.4465 - 64ms/epoch - 9ms/step
# Epoch 89/2000
# 7/7 - 0s - loss: 1.4772 - mse: 1.4772 - val_loss: 6.7451 - val_mse: 6.7451 - 63ms/epoch - 9ms/step
# Epoch 90/2000
# 7/7 - 0s - loss: 1.6481 - mse: 1.6481 - val_loss: 6.5266 - val_mse: 6.5266 - 60ms/epoch - 9ms/step
# Epoch 91/2000
# 7/7 - 0s - loss: 1.8186 - mse: 1.8186 - val_loss: 6.5936 - val_mse: 6.5936 - 63ms/epoch - 9ms/step
# Epoch 92/2000
# 7/7 - 0s - loss: 1.6596 - mse: 1.6596 - val_loss: 6.6528 - val_mse: 6.6528 - 67ms/epoch - 10ms/step
# Epoch 93/2000
# 7/7 - 0s - loss: 1.5649 - mse: 1.5649 - val_loss: 6.5130 - val_mse: 6.5130 - 63ms/epoch - 9ms/step
# Epoch 94/2000
# 7/7 - 0s - loss: 1.5842 - mse: 1.5842 - val_loss: 6.5028 - val_mse: 6.5028 - 62ms/epoch - 9ms/step
# Epoch 95/2000
# 7/7 - 0s - loss: 1.5453 - mse: 1.5453 - val_loss: 6.4715 - val_mse: 6.4715 - 64ms/epoch - 9ms/step
# Epoch 96/2000
# 7/7 - 0s - loss: 1.6237 - mse: 1.6237 - val_loss: 6.4417 - val_mse: 6.4417 - 95ms/epoch - 14ms/step
# Epoch 97/2000
# 7/7 - 0s - loss: 1.5255 - mse: 1.5255 - val_loss: 6.4370 - val_mse: 6.4370 - 61ms/epoch - 9ms/step
# Epoch 98/2000
# 7/7 - 0s - loss: 1.5300 - mse: 1.5300 - val_loss: 6.4447 - val_mse: 6.4447 - 66ms/epoch - 9ms/step
# Epoch 99/2000
# 7/7 - 0s - loss: 1.5447 - mse: 1.5447 - val_loss: 6.3998 - val_mse: 6.3998 - 63ms/epoch - 9ms/step
# Epoch 100/2000
# 7/7 - 0s - loss: 1.5074 - mse: 1.5074 - val_loss: 6.4303 - val_mse: 6.4303 - 57ms/epoch - 8ms/step
# Epoch 101/2000
# 7/7 - 0s - loss: 1.5367 - mse: 1.5367 - val_loss: 6.3738 - val_mse: 6.3738 - 55ms/epoch - 8ms/step
# Epoch 102/2000
# 7/7 - 0s - loss: 1.5372 - mse: 1.5372 - val_loss: 6.3930 - val_mse: 6.3930 - 56ms/epoch - 8ms/step
# Epoch 103/2000
# 7/7 - 0s - loss: 1.5172 - mse: 1.5172 - val_loss: 6.3876 - val_mse: 6.3876 - 57ms/epoch - 8ms/step
# Epoch 104/2000
# 7/7 - 0s - loss: 1.5272 - mse: 1.5272 - val_loss: 6.3565 - val_mse: 6.3565 - 59ms/epoch - 8ms/step
# Epoch 105/2000
# 7/7 - 0s - loss: 1.5381 - mse: 1.5381 - val_loss: 6.4040 - val_mse: 6.4040 - 57ms/epoch - 8ms/step
# Epoch 106/2000
# 7/7 - 0s - loss: 1.5104 - mse: 1.5104 - val_loss: 6.3586 - val_mse: 6.3586 - 52ms/epoch - 7ms/step
# Epoch 107/2000
# 7/7 - 0s - loss: 1.6037 - mse: 1.6037 - val_loss: 6.3482 - val_mse: 6.3482 - 57ms/epoch - 8ms/step
# Epoch 108/2000
# 7/7 - 0s - loss: 1.5422 - mse: 1.5422 - val_loss: 6.3692 - val_mse: 6.3692 - 54ms/epoch - 8ms/step
# Epoch 109/2000
# 7/7 - 0s - loss: 1.4947 - mse: 1.4947 - val_loss: 6.3863 - val_mse: 6.3863 - 55ms/epoch - 8ms/step
# Epoch 110/2000
# 7/7 - 0s - loss: 1.5613 - mse: 1.5613 - val_loss: 6.3351 - val_mse: 6.3351 - 60ms/epoch - 9ms/step
# Epoch 111/2000
# 7/7 - 0s - loss: 1.5085 - mse: 1.5085 - val_loss: 6.3589 - val_mse: 6.3589 - 57ms/epoch - 8ms/step
# Epoch 112/2000
# 7/7 - 0s - loss: 1.5411 - mse: 1.5411 - val_loss: 6.3372 - val_mse: 6.3372 - 59ms/epoch - 8ms/step
# Epoch 113/2000
# 7/7 - 0s - loss: 1.4980 - mse: 1.4980 - val_loss: 6.3219 - val_mse: 6.3219 - 56ms/epoch - 8ms/step
# Epoch 114/2000
# 7/7 - 0s - loss: 1.4751 - mse: 1.4751 - val_loss: 6.4969 - val_mse: 6.4969 - 56ms/epoch - 8ms/step
# Epoch 115/2000
# 7/7 - 0s - loss: 1.5785 - mse: 1.5785 - val_loss: 6.3098 - val_mse: 6.3098 - 53ms/epoch - 8ms/step
# Epoch 116/2000
# 7/7 - 0s - loss: 1.5550 - mse: 1.5550 - val_loss: 6.3299 - val_mse: 6.3299 - 57ms/epoch - 8ms/step
# Epoch 117/2000
# 7/7 - 0s - loss: 1.6617 - mse: 1.6617 - val_loss: 6.4885 - val_mse: 6.4885 - 56ms/epoch - 8ms/step
# Epoch 118/2000
# 7/7 - 0s - loss: 1.5343 - mse: 1.5343 - val_loss: 6.6066 - val_mse: 6.6066 - 58ms/epoch - 8ms/step
# Epoch 119/2000
# 7/7 - 0s - loss: 1.6229 - mse: 1.6229 - val_loss: 6.3554 - val_mse: 6.3554 - 59ms/epoch - 8ms/step
# Epoch 120/2000
# 7/7 - 0s - loss: 1.5965 - mse: 1.5965 - val_loss: 6.3646 - val_mse: 6.3646 - 59ms/epoch - 8ms/step
# Epoch 121/2000
# 7/7 - 0s - loss: 1.5270 - mse: 1.5270 - val_loss: 6.3980 - val_mse: 6.3980 - 55ms/epoch - 8ms/step
# Epoch 122/2000
# 7/7 - 0s - loss: 1.5074 - mse: 1.5074 - val_loss: 6.4019 - val_mse: 6.4019 - 56ms/epoch - 8ms/step
# Epoch 123/2000
# 7/7 - 0s - loss: 1.5706 - mse: 1.5706 - val_loss: 6.3228 - val_mse: 6.3228 - 57ms/epoch - 8ms/step
# Epoch 124/2000
# 7/7 - 0s - loss: 1.4809 - mse: 1.4809 - val_loss: 6.4474 - val_mse: 6.4474 - 54ms/epoch - 8ms/step
# Epoch 125/2000
# 7/7 - 0s - loss: 1.5594 - mse: 1.5594 - val_loss: 6.3315 - val_mse: 6.3315 - 55ms/epoch - 8ms/step
# Epoch 126/2000
# 7/7 - 0s - loss: 1.6776 - mse: 1.6776 - val_loss: 6.3149 - val_mse: 6.3149 - 54ms/epoch - 8ms/step
# Epoch 127/2000
# 7/7 - 0s - loss: 1.4724 - mse: 1.4724 - val_loss: 6.5100 - val_mse: 6.5100 - 62ms/epoch - 9ms/step
# Epoch 128/2000
# 7/7 - 0s - loss: 1.5766 - mse: 1.5766 - val_loss: 6.3214 - val_mse: 6.3214 - 62ms/epoch - 9ms/step
# Epoch 129/2000
# 7/7 - 0s - loss: 1.5694 - mse: 1.5694 - val_loss: 6.3116 - val_mse: 6.3116 - 55ms/epoch - 8ms/step
# Epoch 130/2000
# 7/7 - 0s - loss: 1.5505 - mse: 1.5505 - val_loss: 6.3275 - val_mse: 6.3275 - 56ms/epoch - 8ms/step
# Epoch 131/2000
# 7/7 - 0s - loss: 1.5357 - mse: 1.5357 - val_loss: 6.4535 - val_mse: 6.4535 - 57ms/epoch - 8ms/step
# Epoch 132/2000
# 7/7 - 0s - loss: 1.6136 - mse: 1.6136 - val_loss: 6.3041 - val_mse: 6.3041 - 61ms/epoch - 9ms/step
# Epoch 133/2000
# 7/7 - 0s - loss: 1.5145 - mse: 1.5145 - val_loss: 6.5068 - val_mse: 6.5068 - 63ms/epoch - 9ms/step
# Epoch 134/2000
# 7/7 - 0s - loss: 1.5486 - mse: 1.5486 - val_loss: 6.3023 - val_mse: 6.3023 - 95ms/epoch - 14ms/step
# Epoch 135/2000
# 7/7 - 0s - loss: 1.4935 - mse: 1.4935 - val_loss: 6.3095 - val_mse: 6.3095 - 62ms/epoch - 9ms/step
# Epoch 136/2000
# 7/7 - 0s - loss: 1.5341 - mse: 1.5341 - val_loss: 6.2705 - val_mse: 6.2705 - 63ms/epoch - 9ms/step
# Epoch 137/2000
# 7/7 - 0s - loss: 1.5219 - mse: 1.5219 - val_loss: 6.3394 - val_mse: 6.3394 - 61ms/epoch - 9ms/step
# Epoch 138/2000
# 7/7 - 0s - loss: 1.4701 - mse: 1.4701 - val_loss: 6.2608 - val_mse: 6.2608 - 61ms/epoch - 9ms/step
# Epoch 139/2000
# 7/7 - 0s - loss: 1.5024 - mse: 1.5024 - val_loss: 6.2740 - val_mse: 6.2740 - 62ms/epoch - 9ms/step
# Epoch 140/2000
# 7/7 - 0s - loss: 1.6557 - mse: 1.6557 - val_loss: 6.3154 - val_mse: 6.3154 - 62ms/epoch - 9ms/step
# Epoch 141/2000
# 7/7 - 0s - loss: 1.8044 - mse: 1.8044 - val_loss: 6.3860 - val_mse: 6.3860 - 63ms/epoch - 9ms/step
# Epoch 142/2000
# 7/7 - 0s - loss: 1.6285 - mse: 1.6285 - val_loss: 6.4641 - val_mse: 6.4641 - 61ms/epoch - 9ms/step
# Epoch 143/2000
# 7/7 - 0s - loss: 1.5090 - mse: 1.5090 - val_loss: 6.2783 - val_mse: 6.2783 - 61ms/epoch - 9ms/step
# Epoch 144/2000
# 7/7 - 0s - loss: 1.5954 - mse: 1.5954 - val_loss: 6.2776 - val_mse: 6.2776 - 60ms/epoch - 9ms/step
# Epoch 145/2000
# 7/7 - 0s - loss: 1.4630 - mse: 1.4630 - val_loss: 6.2775 - val_mse: 6.2775 - 61ms/epoch - 9ms/step
# Epoch 146/2000
# 7/7 - 0s - loss: 1.5521 - mse: 1.5521 - val_loss: 6.2655 - val_mse: 6.2655 - 61ms/epoch - 9ms/step
# Epoch 147/2000
# 7/7 - 0s - loss: 1.4913 - mse: 1.4913 - val_loss: 6.3110 - val_mse: 6.3110 - 57ms/epoch - 8ms/step
# Epoch 148/2000
# 7/7 - 0s - loss: 1.5889 - mse: 1.5889 - val_loss: 6.2372 - val_mse: 6.2372 - 61ms/epoch - 9ms/step
# Epoch 149/2000
# 7/7 - 0s - loss: 1.5000 - mse: 1.5000 - val_loss: 6.3722 - val_mse: 6.3722 - 59ms/epoch - 8ms/step
# Epoch 150/2000
# 7/7 - 0s - loss: 1.5348 - mse: 1.5348 - val_loss: 6.2501 - val_mse: 6.2501 - 64ms/epoch - 9ms/step
# Epoch 151/2000
# 7/7 - 0s - loss: 1.5226 - mse: 1.5226 - val_loss: 6.2613 - val_mse: 6.2613 - 61ms/epoch - 9ms/step
# Epoch 152/2000
# 7/7 - 0s - loss: 1.5686 - mse: 1.5686 - val_loss: 6.2534 - val_mse: 6.2534 - 62ms/epoch - 9ms/step
# Epoch 153/2000
# 7/7 - 0s - loss: 1.6079 - mse: 1.6079 - val_loss: 6.2378 - val_mse: 6.2378 - 59ms/epoch - 8ms/step
# Epoch 154/2000
# 7/7 - 0s - loss: 1.5424 - mse: 1.5424 - val_loss: 6.3313 - val_mse: 6.3313 - 57ms/epoch - 8ms/step
# Epoch 155/2000
# 7/7 - 0s - loss: 1.5317 - mse: 1.5317 - val_loss: 6.2482 - val_mse: 6.2482 - 61ms/epoch - 9ms/step
# Epoch 156/2000
# 7/7 - 0s - loss: 1.6506 - mse: 1.6506 - val_loss: 6.4539 - val_mse: 6.4539 - 59ms/epoch - 8ms/step
# Epoch 157/2000
# 7/7 - 0s - loss: 1.5890 - mse: 1.5890 - val_loss: 6.6577 - val_mse: 6.6577 - 60ms/epoch - 9ms/step
# Epoch 158/2000
# 7/7 - 0s - loss: 1.5698 - mse: 1.5698 - val_loss: 6.3559 - val_mse: 6.3559 - 63ms/epoch - 9ms/step
# Epoch 159/2000
# 7/7 - 0s - loss: 1.7672 - mse: 1.7672 - val_loss: 6.2519 - val_mse: 6.2519 - 60ms/epoch - 9ms/step
# Epoch 160/2000
# 7/7 - 0s - loss: 1.4891 - mse: 1.4891 - val_loss: 6.3791 - val_mse: 6.3791 - 59ms/epoch - 8ms/step
# Epoch 161/2000
# 7/7 - 0s - loss: 1.4752 - mse: 1.4752 - val_loss: 6.2342 - val_mse: 6.2342 - 58ms/epoch - 8ms/step
# Epoch 162/2000
# 7/7 - 0s - loss: 1.5008 - mse: 1.5008 - val_loss: 6.2394 - val_mse: 6.2394 - 58ms/epoch - 8ms/step
# Epoch 163/2000
# 7/7 - 0s - loss: 1.5151 - mse: 1.5151 - val_loss: 6.2289 - val_mse: 6.2289 - 59ms/epoch - 8ms/step
# Epoch 164/2000
# 7/7 - 0s - loss: 1.4746 - mse: 1.4746 - val_loss: 6.3209 - val_mse: 6.3209 - 59ms/epoch - 8ms/step
# Epoch 165/2000
# 7/7 - 0s - loss: 1.4745 - mse: 1.4745 - val_loss: 6.2298 - val_mse: 6.2298 - 65ms/epoch - 9ms/step
# Epoch 166/2000
# 7/7 - 0s - loss: 1.7181 - mse: 1.7181 - val_loss: 6.1896 - val_mse: 6.1896 - 65ms/epoch - 9ms/step
# Epoch 167/2000
# 7/7 - 0s - loss: 1.7374 - mse: 1.7374 - val_loss: 6.2065 - val_mse: 6.2065 - 58ms/epoch - 8ms/step
# Epoch 168/2000
# 7/7 - 0s - loss: 2.0965 - mse: 2.0965 - val_loss: 6.8022 - val_mse: 6.8022 - 58ms/epoch - 8ms/step
# Epoch 169/2000
# 7/7 - 0s - loss: 1.8469 - mse: 1.8469 - val_loss: 6.7283 - val_mse: 6.7283 - 56ms/epoch - 8ms/step
# Epoch 170/2000
# 7/7 - 0s - loss: 1.6745 - mse: 1.6745 - val_loss: 6.3293 - val_mse: 6.3293 - 86ms/epoch - 12ms/step
# Epoch 171/2000
# 7/7 - 0s - loss: 1.5079 - mse: 1.5079 - val_loss: 6.2976 - val_mse: 6.2976 - 57ms/epoch - 8ms/step
# Epoch 172/2000
# 7/7 - 0s - loss: 1.5728 - mse: 1.5728 - val_loss: 6.3051 - val_mse: 6.3051 - 59ms/epoch - 8ms/step
# Epoch 173/2000
# 7/7 - 0s - loss: 1.4767 - mse: 1.4767 - val_loss: 6.2828 - val_mse: 6.2828 - 57ms/epoch - 8ms/step
# Epoch 174/2000
# 7/7 - 0s - loss: 1.5223 - mse: 1.5223 - val_loss: 6.2488 - val_mse: 6.2488 - 63ms/epoch - 9ms/step
# Epoch 175/2000
# 7/7 - 0s - loss: 1.4805 - mse: 1.4805 - val_loss: 6.2922 - val_mse: 6.2922 - 56ms/epoch - 8ms/step
# Epoch 176/2000
# 7/7 - 0s - loss: 1.4865 - mse: 1.4865 - val_loss: 6.2145 - val_mse: 6.2145 - 60ms/epoch - 9ms/step
# Epoch 177/2000
# 7/7 - 0s - loss: 1.5155 - mse: 1.5155 - val_loss: 6.2161 - val_mse: 6.2161 - 60ms/epoch - 9ms/step
# Epoch 178/2000
# 7/7 - 0s - loss: 1.5128 - mse: 1.5128 - val_loss: 6.2164 - val_mse: 6.2164 - 57ms/epoch - 8ms/step
# Epoch 179/2000
# 7/7 - 0s - loss: 1.4616 - mse: 1.4616 - val_loss: 6.2629 - val_mse: 6.2629 - 58ms/epoch - 8ms/step
# Epoch 180/2000
# 7/7 - 0s - loss: 1.4919 - mse: 1.4919 - val_loss: 6.2277 - val_mse: 6.2277 - 56ms/epoch - 8ms/step
# Epoch 181/2000
# 7/7 - 0s - loss: 1.4466 - mse: 1.4466 - val_loss: 6.1871 - val_mse: 6.1871 - 58ms/epoch - 8ms/step
# Epoch 182/2000
# 7/7 - 0s - loss: 1.4599 - mse: 1.4599 - val_loss: 6.1872 - val_mse: 6.1872 - 61ms/epoch - 9ms/step
# Epoch 183/2000
# 7/7 - 0s - loss: 1.4479 - mse: 1.4479 - val_loss: 6.2077 - val_mse: 6.2077 - 56ms/epoch - 8ms/step
# Epoch 184/2000
# 7/7 - 0s - loss: 1.4724 - mse: 1.4724 - val_loss: 6.2009 - val_mse: 6.2009 - 55ms/epoch - 8ms/step
# Epoch 185/2000
# 7/7 - 0s - loss: 1.4424 - mse: 1.4424 - val_loss: 6.1656 - val_mse: 6.1656 - 58ms/epoch - 8ms/step
# Epoch 186/2000
# 7/7 - 0s - loss: 1.4784 - mse: 1.4784 - val_loss: 6.2153 - val_mse: 6.2153 - 57ms/epoch - 8ms/step
# Epoch 187/2000
# 7/7 - 0s - loss: 1.4694 - mse: 1.4694 - val_loss: 6.1585 - val_mse: 6.1585 - 57ms/epoch - 8ms/step
# Epoch 188/2000
# 7/7 - 0s - loss: 1.5185 - mse: 1.5185 - val_loss: 6.2569 - val_mse: 6.2569 - 61ms/epoch - 9ms/step
# Epoch 189/2000
# 7/7 - 0s - loss: 1.5092 - mse: 1.5092 - val_loss: 6.1584 - val_mse: 6.1584 - 64ms/epoch - 9ms/step
# Epoch 190/2000
# 7/7 - 0s - loss: 1.5450 - mse: 1.5450 - val_loss: 6.2231 - val_mse: 6.2231 - 65ms/epoch - 9ms/step
# Epoch 191/2000
# 7/7 - 0s - loss: 1.4584 - mse: 1.4584 - val_loss: 6.1829 - val_mse: 6.1829 - 64ms/epoch - 9ms/step
# Epoch 192/2000
# 7/7 - 0s - loss: 1.4955 - mse: 1.4955 - val_loss: 6.2226 - val_mse: 6.2226 - 61ms/epoch - 9ms/step
# Epoch 193/2000
# 7/7 - 0s - loss: 1.5175 - mse: 1.5175 - val_loss: 6.1891 - val_mse: 6.1891 - 65ms/epoch - 9ms/step
# Epoch 194/2000
# 7/7 - 0s - loss: 1.6046 - mse: 1.6046 - val_loss: 6.1553 - val_mse: 6.1553 - 59ms/epoch - 8ms/step
# Epoch 195/2000
# 7/7 - 0s - loss: 1.6444 - mse: 1.6444 - val_loss: 6.2610 - val_mse: 6.2610 - 65ms/epoch - 9ms/step
# Epoch 196/2000
# 7/7 - 0s - loss: 1.6679 - mse: 1.6679 - val_loss: 6.2840 - val_mse: 6.2840 - 67ms/epoch - 10ms/step
# Epoch 197/2000
# 7/7 - 0s - loss: 1.7464 - mse: 1.7464 - val_loss: 6.5321 - val_mse: 6.5321 - 60ms/epoch - 9ms/step
# Epoch 198/2000
# 7/7 - 0s - loss: 1.6817 - mse: 1.6817 - val_loss: 6.3552 - val_mse: 6.3552 - 64ms/epoch - 9ms/step
# Epoch 199/2000
# 7/7 - 0s - loss: 1.8200 - mse: 1.8200 - val_loss: 6.2400 - val_mse: 6.2400 - 60ms/epoch - 9ms/step
# Epoch 200/2000
# 7/7 - 0s - loss: 1.7934 - mse: 1.7934 - val_loss: 6.5260 - val_mse: 6.5260 - 59ms/epoch - 8ms/step
# Epoch 201/2000
# 7/7 - 0s - loss: 1.6604 - mse: 1.6604 - val_loss: 6.4769 - val_mse: 6.4769 - 60ms/epoch - 9ms/step
# Epoch 202/2000
# 7/7 - 0s - loss: 1.5842 - mse: 1.5842 - val_loss: 6.2496 - val_mse: 6.2496 - 59ms/epoch - 8ms/step
# Epoch 203/2000
# 7/7 - 0s - loss: 1.6626 - mse: 1.6626 - val_loss: 6.2348 - val_mse: 6.2348 - 59ms/epoch - 8ms/step
# Epoch 204/2000
# 7/7 - 0s - loss: 1.4868 - mse: 1.4868 - val_loss: 6.5251 - val_mse: 6.5251 - 60ms/epoch - 9ms/step
# Epoch 205/2000
# 7/7 - 0s - loss: 1.5014 - mse: 1.5014 - val_loss: 6.2172 - val_mse: 6.2172 - 59ms/epoch - 8ms/step
# Epoch 206/2000
# 7/7 - 0s - loss: 1.5152 - mse: 1.5152 - val_loss: 6.2708 - val_mse: 6.2708 - 64ms/epoch - 9ms/step
# Epoch 207/2000
# 7/7 - 0s - loss: 1.4399 - mse: 1.4399 - val_loss: 6.1668 - val_mse: 6.1668 - 94ms/epoch - 13ms/step
# Epoch 208/2000
# 7/7 - 0s - loss: 1.5053 - mse: 1.5053 - val_loss: 6.2198 - val_mse: 6.2198 - 60ms/epoch - 9ms/step
# Epoch 209/2000
# 7/7 - 0s - loss: 1.5094 - mse: 1.5094 - val_loss: 6.1489 - val_mse: 6.1489 - 60ms/epoch - 9ms/step
# Epoch 210/2000
# 7/7 - 0s - loss: 1.6043 - mse: 1.6043 - val_loss: 6.1584 - val_mse: 6.1584 - 61ms/epoch - 9ms/step
# Epoch 211/2000
# 7/7 - 0s - loss: 1.5430 - mse: 1.5430 - val_loss: 6.3320 - val_mse: 6.3320 - 60ms/epoch - 9ms/step
# Epoch 212/2000
# 7/7 - 0s - loss: 1.5799 - mse: 1.5799 - val_loss: 6.1691 - val_mse: 6.1691 - 69ms/epoch - 10ms/step
# Epoch 213/2000
# 7/7 - 0s - loss: 1.4596 - mse: 1.4596 - val_loss: 6.3104 - val_mse: 6.3104 - 61ms/epoch - 9ms/step
# Epoch 214/2000
# 7/7 - 0s - loss: 1.5038 - mse: 1.5038 - val_loss: 6.1568 - val_mse: 6.1568 - 62ms/epoch - 9ms/step
# Epoch 215/2000
# 7/7 - 0s - loss: 1.6351 - mse: 1.6351 - val_loss: 6.1553 - val_mse: 6.1553 - 63ms/epoch - 9ms/step
# Epoch 216/2000
# 7/7 - 0s - loss: 1.6011 - mse: 1.6011 - val_loss: 6.1562 - val_mse: 6.1562 - 61ms/epoch - 9ms/step
# Epoch 217/2000
# 7/7 - 0s - loss: 1.5784 - mse: 1.5784 - val_loss: 6.2274 - val_mse: 6.2274 - 59ms/epoch - 8ms/step
# Epoch 218/2000
# 7/7 - 0s - loss: 1.4631 - mse: 1.4631 - val_loss: 6.3288 - val_mse: 6.3288 - 61ms/epoch - 9ms/step
# Epoch 219/2000
# 7/7 - 0s - loss: 1.6374 - mse: 1.6374 - val_loss: 6.1624 - val_mse: 6.1624 - 64ms/epoch - 9ms/step
# Epoch 220/2000
# 7/7 - 0s - loss: 1.8205 - mse: 1.8205 - val_loss: 6.5971 - val_mse: 6.5971 - 57ms/epoch - 8ms/step
# Epoch 221/2000
# 7/7 - 0s - loss: 1.5874 - mse: 1.5874 - val_loss: 6.4851 - val_mse: 6.4851 - 61ms/epoch - 9ms/step
# Epoch 222/2000
# 7/7 - 0s - loss: 1.6775 - mse: 1.6775 - val_loss: 6.2444 - val_mse: 6.2444 - 59ms/epoch - 8ms/step
# Epoch 223/2000
# 7/7 - 0s - loss: 1.7640 - mse: 1.7640 - val_loss: 6.3261 - val_mse: 6.3261 - 56ms/epoch - 8ms/step
# Epoch 224/2000
# 7/7 - 0s - loss: 1.6084 - mse: 1.6084 - val_loss: 6.3766 - val_mse: 6.3766 - 60ms/epoch - 9ms/step
# Epoch 225/2000
# 7/7 - 0s - loss: 1.5166 - mse: 1.5166 - val_loss: 6.2336 - val_mse: 6.2336 - 57ms/epoch - 8ms/step
# Epoch 226/2000
# 7/7 - 0s - loss: 1.4349 - mse: 1.4349 - val_loss: 6.3263 - val_mse: 6.3263 - 55ms/epoch - 8ms/step
# Epoch 227/2000
# 7/7 - 0s - loss: 1.4759 - mse: 1.4759 - val_loss: 6.2118 - val_mse: 6.2118 - 60ms/epoch - 9ms/step
# Epoch 228/2000
# 7/7 - 0s - loss: 1.4413 - mse: 1.4413 - val_loss: 6.1654 - val_mse: 6.1654 - 61ms/epoch - 9ms/step
# Epoch 229/2000
# 7/7 - 0s - loss: 1.5593 - mse: 1.5593 - val_loss: 6.1546 - val_mse: 6.1546 - 57ms/epoch - 8ms/step
# Epoch 230/2000
# 7/7 - 0s - loss: 1.5646 - mse: 1.5646 - val_loss: 6.1796 - val_mse: 6.1796 - 59ms/epoch - 8ms/step
# Epoch 231/2000
# 7/7 - 0s - loss: 1.4581 - mse: 1.4581 - val_loss: 6.3105 - val_mse: 6.3105 - 57ms/epoch - 8ms/step
# Epoch 232/2000
# 7/7 - 0s - loss: 1.5708 - mse: 1.5708 - val_loss: 6.1008 - val_mse: 6.1008 - 56ms/epoch - 8ms/step
# Epoch 233/2000
# 7/7 - 0s - loss: 1.4316 - mse: 1.4316 - val_loss: 6.2304 - val_mse: 6.2304 - 58ms/epoch - 8ms/step
# Epoch 234/2000
# 7/7 - 0s - loss: 1.5143 - mse: 1.5143 - val_loss: 6.0946 - val_mse: 6.0946 - 56ms/epoch - 8ms/step
# Epoch 235/2000
# 7/7 - 0s - loss: 1.4837 - mse: 1.4837 - val_loss: 6.1054 - val_mse: 6.1054 - 55ms/epoch - 8ms/step
# Epoch 236/2000
# 7/7 - 0s - loss: 1.4266 - mse: 1.4266 - val_loss: 6.2575 - val_mse: 6.2575 - 60ms/epoch - 9ms/step
# Epoch 237/2000
# 7/7 - 0s - loss: 1.5690 - mse: 1.5690 - val_loss: 6.0937 - val_mse: 6.0937 - 58ms/epoch - 8ms/step
# Epoch 238/2000
# 7/7 - 0s - loss: 1.5141 - mse: 1.5141 - val_loss: 6.1043 - val_mse: 6.1043 - 56ms/epoch - 8ms/step
# Epoch 239/2000
# 7/7 - 0s - loss: 1.4456 - mse: 1.4456 - val_loss: 6.1405 - val_mse: 6.1405 - 58ms/epoch - 8ms/step
# Epoch 240/2000
# 7/7 - 0s - loss: 1.4557 - mse: 1.4557 - val_loss: 6.0732 - val_mse: 6.0732 - 56ms/epoch - 8ms/step
# Epoch 241/2000
# 7/7 - 0s - loss: 1.4568 - mse: 1.4568 - val_loss: 6.0815 - val_mse: 6.0815 - 62ms/epoch - 9ms/step
# Epoch 242/2000
# 7/7 - 0s - loss: 1.4275 - mse: 1.4275 - val_loss: 6.0973 - val_mse: 6.0973 - 84ms/epoch - 12ms/step
# Epoch 243/2000
# 7/7 - 0s - loss: 1.4337 - mse: 1.4337 - val_loss: 6.1173 - val_mse: 6.1173 - 59ms/epoch - 8ms/step
# Epoch 244/2000
# 7/7 - 0s - loss: 1.4262 - mse: 1.4262 - val_loss: 6.0761 - val_mse: 6.0761 - 54ms/epoch - 8ms/step
# Epoch 245/2000
# 7/7 - 0s - loss: 1.4729 - mse: 1.4729 - val_loss: 6.0967 - val_mse: 6.0967 - 56ms/epoch - 8ms/step
# Epoch 246/2000
# 7/7 - 0s - loss: 1.5193 - mse: 1.5193 - val_loss: 6.0632 - val_mse: 6.0632 - 54ms/epoch - 8ms/step
# Epoch 247/2000
# 7/7 - 0s - loss: 1.5188 - mse: 1.5188 - val_loss: 6.0555 - val_mse: 6.0555 - 59ms/epoch - 8ms/step
# Epoch 248/2000
# 7/7 - 0s - loss: 1.4816 - mse: 1.4816 - val_loss: 6.0886 - val_mse: 6.0886 - 52ms/epoch - 7ms/step
# Epoch 249/2000
# 7/7 - 0s - loss: 1.5709 - mse: 1.5709 - val_loss: 6.0575 - val_mse: 6.0575 - 53ms/epoch - 8ms/step
# Epoch 250/2000
# 7/7 - 0s - loss: 1.5184 - mse: 1.5184 - val_loss: 6.1264 - val_mse: 6.1264 - 53ms/epoch - 8ms/step
# Epoch 251/2000
# 7/7 - 0s - loss: 1.5107 - mse: 1.5107 - val_loss: 6.0699 - val_mse: 6.0699 - 56ms/epoch - 8ms/step
# Epoch 252/2000
# 7/7 - 0s - loss: 1.4063 - mse: 1.4063 - val_loss: 6.2618 - val_mse: 6.2618 - 79ms/epoch - 11ms/step
# Epoch 253/2000
# 7/7 - 0s - loss: 1.4646 - mse: 1.4646 - val_loss: 6.0652 - val_mse: 6.0652 - 62ms/epoch - 9ms/step
# Epoch 254/2000
# 7/7 - 0s - loss: 1.6118 - mse: 1.6118 - val_loss: 6.0445 - val_mse: 6.0445 - 61ms/epoch - 9ms/step
# Epoch 255/2000
# 7/7 - 0s - loss: 1.5141 - mse: 1.5141 - val_loss: 6.1657 - val_mse: 6.1657 - 56ms/epoch - 8ms/step
# Epoch 256/2000
# 7/7 - 0s - loss: 1.5702 - mse: 1.5702 - val_loss: 6.1202 - val_mse: 6.1202 - 57ms/epoch - 8ms/step
# Epoch 257/2000
# 7/7 - 0s - loss: 1.5212 - mse: 1.5212 - val_loss: 6.3636 - val_mse: 6.3636 - 63ms/epoch - 9ms/step
# Epoch 258/2000
# 7/7 - 0s - loss: 1.4545 - mse: 1.4545 - val_loss: 6.1076 - val_mse: 6.1076 - 62ms/epoch - 9ms/step
# Epoch 259/2000
# 7/7 - 0s - loss: 1.5024 - mse: 1.5024 - val_loss: 6.0654 - val_mse: 6.0654 - 61ms/epoch - 9ms/step
# Epoch 260/2000
# 7/7 - 0s - loss: 1.8508 - mse: 1.8508 - val_loss: 6.1599 - val_mse: 6.1599 - 62ms/epoch - 9ms/step
# Epoch 261/2000
# 7/7 - 0s - loss: 1.9050 - mse: 1.9050 - val_loss: 6.3416 - val_mse: 6.3416 - 62ms/epoch - 9ms/step
# Epoch 262/2000
# 7/7 - 0s - loss: 1.6347 - mse: 1.6347 - val_loss: 6.5567 - val_mse: 6.5567 - 62ms/epoch - 9ms/step
# Epoch 263/2000
# 7/7 - 0s - loss: 1.6457 - mse: 1.6457 - val_loss: 6.2082 - val_mse: 6.2082 - 61ms/epoch - 9ms/step
# Epoch 264/2000
# 7/7 - 0s - loss: 1.4945 - mse: 1.4945 - val_loss: 6.1732 - val_mse: 6.1732 - 61ms/epoch - 9ms/step
# Epoch 265/2000
# 7/7 - 0s - loss: 1.6583 - mse: 1.6583 - val_loss: 6.1163 - val_mse: 6.1163 - 61ms/epoch - 9ms/step
# Epoch 266/2000
# 7/7 - 0s - loss: 1.5427 - mse: 1.5427 - val_loss: 6.0706 - val_mse: 6.0706 - 60ms/epoch - 9ms/step
# Epoch 267/2000
# 7/7 - 0s - loss: 1.5067 - mse: 1.5067 - val_loss: 6.1482 - val_mse: 6.1482 - 57ms/epoch - 8ms/step
# Epoch 268/2000
# 7/7 - 0s - loss: 1.4844 - mse: 1.4844 - val_loss: 6.0577 - val_mse: 6.0577 - 60ms/epoch - 9ms/step
# Epoch 269/2000
# 7/7 - 0s - loss: 1.5629 - mse: 1.5629 - val_loss: 6.0604 - val_mse: 6.0604 - 63ms/epoch - 9ms/step
# Epoch 270/2000
# 7/7 - 0s - loss: 1.9581 - mse: 1.9581 - val_loss: 6.5094 - val_mse: 6.5094 - 64ms/epoch - 9ms/step
# Epoch 271/2000
# 7/7 - 0s - loss: 1.8684 - mse: 1.8684 - val_loss: 6.3309 - val_mse: 6.3309 - 60ms/epoch - 9ms/step
# Epoch 272/2000
# 7/7 - 0s - loss: 1.5350 - mse: 1.5350 - val_loss: 6.1356 - val_mse: 6.1356 - 60ms/epoch - 9ms/step
# Epoch 273/2000
# 7/7 - 0s - loss: 1.4843 - mse: 1.4843 - val_loss: 6.1102 - val_mse: 6.1102 - 63ms/epoch - 9ms/step
# Epoch 274/2000
# 7/7 - 0s - loss: 1.4228 - mse: 1.4228 - val_loss: 6.2078 - val_mse: 6.2078 - 95ms/epoch - 14ms/step
# Epoch 275/2000
# 7/7 - 0s - loss: 1.5090 - mse: 1.5090 - val_loss: 6.1156 - val_mse: 6.1156 - 60ms/epoch - 9ms/step
# Epoch 276/2000
# 7/7 - 0s - loss: 1.4664 - mse: 1.4664 - val_loss: 6.0790 - val_mse: 6.0790 - 61ms/epoch - 9ms/step
# Epoch 277/2000
# 7/7 - 0s - loss: 1.4937 - mse: 1.4937 - val_loss: 6.0450 - val_mse: 6.0450 - 62ms/epoch - 9ms/step
# Epoch 278/2000
# 7/7 - 0s - loss: 1.4640 - mse: 1.4640 - val_loss: 6.0758 - val_mse: 6.0758 - 58ms/epoch - 8ms/step
# Epoch 279/2000
# 7/7 - 0s - loss: 1.5355 - mse: 1.5355 - val_loss: 6.1040 - val_mse: 6.1040 - 66ms/epoch - 9ms/step
# Epoch 280/2000
# 7/7 - 0s - loss: 1.4444 - mse: 1.4444 - val_loss: 6.2363 - val_mse: 6.2363 - 61ms/epoch - 9ms/step
# Epoch 281/2000
# 7/7 - 0s - loss: 1.4893 - mse: 1.4893 - val_loss: 6.0237 - val_mse: 6.0237 - 58ms/epoch - 8ms/step
# Epoch 282/2000
# 7/7 - 0s - loss: 1.4295 - mse: 1.4295 - val_loss: 6.0960 - val_mse: 6.0960 - 63ms/epoch - 9ms/step
# Epoch 283/2000
# 7/7 - 0s - loss: 1.4967 - mse: 1.4967 - val_loss: 6.0366 - val_mse: 6.0366 - 55ms/epoch - 8ms/step
# Epoch 284/2000
# 7/7 - 0s - loss: 1.4685 - mse: 1.4685 - val_loss: 6.1501 - val_mse: 6.1501 - 54ms/epoch - 8ms/step
# Epoch 285/2000
# 7/7 - 0s - loss: 1.4264 - mse: 1.4264 - val_loss: 6.0058 - val_mse: 6.0058 - 57ms/epoch - 8ms/step
# Epoch 286/2000
# 7/7 - 0s - loss: 1.4305 - mse: 1.4305 - val_loss: 6.1094 - val_mse: 6.1094 - 55ms/epoch - 8ms/step
# Epoch 287/2000
# 7/7 - 0s - loss: 1.4340 - mse: 1.4340 - val_loss: 6.0180 - val_mse: 6.0180 - 55ms/epoch - 8ms/step
# Epoch 288/2000
# 7/7 - 0s - loss: 1.4683 - mse: 1.4683 - val_loss: 5.9779 - val_mse: 5.9779 - 55ms/epoch - 8ms/step
# Epoch 289/2000
# 7/7 - 0s - loss: 1.4550 - mse: 1.4550 - val_loss: 6.0218 - val_mse: 6.0218 - 55ms/epoch - 8ms/step
# Epoch 290/2000
# 7/7 - 0s - loss: 1.3973 - mse: 1.3973 - val_loss: 5.9628 - val_mse: 5.9628 - 57ms/epoch - 8ms/step
# Epoch 291/2000
# 7/7 - 0s - loss: 1.4713 - mse: 1.4713 - val_loss: 5.9550 - val_mse: 5.9550 - 54ms/epoch - 8ms/step
# Epoch 292/2000
# 7/7 - 0s - loss: 1.4002 - mse: 1.4002 - val_loss: 6.1590 - val_mse: 6.1590 - 54ms/epoch - 8ms/step
# Epoch 293/2000
# 7/7 - 0s - loss: 1.4262 - mse: 1.4262 - val_loss: 5.9943 - val_mse: 5.9943 - 56ms/epoch - 8ms/step
# Epoch 294/2000
# 7/7 - 0s - loss: 1.5030 - mse: 1.5030 - val_loss: 6.0252 - val_mse: 6.0252 - 54ms/epoch - 8ms/step
# Epoch 295/2000
# 7/7 - 0s - loss: 1.5208 - mse: 1.5208 - val_loss: 5.9920 - val_mse: 5.9920 - 57ms/epoch - 8ms/step
# Epoch 296/2000
# 7/7 - 0s - loss: 1.4886 - mse: 1.4886 - val_loss: 5.9811 - val_mse: 5.9811 - 56ms/epoch - 8ms/step
# Epoch 297/2000
# 7/7 - 0s - loss: 1.4979 - mse: 1.4979 - val_loss: 6.0508 - val_mse: 6.0508 - 59ms/epoch - 8ms/step
# Epoch 298/2000
# 7/7 - 0s - loss: 1.4304 - mse: 1.4304 - val_loss: 5.9834 - val_mse: 5.9834 - 54ms/epoch - 8ms/step
# Epoch 299/2000
# 7/7 - 0s - loss: 1.3852 - mse: 1.3852 - val_loss: 6.1501 - val_mse: 6.1501 - 56ms/epoch - 8ms/step
# Epoch 300/2000
# 7/7 - 0s - loss: 1.5616 - mse: 1.5616 - val_loss: 6.0011 - val_mse: 6.0011 - 56ms/epoch - 8ms/step
# Epoch 301/2000
# 7/7 - 0s - loss: 1.5438 - mse: 1.5438 - val_loss: 6.0171 - val_mse: 6.0171 - 58ms/epoch - 8ms/step
# Epoch 302/2000
# 7/7 - 0s - loss: 1.4110 - mse: 1.4110 - val_loss: 6.1160 - val_mse: 6.1160 - 55ms/epoch - 8ms/step
# Epoch 303/2000
# 7/7 - 0s - loss: 1.4173 - mse: 1.4173 - val_loss: 5.9958 - val_mse: 5.9958 - 56ms/epoch - 8ms/step
# Epoch 304/2000
# 7/7 - 0s - loss: 1.4683 - mse: 1.4683 - val_loss: 6.0679 - val_mse: 6.0679 - 59ms/epoch - 8ms/step
# Epoch 305/2000
# 7/7 - 0s - loss: 1.4605 - mse: 1.4605 - val_loss: 5.9571 - val_mse: 5.9571 - 55ms/epoch - 8ms/step
# Epoch 306/2000
# 7/7 - 0s - loss: 1.3762 - mse: 1.3762 - val_loss: 6.1793 - val_mse: 6.1793 - 82ms/epoch - 12ms/step
# Epoch 307/2000
# 7/7 - 0s - loss: 1.4237 - mse: 1.4237 - val_loss: 5.9486 - val_mse: 5.9486 - 67ms/epoch - 10ms/step
# Epoch 308/2000
# 7/7 - 0s - loss: 1.4547 - mse: 1.4547 - val_loss: 5.9429 - val_mse: 5.9429 - 55ms/epoch - 8ms/step
# Epoch 309/2000
# 7/7 - 0s - loss: 1.4474 - mse: 1.4474 - val_loss: 5.9885 - val_mse: 5.9885 - 56ms/epoch - 8ms/step
# Epoch 310/2000
# 7/7 - 0s - loss: 1.4687 - mse: 1.4687 - val_loss: 5.9384 - val_mse: 5.9384 - 56ms/epoch - 8ms/step
# Epoch 311/2000
# 7/7 - 0s - loss: 1.4067 - mse: 1.4067 - val_loss: 5.9922 - val_mse: 5.9922 - 55ms/epoch - 8ms/step
# Epoch 312/2000
# 7/7 - 0s - loss: 1.4187 - mse: 1.4187 - val_loss: 5.9736 - val_mse: 5.9736 - 53ms/epoch - 8ms/step
# Epoch 313/2000
# 7/7 - 0s - loss: 1.4337 - mse: 1.4337 - val_loss: 5.9469 - val_mse: 5.9469 - 55ms/epoch - 8ms/step
# Epoch 314/2000
# 7/7 - 0s - loss: 1.4677 - mse: 1.4677 - val_loss: 5.9297 - val_mse: 5.9297 - 59ms/epoch - 8ms/step
# Epoch 315/2000
# 7/7 - 0s - loss: 1.5630 - mse: 1.5630 - val_loss: 5.9115 - val_mse: 5.9115 - 62ms/epoch - 9ms/step
# Epoch 316/2000
# 7/7 - 0s - loss: 1.3846 - mse: 1.3846 - val_loss: 6.2083 - val_mse: 6.2083 - 63ms/epoch - 9ms/step
# Epoch 317/2000
# 7/7 - 0s - loss: 1.4589 - mse: 1.4589 - val_loss: 5.9068 - val_mse: 5.9068 - 63ms/epoch - 9ms/step
# Epoch 318/2000
# 7/7 - 0s - loss: 1.3761 - mse: 1.3761 - val_loss: 6.0710 - val_mse: 6.0710 - 61ms/epoch - 9ms/step
# Epoch 319/2000
# 7/7 - 0s - loss: 1.4318 - mse: 1.4318 - val_loss: 5.9114 - val_mse: 5.9114 - 61ms/epoch - 9ms/step
# Epoch 320/2000
# 7/7 - 0s - loss: 1.3721 - mse: 1.3721 - val_loss: 5.9980 - val_mse: 5.9980 - 73ms/epoch - 10ms/step
# Epoch 321/2000
# 7/7 - 0s - loss: 1.4108 - mse: 1.4108 - val_loss: 5.9027 - val_mse: 5.9027 - 73ms/epoch - 10ms/step
# Epoch 322/2000
# 7/7 - 0s - loss: 1.4576 - mse: 1.4576 - val_loss: 5.8961 - val_mse: 5.8961 - 64ms/epoch - 9ms/step
# Epoch 323/2000
# 7/7 - 0s - loss: 1.3798 - mse: 1.3798 - val_loss: 5.8869 - val_mse: 5.8869 - 62ms/epoch - 9ms/step
# Epoch 324/2000
# 7/7 - 0s - loss: 1.4129 - mse: 1.4129 - val_loss: 5.9382 - val_mse: 5.9382 - 59ms/epoch - 8ms/step
# Epoch 325/2000
# 7/7 - 0s - loss: 1.5201 - mse: 1.5201 - val_loss: 5.9334 - val_mse: 5.9334 - 62ms/epoch - 9ms/step
# Epoch 326/2000
# 7/7 - 0s - loss: 1.4932 - mse: 1.4932 - val_loss: 5.8873 - val_mse: 5.8873 - 61ms/epoch - 9ms/step
# Epoch 327/2000
# 7/7 - 0s - loss: 1.5193 - mse: 1.5193 - val_loss: 5.8955 - val_mse: 5.8955 - 60ms/epoch - 9ms/step
# Epoch 328/2000
# 7/7 - 0s - loss: 1.4609 - mse: 1.4609 - val_loss: 5.9024 - val_mse: 5.9024 - 60ms/epoch - 9ms/step
# Epoch 329/2000
# 7/7 - 0s - loss: 1.4579 - mse: 1.4579 - val_loss: 5.9322 - val_mse: 5.9322 - 62ms/epoch - 9ms/step
# Epoch 330/2000
# 7/7 - 0s - loss: 1.4095 - mse: 1.4095 - val_loss: 5.8826 - val_mse: 5.8826 - 56ms/epoch - 8ms/step
# Epoch 331/2000
# 7/7 - 0s - loss: 1.3538 - mse: 1.3538 - val_loss: 6.1078 - val_mse: 6.1078 - 74ms/epoch - 11ms/step
# Epoch 332/2000
# 7/7 - 0s - loss: 1.4925 - mse: 1.4925 - val_loss: 5.9032 - val_mse: 5.9032 - 68ms/epoch - 10ms/step
# Epoch 333/2000
# 7/7 - 0s - loss: 1.5375 - mse: 1.5375 - val_loss: 5.8611 - val_mse: 5.8611 - 65ms/epoch - 9ms/step
# Epoch 334/2000
# 7/7 - 0s - loss: 1.5050 - mse: 1.5050 - val_loss: 5.9881 - val_mse: 5.9881 - 58ms/epoch - 8ms/step
# Epoch 335/2000
# 7/7 - 0s - loss: 1.5642 - mse: 1.5642 - val_loss: 5.8749 - val_mse: 5.8749 - 55ms/epoch - 8ms/step
# Epoch 336/2000
# 7/7 - 0s - loss: 1.4414 - mse: 1.4414 - val_loss: 5.9939 - val_mse: 5.9939 - 56ms/epoch - 8ms/step
# Epoch 337/2000
# 7/7 - 0s - loss: 1.3984 - mse: 1.3984 - val_loss: 5.8807 - val_mse: 5.8807 - 53ms/epoch - 8ms/step
# Epoch 338/2000
# 7/7 - 0s - loss: 1.3903 - mse: 1.3903 - val_loss: 6.0123 - val_mse: 6.0123 - 89ms/epoch - 13ms/step
# Epoch 339/2000
# 7/7 - 0s - loss: 1.3981 - mse: 1.3981 - val_loss: 5.8992 - val_mse: 5.8992 - 59ms/epoch - 8ms/step
# Epoch 340/2000
# 7/7 - 0s - loss: 1.3832 - mse: 1.3832 - val_loss: 5.8867 - val_mse: 5.8867 - 53ms/epoch - 8ms/step
# Epoch 341/2000
# 7/7 - 0s - loss: 1.3744 - mse: 1.3744 - val_loss: 5.8828 - val_mse: 5.8828 - 59ms/epoch - 8ms/step
# Epoch 342/2000
# 7/7 - 0s - loss: 1.4228 - mse: 1.4228 - val_loss: 5.8633 - val_mse: 5.8633 - 60ms/epoch - 9ms/step
# Epoch 343/2000
# 7/7 - 0s - loss: 1.4519 - mse: 1.4519 - val_loss: 5.8332 - val_mse: 5.8332 - 64ms/epoch - 9ms/step
# Epoch 344/2000
# 7/7 - 0s - loss: 1.3900 - mse: 1.3900 - val_loss: 5.8833 - val_mse: 5.8833 - 55ms/epoch - 8ms/step
# Epoch 345/2000
# 7/7 - 0s - loss: 1.5753 - mse: 1.5753 - val_loss: 5.8489 - val_mse: 5.8489 - 53ms/epoch - 8ms/step
# Epoch 346/2000
# 7/7 - 0s - loss: 2.1165 - mse: 2.1165 - val_loss: 6.4120 - val_mse: 6.4120 - 54ms/epoch - 8ms/step
# Epoch 347/2000
# 7/7 - 0s - loss: 1.7911 - mse: 1.7911 - val_loss: 6.6705 - val_mse: 6.6705 - 51ms/epoch - 7ms/step
# Epoch 348/2000
# 7/7 - 0s - loss: 1.6078 - mse: 1.6078 - val_loss: 5.9754 - val_mse: 5.9754 - 52ms/epoch - 7ms/step
# Epoch 349/2000
# 7/7 - 0s - loss: 1.4993 - mse: 1.4993 - val_loss: 5.9213 - val_mse: 5.9213 - 55ms/epoch - 8ms/step
# Epoch 350/2000
# 7/7 - 0s - loss: 1.4123 - mse: 1.4123 - val_loss: 6.0717 - val_mse: 6.0717 - 60ms/epoch - 9ms/step
# Epoch 351/2000
# 7/7 - 0s - loss: 1.3695 - mse: 1.3695 - val_loss: 5.9138 - val_mse: 5.9138 - 55ms/epoch - 8ms/step
# Epoch 352/2000
# 7/7 - 0s - loss: 1.4023 - mse: 1.4023 - val_loss: 5.9533 - val_mse: 5.9533 - 56ms/epoch - 8ms/step
# Epoch 353/2000
# 7/7 - 0s - loss: 1.4336 - mse: 1.4336 - val_loss: 5.8429 - val_mse: 5.8429 - 60ms/epoch - 9ms/step
# Epoch 354/2000
# 7/7 - 0s - loss: 1.4482 - mse: 1.4482 - val_loss: 5.8418 - val_mse: 5.8418 - 56ms/epoch - 8ms/step
# Epoch 355/2000
# 7/7 - 0s - loss: 1.4316 - mse: 1.4316 - val_loss: 5.8452 - val_mse: 5.8452 - 62ms/epoch - 9ms/step
# Epoch 356/2000
# 7/7 - 0s - loss: 1.3622 - mse: 1.3622 - val_loss: 5.9606 - val_mse: 5.9606 - 62ms/epoch - 9ms/step
# Epoch 357/2000
# 7/7 - 0s - loss: 1.3879 - mse: 1.3879 - val_loss: 5.8401 - val_mse: 5.8401 - 56ms/epoch - 8ms/step
# Epoch 358/2000
# 7/7 - 0s - loss: 1.4649 - mse: 1.4649 - val_loss: 5.8389 - val_mse: 5.8389 - 55ms/epoch - 8ms/step
# Epoch 359/2000
# 7/7 - 0s - loss: 1.4288 - mse: 1.4288 - val_loss: 5.9535 - val_mse: 5.9535 - 62ms/epoch - 9ms/step
# Epoch 360/2000
# 7/7 - 0s - loss: 1.3897 - mse: 1.3897 - val_loss: 5.8224 - val_mse: 5.8224 - 62ms/epoch - 9ms/step
# Epoch 361/2000
# 7/7 - 0s - loss: 1.3672 - mse: 1.3672 - val_loss: 5.8947 - val_mse: 5.8947 - 62ms/epoch - 9ms/step
# Epoch 362/2000
# 7/7 - 0s - loss: 1.4084 - mse: 1.4084 - val_loss: 5.8340 - val_mse: 5.8340 - 64ms/epoch - 9ms/step
# Epoch 363/2000
# 7/7 - 0s - loss: 1.3727 - mse: 1.3727 - val_loss: 5.9052 - val_mse: 5.9052 - 59ms/epoch - 8ms/step
# Epoch 364/2000
# 7/7 - 0s - loss: 1.4012 - mse: 1.4012 - val_loss: 5.8271 - val_mse: 5.8271 - 64ms/epoch - 9ms/step
# Epoch 365/2000
# 7/7 - 0s - loss: 1.3925 - mse: 1.3925 - val_loss: 5.8395 - val_mse: 5.8395 - 61ms/epoch - 9ms/step
# Epoch 366/2000
# 7/7 - 0s - loss: 1.4451 - mse: 1.4451 - val_loss: 5.8907 - val_mse: 5.8907 - 61ms/epoch - 9ms/step
# Epoch 367/2000
# 7/7 - 0s - loss: 1.4436 - mse: 1.4436 - val_loss: 5.8633 - val_mse: 5.8633 - 61ms/epoch - 9ms/step
# Epoch 368/2000
# 7/7 - 0s - loss: 1.3656 - mse: 1.3656 - val_loss: 5.8579 - val_mse: 5.8579 - 67ms/epoch - 10ms/step
# Epoch 369/2000
# 7/7 - 0s - loss: 1.3838 - mse: 1.3838 - val_loss: 5.8128 - val_mse: 5.8128 - 61ms/epoch - 9ms/step
# Epoch 370/2000
# 7/7 - 0s - loss: 1.4321 - mse: 1.4321 - val_loss: 5.8131 - val_mse: 5.8131 - 97ms/epoch - 14ms/step
# Epoch 371/2000
# 7/7 - 0s - loss: 1.4834 - mse: 1.4834 - val_loss: 5.8431 - val_mse: 5.8431 - 60ms/epoch - 9ms/step
# Epoch 372/2000
# 7/7 - 0s - loss: 1.3821 - mse: 1.3821 - val_loss: 5.8014 - val_mse: 5.8014 - 59ms/epoch - 8ms/step
# Epoch 373/2000
# 7/7 - 0s - loss: 1.3987 - mse: 1.3987 - val_loss: 5.7903 - val_mse: 5.7903 - 60ms/epoch - 9ms/step
# Epoch 374/2000
# 7/7 - 0s - loss: 1.3788 - mse: 1.3788 - val_loss: 5.8349 - val_mse: 5.8349 - 60ms/epoch - 9ms/step
# Epoch 375/2000
# 7/7 - 0s - loss: 1.3510 - mse: 1.3510 - val_loss: 5.8702 - val_mse: 5.8702 - 57ms/epoch - 8ms/step
# Epoch 376/2000
# 7/7 - 0s - loss: 1.3869 - mse: 1.3869 - val_loss: 5.8378 - val_mse: 5.8378 - 58ms/epoch - 8ms/step
# Epoch 377/2000
# 7/7 - 0s - loss: 1.3486 - mse: 1.3486 - val_loss: 5.8526 - val_mse: 5.8526 - 56ms/epoch - 8ms/step
# Epoch 378/2000
# 7/7 - 0s - loss: 1.3658 - mse: 1.3658 - val_loss: 5.8172 - val_mse: 5.8172 - 70ms/epoch - 10ms/step
# Epoch 379/2000
# 7/7 - 0s - loss: 1.3976 - mse: 1.3976 - val_loss: 5.8161 - val_mse: 5.8161 - 61ms/epoch - 9ms/step
# Epoch 380/2000
# 7/7 - 0s - loss: 1.4399 - mse: 1.4399 - val_loss: 5.7906 - val_mse: 5.7906 - 59ms/epoch - 8ms/step
# Epoch 381/2000
# 7/7 - 0s - loss: 1.5357 - mse: 1.5357 - val_loss: 5.7673 - val_mse: 5.7673 - 63ms/epoch - 9ms/step
# Epoch 382/2000
# 7/7 - 0s - loss: 1.4282 - mse: 1.4282 - val_loss: 5.8862 - val_mse: 5.8862 - 63ms/epoch - 9ms/step
# Epoch 383/2000
# 7/7 - 0s - loss: 1.3981 - mse: 1.3981 - val_loss: 5.7799 - val_mse: 5.7799 - 63ms/epoch - 9ms/step
# Epoch 384/2000
# 7/7 - 0s - loss: 1.3754 - mse: 1.3754 - val_loss: 5.9002 - val_mse: 5.9002 - 59ms/epoch - 8ms/step
# Epoch 385/2000
# 7/7 - 0s - loss: 1.3958 - mse: 1.3958 - val_loss: 5.7783 - val_mse: 5.7783 - 61ms/epoch - 9ms/step
# Epoch 386/2000
# 7/7 - 0s - loss: 1.3787 - mse: 1.3787 - val_loss: 5.7817 - val_mse: 5.7817 - 58ms/epoch - 8ms/step
# Epoch 387/2000
# 7/7 - 0s - loss: 1.3569 - mse: 1.3569 - val_loss: 5.8582 - val_mse: 5.8582 - 57ms/epoch - 8ms/step
# Epoch 388/2000
# 7/7 - 0s - loss: 1.3631 - mse: 1.3631 - val_loss: 5.8849 - val_mse: 5.8849 - 57ms/epoch - 8ms/step
# Epoch 389/2000
# 7/7 - 0s - loss: 1.4464 - mse: 1.4464 - val_loss: 5.7831 - val_mse: 5.7831 - 60ms/epoch - 9ms/step
# Epoch 390/2000
# 7/7 - 0s - loss: 1.3996 - mse: 1.3996 - val_loss: 5.8226 - val_mse: 5.8226 - 56ms/epoch - 8ms/step
# Epoch 391/2000
# 7/7 - 0s - loss: 1.4652 - mse: 1.4652 - val_loss: 5.7587 - val_mse: 5.7587 - 56ms/epoch - 8ms/step
# Epoch 392/2000
# 7/7 - 0s - loss: 1.3968 - mse: 1.3968 - val_loss: 5.8336 - val_mse: 5.8336 - 60ms/epoch - 9ms/step
# Epoch 393/2000
# 7/7 - 0s - loss: 1.3911 - mse: 1.3911 - val_loss: 5.7698 - val_mse: 5.7698 - 60ms/epoch - 9ms/step
# Epoch 394/2000
# 7/7 - 0s - loss: 1.4272 - mse: 1.4272 - val_loss: 5.9039 - val_mse: 5.9039 - 60ms/epoch - 9ms/step
# Epoch 395/2000
# 7/7 - 0s - loss: 1.4982 - mse: 1.4982 - val_loss: 5.7785 - val_mse: 5.7785 - 61ms/epoch - 9ms/step
# Epoch 396/2000
# 7/7 - 0s - loss: 1.3433 - mse: 1.3433 - val_loss: 6.0412 - val_mse: 6.0412 - 55ms/epoch - 8ms/step
# Epoch 397/2000
# 7/7 - 0s - loss: 1.5240 - mse: 1.5240 - val_loss: 5.7736 - val_mse: 5.7736 - 55ms/epoch - 8ms/step
# Epoch 398/2000
# 7/7 - 0s - loss: 1.3499 - mse: 1.3499 - val_loss: 6.0021 - val_mse: 6.0021 - 59ms/epoch - 8ms/step
# Epoch 399/2000
# 7/7 - 0s - loss: 1.3948 - mse: 1.3948 - val_loss: 5.7432 - val_mse: 5.7432 - 58ms/epoch - 8ms/step
# Epoch 400/2000
# 7/7 - 0s - loss: 1.3604 - mse: 1.3604 - val_loss: 5.9799 - val_mse: 5.9799 - 65ms/epoch - 9ms/step
# Epoch 401/2000
# 7/7 - 0s - loss: 1.3756 - mse: 1.3756 - val_loss: 5.7447 - val_mse: 5.7447 - 88ms/epoch - 13ms/step
# Epoch 402/2000
# 7/7 - 0s - loss: 1.3452 - mse: 1.3452 - val_loss: 5.8205 - val_mse: 5.8205 - 58ms/epoch - 8ms/step
# Epoch 403/2000
# 7/7 - 0s - loss: 1.5404 - mse: 1.5404 - val_loss: 5.7483 - val_mse: 5.7483 - 55ms/epoch - 8ms/step
# Epoch 404/2000
# 7/7 - 0s - loss: 1.4592 - mse: 1.4592 - val_loss: 5.7912 - val_mse: 5.7912 - 59ms/epoch - 8ms/step
# Epoch 405/2000
# 7/7 - 0s - loss: 1.5014 - mse: 1.5014 - val_loss: 5.7202 - val_mse: 5.7202 - 56ms/epoch - 8ms/step
# Epoch 406/2000
# 7/7 - 0s - loss: 1.3241 - mse: 1.3241 - val_loss: 5.9955 - val_mse: 5.9955 - 56ms/epoch - 8ms/step
# Epoch 407/2000
# 7/7 - 0s - loss: 1.5507 - mse: 1.5507 - val_loss: 5.7115 - val_mse: 5.7115 - 54ms/epoch - 8ms/step
# Epoch 408/2000
# 7/7 - 0s - loss: 1.2807 - mse: 1.2807 - val_loss: 6.2687 - val_mse: 6.2687 - 53ms/epoch - 8ms/step
# Epoch 409/2000
# 7/7 - 0s - loss: 1.4814 - mse: 1.4814 - val_loss: 5.7723 - val_mse: 5.7723 - 51ms/epoch - 7ms/step
# Epoch 410/2000
# 7/7 - 0s - loss: 1.4492 - mse: 1.4492 - val_loss: 5.7778 - val_mse: 5.7778 - 57ms/epoch - 8ms/step
# Epoch 411/2000
# 7/7 - 0s - loss: 1.4990 - mse: 1.4990 - val_loss: 5.7268 - val_mse: 5.7268 - 57ms/epoch - 8ms/step
# Epoch 412/2000
# 7/7 - 0s - loss: 1.3496 - mse: 1.3496 - val_loss: 5.8338 - val_mse: 5.8338 - 58ms/epoch - 8ms/step
# Epoch 413/2000
# 7/7 - 0s - loss: 1.3517 - mse: 1.3517 - val_loss: 5.7220 - val_mse: 5.7220 - 62ms/epoch - 9ms/step
# Epoch 414/2000
# 7/7 - 0s - loss: 1.4113 - mse: 1.4113 - val_loss: 5.7172 - val_mse: 5.7172 - 64ms/epoch - 9ms/step
# Epoch 415/2000
# 7/7 - 0s - loss: 1.3314 - mse: 1.3314 - val_loss: 5.8349 - val_mse: 5.8349 - 62ms/epoch - 9ms/step
# Epoch 416/2000
# 7/7 - 0s - loss: 1.3432 - mse: 1.3432 - val_loss: 5.6998 - val_mse: 5.6998 - 61ms/epoch - 9ms/step
# Epoch 417/2000
# 7/7 - 0s - loss: 1.3803 - mse: 1.3803 - val_loss: 5.7769 - val_mse: 5.7769 - 60ms/epoch - 9ms/step
# Epoch 418/2000
# 7/7 - 0s - loss: 1.3377 - mse: 1.3377 - val_loss: 5.6908 - val_mse: 5.6908 - 62ms/epoch - 9ms/step
# Epoch 419/2000
# 7/7 - 0s - loss: 1.3463 - mse: 1.3463 - val_loss: 5.8633 - val_mse: 5.8633 - 60ms/epoch - 9ms/step
# Epoch 420/2000
# 7/7 - 0s - loss: 1.4014 - mse: 1.4014 - val_loss: 5.7411 - val_mse: 5.7411 - 68ms/epoch - 10ms/step
# Epoch 421/2000
# 7/7 - 0s - loss: 1.6560 - mse: 1.6560 - val_loss: 5.7232 - val_mse: 5.7232 - 62ms/epoch - 9ms/step
# Epoch 422/2000
# ...
# 7/7 - 0s - loss: 1.3623 - mse: 1.3623 - val_loss: 4.8305 - val_mse: 4.8305 - 59ms/epoch - 8ms/step
# Epoch 1863/2000
# 7/7 - 0s - loss: 1.1143 - mse: 1.1143 - val_loss: 4.9143 - val_mse: 4.9143 - 60ms/epoch - 9ms/step
# Epoch 1864/2000
# 7/7 - 0s - loss: 1.2077 - mse: 1.2077 - val_loss: 4.7754 - val_mse: 4.7754 - 75ms/epoch - 11ms/step
# Epoch 1865/2000
# 7/7 - 0s - loss: 1.0974 - mse: 1.0974 - val_loss: 4.8543 - val_mse: 4.8543 - 53ms/epoch - 8ms/step
# Epoch 1866/2000
# 7/7 - 0s - loss: 1.1629 - mse: 1.1629 - val_loss: 4.8290 - val_mse: 4.8290 - 55ms/epoch - 8ms/step
# Epoch 1867/2000
# 7/7 - 0s - loss: 1.0726 - mse: 1.0726 - val_loss: 4.7959 - val_mse: 4.7959 - 61ms/epoch - 9ms/step
# Epoch 1868/2000
# 7/7 - 0s - loss: 1.0740 - mse: 1.0740 - val_loss: 4.8527 - val_mse: 4.8527 - 54ms/epoch - 8ms/step
# Epoch 1869/2000
# 7/7 - 0s - loss: 1.2038 - mse: 1.2038 - val_loss: 4.8083 - val_mse: 4.8083 - 55ms/epoch - 8ms/step
# Epoch 1870/2000
# 7/7 - 0s - loss: 1.1453 - mse: 1.1453 - val_loss: 4.9481 - val_mse: 4.9481 - 55ms/epoch - 8ms/step
# Epoch 1871/2000
# 7/7 - 0s - loss: 1.0624 - mse: 1.0624 - val_loss: 4.7746 - val_mse: 4.7746 - 55ms/epoch - 8ms/step
# Epoch 1872/2000
# 7/7 - 0s - loss: 1.1866 - mse: 1.1866 - val_loss: 4.9010 - val_mse: 4.9010 - 64ms/epoch - 9ms/step
# Epoch 1873/2000
# 7/7 - 0s - loss: 1.1518 - mse: 1.1518 - val_loss: 4.7467 - val_mse: 4.7467 - 54ms/epoch - 8ms/step
# Epoch 1874/2000
# 7/7 - 0s - loss: 1.0966 - mse: 1.0966 - val_loss: 4.9946 - val_mse: 4.9946 - 57ms/epoch - 8ms/step
# Epoch 1875/2000
# 7/7 - 0s - loss: 1.1187 - mse: 1.1187 - val_loss: 4.8000 - val_mse: 4.8000 - 57ms/epoch - 8ms/step
# Epoch 1876/2000
# 7/7 - 0s - loss: 1.1849 - mse: 1.1849 - val_loss: 4.8745 - val_mse: 4.8745 - 52ms/epoch - 7ms/step
# Epoch 1877/2000
# 7/7 - 0s - loss: 1.1769 - mse: 1.1769 - val_loss: 4.7774 - val_mse: 4.7774 - 63ms/epoch - 9ms/step
# Epoch 1878/2000
# 7/7 - 0s - loss: 1.0957 - mse: 1.0957 - val_loss: 4.8643 - val_mse: 4.8643 - 68ms/epoch - 10ms/step
# Epoch 1879/2000
# 7/7 - 0s - loss: 1.0680 - mse: 1.0680 - val_loss: 4.7728 - val_mse: 4.7728 - 90ms/epoch - 13ms/step
# Epoch 1880/2000
# 7/7 - 0s - loss: 1.1548 - mse: 1.1548 - val_loss: 4.7601 - val_mse: 4.7601 - 56ms/epoch - 8ms/step
# Epoch 1881/2000
# 7/7 - 0s - loss: 1.0104 - mse: 1.0104 - val_loss: 4.9746 - val_mse: 4.9746 - 57ms/epoch - 8ms/step
# Epoch 1882/2000
# 7/7 - 0s - loss: 1.0882 - mse: 1.0882 - val_loss: 4.7926 - val_mse: 4.7926 - 58ms/epoch - 8ms/step
# Epoch 1883/2000
# 7/7 - 0s - loss: 1.0856 - mse: 1.0856 - val_loss: 4.8562 - val_mse: 4.8562 - 56ms/epoch - 8ms/step
# Epoch 1884/2000
# 7/7 - 0s - loss: 1.1114 - mse: 1.1114 - val_loss: 4.8465 - val_mse: 4.8465 - 58ms/epoch - 8ms/step
# Epoch 1885/2000
# 7/7 - 0s - loss: 1.0681 - mse: 1.0681 - val_loss: 4.8474 - val_mse: 4.8474 - 55ms/epoch - 8ms/step
# Epoch 1886/2000
# 7/7 - 0s - loss: 1.1972 - mse: 1.1972 - val_loss: 4.7655 - val_mse: 4.7655 - 55ms/epoch - 8ms/step
# Epoch 1887/2000
# 7/7 - 0s - loss: 1.0631 - mse: 1.0631 - val_loss: 4.7911 - val_mse: 4.7911 - 53ms/epoch - 8ms/step
# Epoch 1888/2000
# 7/7 - 0s - loss: 1.0823 - mse: 1.0823 - val_loss: 4.8421 - val_mse: 4.8421 - 52ms/epoch - 7ms/step
# Epoch 1889/2000
# 7/7 - 0s - loss: 1.0875 - mse: 1.0875 - val_loss: 4.7887 - val_mse: 4.7887 - 59ms/epoch - 8ms/step
# Epoch 1890/2000
# 7/7 - 0s - loss: 1.1834 - mse: 1.1834 - val_loss: 4.7910 - val_mse: 4.7910 - 53ms/epoch - 8ms/step
# Epoch 1891/2000
# 7/7 - 0s - loss: 1.1357 - mse: 1.1357 - val_loss: 4.7791 - val_mse: 4.7791 - 55ms/epoch - 8ms/step
# Epoch 1892/2000
# 7/7 - 0s - loss: 1.0952 - mse: 1.0952 - val_loss: 4.8434 - val_mse: 4.8434 - 57ms/epoch - 8ms/step
# Epoch 1893/2000
# 7/7 - 0s - loss: 1.1131 - mse: 1.1131 - val_loss: 4.7726 - val_mse: 4.7726 - 59ms/epoch - 8ms/step
# Epoch 1894/2000
# 7/7 - 0s - loss: 1.0563 - mse: 1.0563 - val_loss: 4.8169 - val_mse: 4.8169 - 71ms/epoch - 10ms/step
# Epoch 1895/2000
# 7/7 - 0s - loss: 1.0704 - mse: 1.0704 - val_loss: 4.8444 - val_mse: 4.8444 - 63ms/epoch - 9ms/step
# Epoch 1896/2000
# 7/7 - 0s - loss: 1.0569 - mse: 1.0569 - val_loss: 4.8462 - val_mse: 4.8462 - 94ms/epoch - 13ms/step
# Epoch 1897/2000
# 7/7 - 0s - loss: 1.0460 - mse: 1.0460 - val_loss: 4.8002 - val_mse: 4.8002 - 63ms/epoch - 9ms/step
# Epoch 1898/2000
# 7/7 - 0s - loss: 1.0477 - mse: 1.0477 - val_loss: 5.0110 - val_mse: 5.0110 - 64ms/epoch - 9ms/step
# Epoch 1899/2000
# 7/7 - 0s - loss: 1.2036 - mse: 1.2036 - val_loss: 4.7793 - val_mse: 4.7793 - 68ms/epoch - 10ms/step
# Epoch 1900/2000
# 7/7 - 0s - loss: 1.0715 - mse: 1.0715 - val_loss: 4.8909 - val_mse: 4.8909 - 65ms/epoch - 9ms/step
# Epoch 1901/2000
# 7/7 - 0s - loss: 1.0508 - mse: 1.0508 - val_loss: 4.7295 - val_mse: 4.7295 - 62ms/epoch - 9ms/step
# Epoch 1902/2000
# 7/7 - 0s - loss: 1.0663 - mse: 1.0663 - val_loss: 4.8075 - val_mse: 4.8075 - 60ms/epoch - 9ms/step
# Epoch 1903/2000
# 7/7 - 0s - loss: 1.0837 - mse: 1.0837 - val_loss: 4.7406 - val_mse: 4.7406 - 61ms/epoch - 9ms/step
# Epoch 1904/2000
# 7/7 - 0s - loss: 1.1105 - mse: 1.1105 - val_loss: 4.7966 - val_mse: 4.7966 - 72ms/epoch - 10ms/step
# Epoch 1905/2000
# 7/7 - 0s - loss: 1.1246 - mse: 1.1246 - val_loss: 4.7902 - val_mse: 4.7902 - 58ms/epoch - 8ms/step
# Epoch 1906/2000
# 7/7 - 0s - loss: 1.1591 - mse: 1.1591 - val_loss: 4.7814 - val_mse: 4.7814 - 60ms/epoch - 9ms/step
# Epoch 1907/2000
# 7/7 - 0s - loss: 1.1672 - mse: 1.1672 - val_loss: 4.8785 - val_mse: 4.8785 - 63ms/epoch - 9ms/step
# Epoch 1908/2000
# 7/7 - 0s - loss: 1.3318 - mse: 1.3318 - val_loss: 4.8108 - val_mse: 4.8108 - 60ms/epoch - 9ms/step
# Epoch 1909/2000
# 7/7 - 0s - loss: 1.2809 - mse: 1.2809 - val_loss: 4.8703 - val_mse: 4.8703 - 66ms/epoch - 9ms/step
# Epoch 1910/2000
# 7/7 - 0s - loss: 1.1432 - mse: 1.1432 - val_loss: 4.8299 - val_mse: 4.8299 - 63ms/epoch - 9ms/step
# Epoch 1911/2000
# 7/7 - 0s - loss: 1.2750 - mse: 1.2750 - val_loss: 4.7478 - val_mse: 4.7478 - 63ms/epoch - 9ms/step
# Epoch 1912/2000
# 7/7 - 0s - loss: 1.1367 - mse: 1.1367 - val_loss: 4.8276 - val_mse: 4.8276 - 60ms/epoch - 9ms/step
# Epoch 1913/2000
# 7/7 - 0s - loss: 1.1166 - mse: 1.1166 - val_loss: 4.7249 - val_mse: 4.7249 - 85ms/epoch - 12ms/step
# Epoch 1914/2000
# 7/7 - 0s - loss: 1.1375 - mse: 1.1375 - val_loss: 4.8371 - val_mse: 4.8371 - 61ms/epoch - 9ms/step
# Epoch 1915/2000
# 7/7 - 0s - loss: 1.0897 - mse: 1.0897 - val_loss: 4.8503 - val_mse: 4.8503 - 67ms/epoch - 10ms/step
# Epoch 1916/2000
# 7/7 - 0s - loss: 1.0647 - mse: 1.0647 - val_loss: 4.7945 - val_mse: 4.7945 - 60ms/epoch - 9ms/step
# Epoch 1917/2000
# 7/7 - 0s - loss: 1.0649 - mse: 1.0649 - val_loss: 4.8470 - val_mse: 4.8470 - 61ms/epoch - 9ms/step
# Epoch 1918/2000
# 7/7 - 0s - loss: 1.0439 - mse: 1.0439 - val_loss: 4.8231 - val_mse: 4.8231 - 58ms/epoch - 8ms/step
# Epoch 1919/2000
# 7/7 - 0s - loss: 1.0532 - mse: 1.0532 - val_loss: 4.8586 - val_mse: 4.8586 - 60ms/epoch - 9ms/step
# Epoch 1920/2000
# 7/7 - 0s - loss: 1.1043 - mse: 1.1043 - val_loss: 4.7773 - val_mse: 4.7773 - 62ms/epoch - 9ms/step
# Epoch 1921/2000
# 7/7 - 0s - loss: 1.1534 - mse: 1.1534 - val_loss: 4.9406 - val_mse: 4.9406 - 73ms/epoch - 10ms/step
# Epoch 1922/2000
# 7/7 - 0s - loss: 1.0845 - mse: 1.0845 - val_loss: 4.7768 - val_mse: 4.7768 - 60ms/epoch - 9ms/step
# Epoch 1923/2000
# 7/7 - 0s - loss: 1.1334 - mse: 1.1334 - val_loss: 4.8355 - val_mse: 4.8355 - 63ms/epoch - 9ms/step
# Epoch 1924/2000
# 7/7 - 0s - loss: 1.1909 - mse: 1.1909 - val_loss: 4.7435 - val_mse: 4.7435 - 59ms/epoch - 8ms/step
# Epoch 1925/2000
# 7/7 - 0s - loss: 1.0408 - mse: 1.0408 - val_loss: 5.0759 - val_mse: 5.0759 - 62ms/epoch - 9ms/step
# Epoch 1926/2000
# 7/7 - 0s - loss: 1.1495 - mse: 1.1495 - val_loss: 4.7637 - val_mse: 4.7637 - 59ms/epoch - 8ms/step
# Epoch 1927/2000
# 7/7 - 0s - loss: 1.0764 - mse: 1.0764 - val_loss: 5.1282 - val_mse: 5.1282 - 99ms/epoch - 14ms/step
# Epoch 1928/2000
# 7/7 - 0s - loss: 1.1238 - mse: 1.1238 - val_loss: 4.7905 - val_mse: 4.7905 - 55ms/epoch - 8ms/step
# Epoch 1929/2000
# 7/7 - 0s - loss: 1.1520 - mse: 1.1520 - val_loss: 4.8940 - val_mse: 4.8940 - 61ms/epoch - 9ms/step
# Epoch 1930/2000
# 7/7 - 0s - loss: 1.1782 - mse: 1.1782 - val_loss: 4.7831 - val_mse: 4.7831 - 61ms/epoch - 9ms/step
# Epoch 1931/2000
# 7/7 - 0s - loss: 1.1449 - mse: 1.1449 - val_loss: 5.1428 - val_mse: 5.1428 - 56ms/epoch - 8ms/step
# Epoch 1932/2000
# 7/7 - 0s - loss: 1.1774 - mse: 1.1774 - val_loss: 4.7594 - val_mse: 4.7594 - 62ms/epoch - 9ms/step
# Epoch 1933/2000
# 7/7 - 0s - loss: 1.0168 - mse: 1.0168 - val_loss: 4.9924 - val_mse: 4.9924 - 54ms/epoch - 8ms/step
# Epoch 1934/2000
# 7/7 - 0s - loss: 1.0951 - mse: 1.0951 - val_loss: 4.7879 - val_mse: 4.7879 - 56ms/epoch - 8ms/step
# Epoch 1935/2000
# 7/7 - 0s - loss: 1.0954 - mse: 1.0954 - val_loss: 4.9833 - val_mse: 4.9833 - 58ms/epoch - 8ms/step
# Epoch 1936/2000
# 7/7 - 0s - loss: 1.1190 - mse: 1.1190 - val_loss: 4.8064 - val_mse: 4.8064 - 58ms/epoch - 8ms/step
# Epoch 1937/2000
# 7/7 - 0s - loss: 1.2826 - mse: 1.2826 - val_loss: 4.8302 - val_mse: 4.8302 - 66ms/epoch - 9ms/step
# Epoch 1938/2000
# 7/7 - 0s - loss: 1.2090 - mse: 1.2090 - val_loss: 4.7990 - val_mse: 4.7990 - 57ms/epoch - 8ms/step
# Epoch 1939/2000
# 7/7 - 0s - loss: 1.2006 - mse: 1.2006 - val_loss: 4.8465 - val_mse: 4.8465 - 57ms/epoch - 8ms/step
# Epoch 1940/2000
# 7/7 - 0s - loss: 1.0985 - mse: 1.0985 - val_loss: 4.7624 - val_mse: 4.7624 - 58ms/epoch - 8ms/step
# Epoch 1941/2000
# 7/7 - 0s - loss: 1.0366 - mse: 1.0366 - val_loss: 4.8294 - val_mse: 4.8294 - 56ms/epoch - 8ms/step
# Epoch 1942/2000
# 7/7 - 0s - loss: 1.0617 - mse: 1.0617 - val_loss: 4.7485 - val_mse: 4.7485 - 64ms/epoch - 9ms/step
# Epoch 1943/2000
# 7/7 - 0s - loss: 1.0736 - mse: 1.0736 - val_loss: 4.9485 - val_mse: 4.9485 - 77ms/epoch - 11ms/step
# Epoch 1944/2000
# 7/7 - 0s - loss: 1.0758 - mse: 1.0758 - val_loss: 4.7620 - val_mse: 4.7620 - 66ms/epoch - 9ms/step
# Epoch 1945/2000
# 7/7 - 0s - loss: 1.1992 - mse: 1.1992 - val_loss: 4.8528 - val_mse: 4.8528 - 57ms/epoch - 8ms/step
# Epoch 1946/2000
# 7/7 - 0s - loss: 1.3701 - mse: 1.3701 - val_loss: 4.8472 - val_mse: 4.8472 - 57ms/epoch - 8ms/step
# Epoch 1947/2000
# 7/7 - 0s - loss: 1.5206 - mse: 1.5206 - val_loss: 4.8139 - val_mse: 4.8139 - 61ms/epoch - 9ms/step
# Epoch 1948/2000
# 7/7 - 0s - loss: 1.0423 - mse: 1.0423 - val_loss: 5.1780 - val_mse: 5.1780 - 55ms/epoch - 8ms/step
# Epoch 1949/2000
# 7/7 - 0s - loss: 1.0629 - mse: 1.0629 - val_loss: 4.7738 - val_mse: 4.7738 - 54ms/epoch - 8ms/step
# Epoch 1950/2000
# 7/7 - 0s - loss: 1.0830 - mse: 1.0830 - val_loss: 4.9325 - val_mse: 4.9325 - 54ms/epoch - 8ms/step
# Epoch 1951/2000
# 7/7 - 0s - loss: 1.0632 - mse: 1.0632 - val_loss: 4.7840 - val_mse: 4.7840 - 54ms/epoch - 8ms/step
# Epoch 1952/2000
# 7/7 - 0s - loss: 1.1905 - mse: 1.1905 - val_loss: 4.9081 - val_mse: 4.9081 - 61ms/epoch - 9ms/step
# Epoch 1953/2000
# 7/7 - 0s - loss: 1.3284 - mse: 1.3284 - val_loss: 4.8486 - val_mse: 4.8486 - 67ms/epoch - 10ms/step
# Epoch 1954/2000
# 7/7 - 0s - loss: 1.2716 - mse: 1.2716 - val_loss: 4.8536 - val_mse: 4.8536 - 60ms/epoch - 9ms/step
# Epoch 1955/2000
# 7/7 - 0s - loss: 1.1553 - mse: 1.1553 - val_loss: 4.7171 - val_mse: 4.7171 - 61ms/epoch - 9ms/step
# Epoch 1956/2000
# 7/7 - 0s - loss: 1.1129 - mse: 1.1129 - val_loss: 4.7749 - val_mse: 4.7749 - 64ms/epoch - 9ms/step
# Epoch 1957/2000
# 7/7 - 0s - loss: 1.1641 - mse: 1.1641 - val_loss: 4.7283 - val_mse: 4.7283 - 64ms/epoch - 9ms/step
# Epoch 1958/2000
# 7/7 - 0s - loss: 1.0732 - mse: 1.0732 - val_loss: 4.7656 - val_mse: 4.7656 - 103ms/epoch - 15ms/step
# Epoch 1959/2000
# 7/7 - 0s - loss: 1.1070 - mse: 1.1070 - val_loss: 4.7649 - val_mse: 4.7649 - 62ms/epoch - 9ms/step
# Epoch 1960/2000
# 7/7 - 0s - loss: 1.1576 - mse: 1.1576 - val_loss: 4.7704 - val_mse: 4.7704 - 64ms/epoch - 9ms/step
# Epoch 1961/2000
# 7/7 - 0s - loss: 1.0864 - mse: 1.0864 - val_loss: 4.8715 - val_mse: 4.8715 - 61ms/epoch - 9ms/step
# Epoch 1962/2000
# 7/7 - 0s - loss: 1.1414 - mse: 1.1414 - val_loss: 4.7806 - val_mse: 4.7806 - 61ms/epoch - 9ms/step
# Epoch 1963/2000
# 7/7 - 0s - loss: 1.2022 - mse: 1.2022 - val_loss: 4.8010 - val_mse: 4.8010 - 61ms/epoch - 9ms/step
# Epoch 1964/2000
# 7/7 - 0s - loss: 1.0314 - mse: 1.0314 - val_loss: 4.8190 - val_mse: 4.8190 - 64ms/epoch - 9ms/step
# Epoch 1965/2000
# 7/7 - 0s - loss: 1.1093 - mse: 1.1093 - val_loss: 4.7964 - val_mse: 4.7964 - 60ms/epoch - 9ms/step
# Epoch 1966/2000
# 7/7 - 0s - loss: 1.1808 - mse: 1.1808 - val_loss: 4.7650 - val_mse: 4.7650 - 58ms/epoch - 8ms/step
# Epoch 1967/2000
# 7/7 - 0s - loss: 1.0731 - mse: 1.0731 - val_loss: 4.9305 - val_mse: 4.9305 - 59ms/epoch - 8ms/step
# Epoch 1968/2000
# 7/7 - 0s - loss: 1.0397 - mse: 1.0397 - val_loss: 4.7456 - val_mse: 4.7456 - 60ms/epoch - 9ms/step
# Epoch 1969/2000
# 7/7 - 0s - loss: 1.1216 - mse: 1.1216 - val_loss: 4.7458 - val_mse: 4.7458 - 66ms/epoch - 9ms/step
# Epoch 1970/2000
# 7/7 - 0s - loss: 1.3363 - mse: 1.3363 - val_loss: 4.7678 - val_mse: 4.7678 - 58ms/epoch - 8ms/step
# Epoch 1971/2000
# 7/7 - 0s - loss: 1.1176 - mse: 1.1176 - val_loss: 5.1601 - val_mse: 5.1601 - 61ms/epoch - 9ms/step
# Epoch 1972/2000
# 7/7 - 0s - loss: 1.4220 - mse: 1.4220 - val_loss: 4.7599 - val_mse: 4.7599 - 57ms/epoch - 8ms/step
# Epoch 1973/2000
# 7/7 - 0s - loss: 1.2140 - mse: 1.2140 - val_loss: 4.9199 - val_mse: 4.9199 - 63ms/epoch - 9ms/step
# Epoch 1974/2000
# 7/7 - 0s - loss: 1.0777 - mse: 1.0777 - val_loss: 4.7466 - val_mse: 4.7466 - 97ms/epoch - 14ms/step
# Epoch 1975/2000
# 7/7 - 0s - loss: 1.0601 - mse: 1.0601 - val_loss: 4.8207 - val_mse: 4.8207 - 63ms/epoch - 9ms/step
# Epoch 1976/2000
# 7/7 - 0s - loss: 1.0800 - mse: 1.0800 - val_loss: 4.8372 - val_mse: 4.8372 - 58ms/epoch - 8ms/step
# Epoch 1977/2000
# 7/7 - 0s - loss: 1.1022 - mse: 1.1022 - val_loss: 4.7876 - val_mse: 4.7876 - 61ms/epoch - 9ms/step
# Epoch 1978/2000
# 7/7 - 0s - loss: 1.1363 - mse: 1.1363 - val_loss: 4.7925 - val_mse: 4.7925 - 67ms/epoch - 10ms/step
# Epoch 1979/2000
# 7/7 - 0s - loss: 1.0082 - mse: 1.0082 - val_loss: 4.9765 - val_mse: 4.9765 - 59ms/epoch - 8ms/step
# Epoch 1980/2000
# 7/7 - 0s - loss: 1.1081 - mse: 1.1081 - val_loss: 4.7844 - val_mse: 4.7844 - 57ms/epoch - 8ms/step
# Epoch 1981/2000
# 7/7 - 0s - loss: 1.0525 - mse: 1.0525 - val_loss: 4.7865 - val_mse: 4.7865 - 59ms/epoch - 8ms/step
# Epoch 1982/2000
# 7/7 - 0s - loss: 1.0770 - mse: 1.0770 - val_loss: 4.8681 - val_mse: 4.8681 - 58ms/epoch - 8ms/step
# Epoch 1983/2000
# 7/7 - 0s - loss: 1.0356 - mse: 1.0356 - val_loss: 4.8601 - val_mse: 4.8601 - 65ms/epoch - 9ms/step
# Epoch 1984/2000
# 7/7 - 0s - loss: 1.0465 - mse: 1.0465 - val_loss: 4.8270 - val_mse: 4.8270 - 56ms/epoch - 8ms/step
# Epoch 1985/2000
# 7/7 - 0s - loss: 1.1038 - mse: 1.1038 - val_loss: 4.7804 - val_mse: 4.7804 - 56ms/epoch - 8ms/step
# Epoch 1986/2000
# 7/7 - 0s - loss: 1.1152 - mse: 1.1152 - val_loss: 4.9001 - val_mse: 4.9001 - 58ms/epoch - 8ms/step
# Epoch 1987/2000
# 7/7 - 0s - loss: 1.1316 - mse: 1.1316 - val_loss: 4.7734 - val_mse: 4.7734 - 58ms/epoch - 8ms/step
# Epoch 1988/2000
# 7/7 - 0s - loss: 1.1448 - mse: 1.1448 - val_loss: 4.7715 - val_mse: 4.7715 - 62ms/epoch - 9ms/step
# Epoch 1989/2000
# 7/7 - 0s - loss: 1.4369 - mse: 1.4369 - val_loss: 4.7509 - val_mse: 4.7509 - 56ms/epoch - 8ms/step
# Epoch 1990/2000
# 7/7 - 0s - loss: 1.5682 - mse: 1.5682 - val_loss: 4.7822 - val_mse: 4.7822 - 86ms/epoch - 12ms/step
# Epoch 1991/2000
# 7/7 - 0s - loss: 1.6498 - mse: 1.6498 - val_loss: 5.1164 - val_mse: 5.1164 - 59ms/epoch - 8ms/step
# Epoch 1992/2000
# 7/7 - 0s - loss: 1.5756 - mse: 1.5756 - val_loss: 5.1944 - val_mse: 5.1944 - 55ms/epoch - 8ms/step
# Epoch 1993/2000
# 7/7 - 0s - loss: 1.2197 - mse: 1.2197 - val_loss: 4.7329 - val_mse: 4.7329 - 63ms/epoch - 9ms/step
# Epoch 1994/2000
# 7/7 - 0s - loss: 1.1061 - mse: 1.1061 - val_loss: 4.7916 - val_mse: 4.7916 - 60ms/epoch - 9ms/step
# Epoch 1995/2000
# 7/7 - 0s - loss: 1.0391 - mse: 1.0391 - val_loss: 4.7332 - val_mse: 4.7332 - 53ms/epoch - 8ms/step
# Epoch 1996/2000
# 7/7 - 0s - loss: 1.0865 - mse: 1.0865 - val_loss: 4.8416 - val_mse: 4.8416 - 55ms/epoch - 8ms/step
# Epoch 1997/2000
# 7/7 - 0s - loss: 1.0816 - mse: 1.0816 - val_loss: 4.8018 - val_mse: 4.8018 - 52ms/epoch - 7ms/step
# Epoch 1998/2000
# 7/7 - 0s - loss: 1.1027 - mse: 1.1027 - val_loss: 4.8147 - val_mse: 4.8147 - 58ms/epoch - 8ms/step
# Epoch 1999/2000
# 7/7 - 0s - loss: 1.1949 - mse: 1.1949 - val_loss: 4.8101 - val_mse: 4.8101 - 68ms/epoch - 10ms/step
# Epoch 2000/2000
# 7/7 - 0s - loss: 1.0476 - mse: 1.0476 - val_loss: 4.9101 - val_mse: 4.9101 - 61ms/epoch - 9ms/step

# %%
fig, ax = plt.subplots(figsize=(25, 4))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Accuracy')
ax.set_xlabel('Accuracy')
ax.set_ylabel('Epoch')

plt.legend(['Train', 'Test'])
plt.show()

# %%
y_pred = model.predict(X_test, verbose = 0)

print("R Squared Error    :",round(r2_score(y_test, y_pred), 2))
print("Mean Squared Error :",round(mean_squared_error(y_test, y_pred), 2))
print("Mean Absolute Error:",round(mean_absolute_error(y_test, y_pred), 2))
# Out:
# R Squared Error    : 0.85
# Mean Squared Error : 4.91
# Mean Absolute Error: 1.13

# %%
train_predictions = model.predict(X_test, verbose=0).flatten()

train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_test})
train_results['Diff'] = abs(train_results['Actuals'] - train_results['Train Predictions'])
print(train_results.head(5))
print((train_results['Diff'].mean()), '/', (train_results['Diff'].sum()))
# Out:
#      Train Predictions  Actuals       Diff
# 6             6.236134     6.75   0.513866
# 30            3.950428     3.10   0.850428
# 167           0.563788     0.42   0.143788
# 86           21.617908    35.00  13.382092
# 218           5.172575     6.45   1.277425
# 1.1299052869876225 / 67.79431721925735

# %% [markdown]
# # 6. Supervised Learning

# %% [markdown]
# ### 6.1. Stacking Algoritms

# %%
adaboost = AdaBoostRegressor(n_estimators = 100, random_state = 42)
bagging = BaggingRegressor(n_jobs = -1)
extraTrees = ExtraTreesRegressor(max_depth = 100, n_jobs = -1, random_state = 42)
gradient = GradientBoostingRegressor(max_depth = 100, n_estimators = 100, learning_rate = .01,  random_state = 0)
randomForest = RandomForestRegressor(max_depth = 100, random_state = 42, n_jobs = -1)
histGradient = HistGradientBoostingRegressor()
XGB = XGBRegressor(n_jobs = -1)
knn = KNeighborsRegressor(n_jobs = -1)
decisionTree = DecisionTreeRegressor( max_depth = 100, random_state = 42)

model = StackingRegressor([
    ('extraTrees', extraTrees),
    ('knn', knn),
    ('histGradient', histGradient),
    ('adaboost', adaboost),
    ('bagging', bagging),
    ('randomforest', randomForest),
    ('XGB', XGB),
    ('decisionTree', decisionTree),
    # ('gradient', gradient),
], n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('extraTrees',
#                                ExtraTreesRegressor(max_depth=100, n_jobs=-1,
#                                                    random_state=42)),
#                               ('knn', KNeighborsRegressor(n_jobs=-1)),
#                               ('histGradient', HistGradientBoostingRegressor()),
#                               ('adaboost',
#                                AdaBoostRegressor(n_estimators=100,
#                                                  random_state=42)),
#                               ('bagging', BaggingRegressor(n_jobs=-1)),
#                               ('randomforest',
#                                RandomForestRegressor(max_depth=100...
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...)),
#                               ('decisionTree',
#                                DecisionTreeRegressor(max_depth=100,
#                                                      random_state=42))],
#                   n_jobs=-1)

# %%
print("Train Score        :",round((model.score(X_train, y_train)*100), 2),'%')
print("Test Score         :",round((model.score(X_test, y_test)*100), 2),'%')

y_pred = model.predict(X_test)

print("R Squared Error    :",round(r2_score(y_test, y_pred), 2))
print("Mean Squared Error :",round(mean_squared_error(y_test, y_pred), 2))
print("Mean Absolute Error:",round(mean_absolute_error(y_test, y_pred), 2))
# Out:
# Train Score        : 99.76 %
# Test Score         : 69.34 %
# R Squared Error    : 0.69
# Mean Squared Error : 10.07
# Mean Absolute Error: 1.16

# %%
train_predictions = (model.predict(X_test)).flatten()

train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_test})
train_results['Diff'] = abs(train_results['Actuals'] - train_results['Train Predictions'])
print(train_results.head(5))
print((train_results['Diff'].mean()), '/', (train_results['Diff'].sum()))
# Out:
#      Train Predictions  Actuals       Diff
# 6             6.580410     6.75   0.169590
# 30            2.979934     3.10   0.120066
# 167           0.352228     0.42   0.067772
# 86           13.219767    35.00  21.780233
# 218           5.994528     6.45   0.455472
# 1.1569082360734069 / 69.41449416440442

# %% [markdown]
# ### 6.2. Pycarets

# %%
s = RegressionExperiment()
s.setup(data, target = 'price', session_id = 123)

# %%
best = s.compare_models()
print(best)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              20:24:29
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library

# %%
s.evaluate_model(best)

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8212e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8212e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8212e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8212e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8212e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8212e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8212e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8212e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8212e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8212e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8212e_row0_col1" class="data row0 col1" >284.1660</td>
#       <td id="T_8212e_row0_col2" class="data row0 col2" >292688.2905</td>
#       <td id="T_8212e_row0_col3" class="data row0 col3" >541.0067</td>
#       <td id="T_8212e_row0_col4" class="data row0 col4" >0.9817</td>
#       <td id="T_8212e_row0_col5" class="data row0 col5" >0.1070</td>
#       <td id="T_8212e_row0_col6" class="data row0 col6" >0.0831</td>
#     </tr>
#   </tbody>
# </table>
#        carat  cut  color  clarity      depth  table     x     y     z  price  \
# 47295   0.30    1      2        3  63.400002   56.0  4.26  4.29  2.71    394
# 52309   0.31    2      0        2  62.299999   56.0  4.32  4.35  2.70    548
# 3825    0.73    2      1        4  61.400002   55.0  5.80  5.82  3.57   3471
# 45257   0.51    2      2        5  61.599998   57.0  5.14  5.15  3.17   1661
# 8585    1.01    4      5        5  61.299999   56.0  6.53  6.45  3.98   4438
# ...      ...  ...    ...      ...        ...    ...   ...   ...   ...    ...
# 13768   1.35    4      6        2  61.099998   61.0  7.10  7.13  4.35   5613
# 46340   0.50    1      0        5  63.700001   56.0  5.09  5.05  3.23   1758
# 47227   0.60    2      0        2  62.299999   57.0  5.42  5.37  3.36   1840
# 22661   1.26    2      2        5  61.500000   56.0  6.97  7.01  4.30  10709
# 13942   1.30    3      4        2  62.900002   60.0  6.95  6.88  4.35   5671
#
#        prediction_label
# 47295        486.420649
# 52309        682.183706
# 3825        3510.702591
# 45257       1652.668495
# 8585        4476.470241
# ...                 ...
# 13768       5533.372564
# 46340       1613.025171
# 47227       1804.547772
# 22661       9923.811775
# 13942       6593.265576
#
# [16176 rows x 11 columns]
