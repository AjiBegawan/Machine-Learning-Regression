# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import plotly.express as px
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD, Adam,  RMSprop, Nadam
from tensorflow.keras.layers import Dense, Flatten,  LSTM, GRU, LeakyReLU, Dropout, Bidirectional

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import  MinMaxScaler, PowerTransformer, RobustScaler

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import (
    AdaBoostRegressor,
    BaggingRegressor,
    ExtraTreesRegressor,
    GradientBoostingRegressor, 
    HistGradientBoostingRegressor,
    RandomForestRegressor,
    StackingRegressor,
)
from xgboost import XGBRegressor

from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

from pycaret.regression import RegressionExperiment

from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# # 2. Load Data

# %%
data = pd.read_csv('../Dataset/advertising.csv')
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # 3. Initial Analysis

# %% [markdown]
# ### 3.1. Metadata

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float32
#  1   Radio      200 non-null    float32
#  2   Newspaper  200 non-null    float32
#  3   Sales      200 non-null    float32
# dtypes: float32(4)
# memory usage: 3.2 KB

# %%
data.describe().transpose()
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   15.1305   5.283892  1.6  11.000   16.00   19.050   27.0

# %%
print(f'Number of null data       : {data.isnull().sum().sum()}')
print(f'Number of duplicates data : {data.duplicated().sum()}')
# Out:
# Number of null data       : 0
# Number of duplicates data : 0

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ### 3.2. Columns Processing

# %%
numerical_columns = [column_name for column_name in data.columns if data[column_name].dtype != 'object']
categorical_columns = [column_name for column_name in data.columns if data[column_name].dtype == 'object']
print(f'Numerical Columns   : {numerical_columns}')
print(f'Categorical Columns : {categorical_columns}')
# Out:
# Numerical Columns   : ['TV', 'Radio', 'Newspaper', 'Sales']
# Categorical Columns : []

# %%
def downcasting_dtypes(data):
    fcols = data.select_dtypes('float').columns
    icols = data.select_dtypes('integer').columns

    data[fcols] = data[fcols].apply(pd.to_numeric, downcast='float')
    data[icols] = data[icols].apply(pd.to_numeric, downcast='integer')

downcasting_dtypes(data)

# %%
def change_columns_to_numerical(data):
    LE = LabelEncoder()
    columns = ['Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years']
    for column in columns:
        data[column] = LE.fit_transform(data[column].astype(str))
        data[column] = data[column].astype('int8')
        print(f'{column} : {LE.classes_}') 
    return data

data = change_columns_to_numerical(data)

# %% [markdown]
# ### 3.3. EDA

# %%
num_cols = 2
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.regplot(data = data, x = data['Sales'], y = data[column], ax=axes[row, col]) \
        .set_title(column)
    

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
num_cols = 2
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data = data, x = column, ax=axes[row, col], bw_adjust=.1) \
        .set_title("Distribusi nilai kolom " + column)
    

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# num_cols = 3
# num_rows = math.ceil(len(numerical_columns) / num_cols)

# fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10))

# for i, column in enumerate(numerical_columns):
#     row = i // num_cols
#     col = i % num_cols
#     sns.kdeplot(data=data, x=column, hue="Region", 
#                 fill=True, alpha=.2, palette="YlOrRd", 
#                 common_norm=False, ax=axes[row, col],
#                 warn_singular=False)\
#         .set_title(column)

# for i in range(len(numerical_columns), num_rows * num_cols):
#     row = i // num_cols
#     col = i % num_cols
#     axes[row, col].axis('off')

# plt.tight_layout()
# plt.show()

# %%
sns.pairplot(data, diag_kind="kde")
plt.show()

# %%
# plt.subplots(figsize = (20,4))
# ax = sns.countplot(data = data, x = 'cut', palette='YlOrBr')
# ax.bar_label(ax.containers[0])

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))
for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.boxplot(x=data[column], ax=axes[row, col], palette="Oranges").set_title(column)
    
for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# Q1 = data['text_len'].quantile(0.25)
# Q3 = data['text_len'].quantile(1.)

# print(Q1)
# print(Q3)

# data = data[(data['text_len'] > Q1) & (data['text_len'] < Q3)]

# fig, axes = plt.subplots(figsize=(25, 2))
# sns.boxplot(x = data['text_len'], palette="Oranges")

# sns.stripplot(x=data['text_len'], data=data,
#               size=4, color=".3", linewidth=0, palette="crest", hue=data['text_len'])

# %% [markdown]
# ### 3.4. Data Correlation

# %%
corr_data = data.corr().round(2)

mask = np.zeros_like(corr_data)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(25, 10))
# sns.heatmap(corr_data, annot=True, mask=mask, cmap='RdBu')
sns.heatmap(corr_data, annot=True, cmap='RdBu')
plt.title("Correlation Matrix", size=20)
plt.show()

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ### 4.1. Features Selections

# %%
### Pearson Correlation
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    print(str(len(cor_feature)), 'selected features')
    print(cor_feature)
    return cor_feature

### Chi-Squared
def chi_squared_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_feats)
    chi_selector.fit(X_norm, Y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    print(str(len(chi_feature)), 'selected features')
    print(chi_feature)
    return chi_feature

### Recursive Feature Elimination
def recursive_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
    rfe_selector.fit(X_norm, Y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    print(str(len(rfe_feature)), 'selected features')
    print(rfe_feature)
    return rfe_feature

### Lasso: SelectFromModel
def lasso_elimination(X, Y, num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
    embeded_lr_selector.fit(X_norm, Y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    print(str(len(embeded_lr_feature)), 'selected features')
    print(embeded_lr_feature)
    return embeded_lr_feature

### LightGBM: SelectFromModel
def LGBMC_elimination(X, Y, num_feats):
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
                reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

    embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
    embeded_lgb_selector.fit(X, Y)
    embeded_lgb_support = embeded_lgb_selector.get_support()
    embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    print(str(len(embeded_lgb_feature)), 'selected features')
    print(embeded_lgb_feature)
    return embeded_lgb_feature

### Tree-based: SelectFromModel
def RFC_elimination (X, Y, num_feats):
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
    embeded_rf_selector.fit(X, Y)

    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    print(str(len(embeded_rf_feature)), 'selected features')
    print(embeded_rf_feature)
    return embeded_rf_feature

# %%
X = data.drop(columns=['Potability'])
Y = data['Potability']

num_feats = 10

selected_feature = cor_selector(X, Y,num_feats)
# selected_feature = chi_squared_elimination(X, Y,num_feats)
# selected_feature = recursive_elimination(X, Y,num_feats)
# selected_feature = lasso_elimination(X, Y, num_feats)
# selected_feature = LGBMC_elimination(X, Y, num_feats)
# selected_feature = RFC_elimination(X, Y, num_feats)

X = data[selected_feature]
Y = data['Credit_Score']


print(Counter(Y))
undersample = RandomUnderSampler()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = to_categorical(Y)

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# 10 selected features
# ['Monthly_Balance', 'Num_Bank_Accounts', 'Credit_History_Age', 'Num_Credit_Card', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Interest_Rate', 'Num_Credit_Inquiries', 'Credit_Mix']
# Counter({0: 53174, 2: 28998, 1: 17828})
# Counter({0: 17828, 1: 17828, 2: 17828})
# (37545, 10)
# (10590, 10)
# (5349, 10)

# %% [markdown]
# ### 4.2. Data Splitting

# %%
X = data.drop(columns=['Sales'])
Y = data['Sales']

# scaler = MinMaxScaler(feature_range=(0,1))
# scaler = RobustScaler()
# X = scaler.fit_transform(X)
# scaler = PowerTransformer(method='yeo-johnson', standardize=True)
# X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (140, 3) (140,)
# (40, 3) (40,)
# (20, 3) (20,)

# %% [markdown]
# # 5. Neural Network Algoritms

# %%
def DNN_Model():
    model = Sequential()
    model.add(Dense(1024, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01), input_shape=(X_train.shape[1],)))
    # model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))
    # model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))
    # model.add(Dropout(0.5))
    model.add(Dense(1))
    
    return model

def LSTM_Model():
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    # model.add(LSTM(64))
    model.add(Dense(32, activation='relu'))
    # model.add(Dropout(0.2))
    # model.add(Dropout(0.5))
    # model.add(Dense(16, activation='relu'))
    model.add(Dense(1))
    return model

def GRU_Model():
    model = Sequential()
    model.add((GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True, input_shape = (X_train.shape[1],1))))
    # model.add(GRU(64, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True))
    model.add((GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True)))
    # model.add(Dense(128, activation='relu'))
    # model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    return model

# model = DNN_Model()
# model = LSTM_Model()
model = GRU_Model()

model.summary()

# opt = SGD(learning_rate=0.01, momentum=0.9)
opt = Adam(learning_rate = 0.000_01)

model.compile(loss='mse', optimizer=opt, metrics=['mse'])
# model.compile(loss='mae', optimizer = opt, metrics=['mae'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 3, 256)            198912
#
#  gru_1 (GRU)                 (None, 256)               394752
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 593,921
# Trainable params: 593,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epoch = 1000
batch_size = 32

history = model.fit(X_train, y_train, verbose=1,
                    batch_size = batch_size, epochs = num_epoch, 
                    validation_data = (X_val, y_val))
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.8954 - mse: 0.8954 - val_loss: 0.7776 - val_mse: 0.7776
# Epoch 2/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8963 - mse: 0.8963 - val_loss: 0.7780 - val_mse: 0.7780
# Epoch 3/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8945 - mse: 0.8945 - val_loss: 0.7824 - val_mse: 0.7824
# Epoch 4/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.9049 - mse: 0.9049 - val_loss: 0.7976 - val_mse: 0.7976
# Epoch 5/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8994 - mse: 0.8994 - val_loss: 0.7867 - val_mse: 0.7867
# Epoch 6/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8949 - mse: 0.8949 - val_loss: 0.7767 - val_mse: 0.7767
# Epoch 7/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9027 - mse: 0.9027 - val_loss: 0.7741 - val_mse: 0.7741
# Epoch 8/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 0.9040 - mse: 0.9040 - val_loss: 0.7799 - val_mse: 0.7799
# Epoch 9/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8961 - mse: 0.8961 - val_loss: 0.7759 - val_mse: 0.7759
# Epoch 10/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9002 - mse: 0.9002 - val_loss: 0.7708 - val_mse: 0.7708
# Epoch 11/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8942 - mse: 0.8942 - val_loss: 0.7765 - val_mse: 0.7765
# Epoch 12/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8965 - mse: 0.8965 - val_loss: 0.7783 - val_mse: 0.7783
# Epoch 13/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8957 - mse: 0.8957 - val_loss: 0.7854 - val_mse: 0.7854
# Epoch 14/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9010 - mse: 0.9010 - val_loss: 0.7773 - val_mse: 0.7773
# Epoch 15/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8962 - mse: 0.8962 - val_loss: 0.7791 - val_mse: 0.7791
# Epoch 16/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9013 - mse: 0.9013 - val_loss: 0.7805 - val_mse: 0.7805
# Epoch 17/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8922 - mse: 0.8922 - val_loss: 0.7880 - val_mse: 0.7880
# Epoch 18/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8987 - mse: 0.8987 - val_loss: 0.8105 - val_mse: 0.8105
# Epoch 19/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9017 - mse: 0.9017 - val_loss: 0.7903 - val_mse: 0.7903
# Epoch 20/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8935 - mse: 0.8935 - val_loss: 0.7848 - val_mse: 0.7848
# Epoch 21/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8954 - mse: 0.8954 - val_loss: 0.7816 - val_mse: 0.7816
# Epoch 22/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9004 - mse: 0.9004 - val_loss: 0.7738 - val_mse: 0.7738
# Epoch 23/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8988 - mse: 0.8988 - val_loss: 0.7758 - val_mse: 0.7758
# Epoch 24/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8970 - mse: 0.8970 - val_loss: 0.7772 - val_mse: 0.7772
# Epoch 25/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8963 - mse: 0.8963 - val_loss: 0.7700 - val_mse: 0.7700
# Epoch 26/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8928 - mse: 0.8928 - val_loss: 0.7710 - val_mse: 0.7710
# Epoch 27/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8958 - mse: 0.8958 - val_loss: 0.7753 - val_mse: 0.7753
# Epoch 28/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8936 - mse: 0.8936 - val_loss: 0.7668 - val_mse: 0.7668
# Epoch 29/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8919 - mse: 0.8919 - val_loss: 0.7706 - val_mse: 0.7706
# Epoch 30/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8928 - mse: 0.8928 - val_loss: 0.7781 - val_mse: 0.7781
# Epoch 31/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8940 - mse: 0.8940 - val_loss: 0.7772 - val_mse: 0.7772
# Epoch 32/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8927 - mse: 0.8927 - val_loss: 0.7778 - val_mse: 0.7778
# Epoch 33/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8919 - mse: 0.8919 - val_loss: 0.7803 - val_mse: 0.7803
# Epoch 34/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8916 - mse: 0.8916 - val_loss: 0.7837 - val_mse: 0.7837
# Epoch 35/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8947 - mse: 0.8947 - val_loss: 0.7910 - val_mse: 0.7910
# Epoch 36/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8945 - mse: 0.8945 - val_loss: 0.7810 - val_mse: 0.7810
# Epoch 37/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8931 - mse: 0.8931 - val_loss: 0.7671 - val_mse: 0.7671
# Epoch 38/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8977 - mse: 0.8977 - val_loss: 0.7577 - val_mse: 0.7577
# Epoch 39/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8958 - mse: 0.8958 - val_loss: 0.7544 - val_mse: 0.7544
# Epoch 40/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8928 - mse: 0.8928 - val_loss: 0.7511 - val_mse: 0.7511
# Epoch 41/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8919 - mse: 0.8919 - val_loss: 0.7535 - val_mse: 0.7535
# Epoch 42/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8923 - mse: 0.8923 - val_loss: 0.7682 - val_mse: 0.7682
# Epoch 43/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.8945 - mse: 0.8945 - val_loss: 0.7644 - val_mse: 0.7644
# Epoch 44/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8916 - mse: 0.8916 - val_loss: 0.7703 - val_mse: 0.7703
# Epoch 45/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8909 - mse: 0.8909 - val_loss: 0.7820 - val_mse: 0.7820
# Epoch 46/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9046 - mse: 0.9046 - val_loss: 0.7972 - val_mse: 0.7972
# Epoch 47/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8941 - mse: 0.8941 - val_loss: 0.7807 - val_mse: 0.7807
# Epoch 48/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8924 - mse: 0.8924 - val_loss: 0.7789 - val_mse: 0.7789
# Epoch 49/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8987 - mse: 0.8987 - val_loss: 0.7761 - val_mse: 0.7761
# Epoch 50/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8924 - mse: 0.8924 - val_loss: 0.7829 - val_mse: 0.7829
# Epoch 51/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8923 - mse: 0.8923 - val_loss: 0.7760 - val_mse: 0.7760
# Epoch 52/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8910 - mse: 0.8910 - val_loss: 0.7671 - val_mse: 0.7671
# Epoch 53/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8923 - mse: 0.8923 - val_loss: 0.7654 - val_mse: 0.7654
# Epoch 54/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8858 - mse: 0.8858 - val_loss: 0.7789 - val_mse: 0.7789
# Epoch 55/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8950 - mse: 0.8950 - val_loss: 0.7977 - val_mse: 0.7977
# Epoch 56/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9084 - mse: 0.9084 - val_loss: 0.7960 - val_mse: 0.7960
# Epoch 57/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8917 - mse: 0.8917 - val_loss: 0.7730 - val_mse: 0.7730
# Epoch 58/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9090 - mse: 0.9090 - val_loss: 0.7753 - val_mse: 0.7753
# Epoch 59/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8964 - mse: 0.8964 - val_loss: 0.7780 - val_mse: 0.7780
# Epoch 60/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8964 - mse: 0.8964 - val_loss: 0.7912 - val_mse: 0.7912
# Epoch 61/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8978 - mse: 0.8978 - val_loss: 0.7775 - val_mse: 0.7775
# Epoch 62/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8949 - mse: 0.8949 - val_loss: 0.7811 - val_mse: 0.7811
# Epoch 63/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8928 - mse: 0.8928 - val_loss: 0.7781 - val_mse: 0.7781
# Epoch 64/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8895 - mse: 0.8895 - val_loss: 0.7734 - val_mse: 0.7734
# Epoch 65/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8880 - mse: 0.8880 - val_loss: 0.7806 - val_mse: 0.7806
# Epoch 66/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8875 - mse: 0.8875 - val_loss: 0.7942 - val_mse: 0.7942
# Epoch 67/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8951 - mse: 0.8951 - val_loss: 0.7873 - val_mse: 0.7873
# Epoch 68/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8907 - mse: 0.8907 - val_loss: 0.7887 - val_mse: 0.7887
# Epoch 69/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8917 - mse: 0.8917 - val_loss: 0.7923 - val_mse: 0.7923
# Epoch 70/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8901 - mse: 0.8901 - val_loss: 0.7848 - val_mse: 0.7848
# Epoch 71/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8896 - mse: 0.8896 - val_loss: 0.7845 - val_mse: 0.7845
# Epoch 72/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8888 - mse: 0.8888 - val_loss: 0.7860 - val_mse: 0.7860
# Epoch 73/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8892 - mse: 0.8892 - val_loss: 0.7853 - val_mse: 0.7853
# Epoch 74/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8899 - mse: 0.8899 - val_loss: 0.7843 - val_mse: 0.7843
# Epoch 75/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8902 - mse: 0.8902 - val_loss: 0.7697 - val_mse: 0.7697
# Epoch 76/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8882 - mse: 0.8882 - val_loss: 0.7637 - val_mse: 0.7637
# Epoch 77/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8894 - mse: 0.8894 - val_loss: 0.7631 - val_mse: 0.7631
# Epoch 78/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8866 - mse: 0.8866 - val_loss: 0.7682 - val_mse: 0.7682
# Epoch 79/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8891 - mse: 0.8891 - val_loss: 0.7714 - val_mse: 0.7714
# Epoch 80/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8887 - mse: 0.8887 - val_loss: 0.7620 - val_mse: 0.7620
# Epoch 81/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8872 - mse: 0.8872 - val_loss: 0.7636 - val_mse: 0.7636
# Epoch 82/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8885 - mse: 0.8885 - val_loss: 0.7659 - val_mse: 0.7659
# Epoch 83/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8861 - mse: 0.8861 - val_loss: 0.7665 - val_mse: 0.7665
# Epoch 84/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8890 - mse: 0.8890 - val_loss: 0.7703 - val_mse: 0.7703
# Epoch 85/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8877 - mse: 0.8877 - val_loss: 0.7635 - val_mse: 0.7635
# Epoch 86/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8884 - mse: 0.8884 - val_loss: 0.7530 - val_mse: 0.7530
# Epoch 87/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8911 - mse: 0.8911 - val_loss: 0.7520 - val_mse: 0.7520
# Epoch 88/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8882 - mse: 0.8882 - val_loss: 0.7548 - val_mse: 0.7548
# Epoch 89/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8875 - mse: 0.8875 - val_loss: 0.7627 - val_mse: 0.7627
# Epoch 90/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8935 - mse: 0.8935 - val_loss: 0.7715 - val_mse: 0.7715
# Epoch 91/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8863 - mse: 0.8863 - val_loss: 0.7608 - val_mse: 0.7608
# Epoch 92/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9046 - mse: 0.9046 - val_loss: 0.7616 - val_mse: 0.7616
# Epoch 93/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8935 - mse: 0.8935 - val_loss: 0.7629 - val_mse: 0.7629
# Epoch 94/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8878 - mse: 0.8878 - val_loss: 0.8003 - val_mse: 0.8003
# Epoch 95/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8990 - mse: 0.8990 - val_loss: 0.8049 - val_mse: 0.8049
# Epoch 96/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8927 - mse: 0.8927 - val_loss: 0.7860 - val_mse: 0.7860
# Epoch 97/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8857 - mse: 0.8857 - val_loss: 0.7750 - val_mse: 0.7750
# Epoch 98/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8983 - mse: 0.8983 - val_loss: 0.7707 - val_mse: 0.7707
# Epoch 99/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8949 - mse: 0.8949 - val_loss: 0.7650 - val_mse: 0.7650
# Epoch 100/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8846 - mse: 0.8846 - val_loss: 0.7755 - val_mse: 0.7755
# Epoch 101/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8883 - mse: 0.8883 - val_loss: 0.7791 - val_mse: 0.7791
# Epoch 102/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8895 - mse: 0.8895 - val_loss: 0.7693 - val_mse: 0.7693
# Epoch 103/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8853 - mse: 0.8853 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 104/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8884 - mse: 0.8884 - val_loss: 0.7654 - val_mse: 0.7654
# Epoch 105/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8842 - mse: 0.8842 - val_loss: 0.7621 - val_mse: 0.7621
# Epoch 106/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8872 - mse: 0.8872 - val_loss: 0.7607 - val_mse: 0.7607
# Epoch 107/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8863 - mse: 0.8863 - val_loss: 0.7648 - val_mse: 0.7648
# Epoch 108/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8847 - mse: 0.8847 - val_loss: 0.7713 - val_mse: 0.7713
# Epoch 109/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8869 - mse: 0.8869 - val_loss: 0.7764 - val_mse: 0.7764
# Epoch 110/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8856 - mse: 0.8856 - val_loss: 0.7728 - val_mse: 0.7728
# Epoch 111/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8812 - mse: 0.8812 - val_loss: 0.7670 - val_mse: 0.7670
# Epoch 112/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8987 - mse: 0.8987 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 113/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9008 - mse: 0.9008 - val_loss: 0.7650 - val_mse: 0.7650
# Epoch 114/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8850 - mse: 0.8850 - val_loss: 0.7617 - val_mse: 0.7617
# Epoch 115/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8882 - mse: 0.8882 - val_loss: 0.7542 - val_mse: 0.7542
# Epoch 116/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8875 - mse: 0.8875 - val_loss: 0.7589 - val_mse: 0.7589
# Epoch 117/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8842 - mse: 0.8842 - val_loss: 0.7556 - val_mse: 0.7556
# Epoch 118/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8833 - mse: 0.8833 - val_loss: 0.7559 - val_mse: 0.7559
# Epoch 119/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8837 - mse: 0.8837 - val_loss: 0.7559 - val_mse: 0.7559
# Epoch 120/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8869 - mse: 0.8869 - val_loss: 0.7525 - val_mse: 0.7525
# Epoch 121/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8851 - mse: 0.8851 - val_loss: 0.7607 - val_mse: 0.7607
# Epoch 122/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8965 - mse: 0.8965 - val_loss: 0.7747 - val_mse: 0.7747
# Epoch 123/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8831 - mse: 0.8831 - val_loss: 0.7614 - val_mse: 0.7614
# Epoch 124/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8866 - mse: 0.8866 - val_loss: 0.7620 - val_mse: 0.7620
# Epoch 125/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8826 - mse: 0.8826 - val_loss: 0.7696 - val_mse: 0.7696
# Epoch 126/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8814 - mse: 0.8814 - val_loss: 0.7790 - val_mse: 0.7790
# Epoch 127/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8866 - mse: 0.8866 - val_loss: 0.7792 - val_mse: 0.7792
# Epoch 128/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8812 - mse: 0.8812 - val_loss: 0.7684 - val_mse: 0.7684
# Epoch 129/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8881 - mse: 0.8881 - val_loss: 0.7639 - val_mse: 0.7639
# Epoch 130/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8971 - mse: 0.8971 - val_loss: 0.7584 - val_mse: 0.7584
# Epoch 131/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8865 - mse: 0.8865 - val_loss: 0.7680 - val_mse: 0.7680
# Epoch 132/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8834 - mse: 0.8834 - val_loss: 0.7778 - val_mse: 0.7778
# Epoch 133/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8882 - mse: 0.8882 - val_loss: 0.7703 - val_mse: 0.7703
# Epoch 134/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8830 - mse: 0.8830 - val_loss: 0.7708 - val_mse: 0.7708
# Epoch 135/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8817 - mse: 0.8817 - val_loss: 0.7746 - val_mse: 0.7746
# Epoch 136/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8844 - mse: 0.8844 - val_loss: 0.7667 - val_mse: 0.7667
# Epoch 137/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8864 - mse: 0.8864 - val_loss: 0.7649 - val_mse: 0.7649
# Epoch 138/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8825 - mse: 0.8825 - val_loss: 0.7784 - val_mse: 0.7784
# Epoch 139/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8858 - mse: 0.8858 - val_loss: 0.7904 - val_mse: 0.7904
# Epoch 140/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8847 - mse: 0.8847 - val_loss: 0.7731 - val_mse: 0.7731
# Epoch 141/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8884 - mse: 0.8884 - val_loss: 0.7617 - val_mse: 0.7617
# Epoch 142/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8884 - mse: 0.8884 - val_loss: 0.7705 - val_mse: 0.7705
# Epoch 143/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8797 - mse: 0.8797 - val_loss: 0.7670 - val_mse: 0.7670
# Epoch 144/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8818 - mse: 0.8818 - val_loss: 0.7614 - val_mse: 0.7614
# Epoch 145/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8820 - mse: 0.8820 - val_loss: 0.7656 - val_mse: 0.7656
# Epoch 146/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8843 - mse: 0.8843 - val_loss: 0.7765 - val_mse: 0.7765
# Epoch 147/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8793 - mse: 0.8793 - val_loss: 0.7666 - val_mse: 0.7666
# Epoch 148/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8828 - mse: 0.8828 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 149/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8868 - mse: 0.8868 - val_loss: 0.7601 - val_mse: 0.7601
# Epoch 150/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8867 - mse: 0.8867 - val_loss: 0.7603 - val_mse: 0.7603
# Epoch 151/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8808 - mse: 0.8808 - val_loss: 0.7578 - val_mse: 0.7578
# Epoch 152/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8922 - mse: 0.8922 - val_loss: 0.7456 - val_mse: 0.7456
# Epoch 153/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8818 - mse: 0.8818 - val_loss: 0.7489 - val_mse: 0.7489
# Epoch 154/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8842 - mse: 0.8842 - val_loss: 0.7694 - val_mse: 0.7694
# Epoch 155/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8849 - mse: 0.8849 - val_loss: 0.7598 - val_mse: 0.7598
# Epoch 156/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8778 - mse: 0.8778 - val_loss: 0.7506 - val_mse: 0.7506
# Epoch 157/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8803 - mse: 0.8803 - val_loss: 0.7532 - val_mse: 0.7532
# Epoch 158/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8794 - mse: 0.8794 - val_loss: 0.7597 - val_mse: 0.7597
# Epoch 159/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8824 - mse: 0.8824 - val_loss: 0.7760 - val_mse: 0.7760
# Epoch 160/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8799 - mse: 0.8799 - val_loss: 0.7658 - val_mse: 0.7658
# Epoch 161/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8762 - mse: 0.8762 - val_loss: 0.7528 - val_mse: 0.7528
# Epoch 162/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8924 - mse: 0.8924 - val_loss: 0.7463 - val_mse: 0.7463
# Epoch 163/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8884 - mse: 0.8884 - val_loss: 0.7500 - val_mse: 0.7500
# Epoch 164/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8872 - mse: 0.8872 - val_loss: 0.7589 - val_mse: 0.7589
# Epoch 165/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8792 - mse: 0.8792 - val_loss: 0.7424 - val_mse: 0.7424
# Epoch 166/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8797 - mse: 0.8797 - val_loss: 0.7400 - val_mse: 0.7400
# Epoch 167/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8823 - mse: 0.8823 - val_loss: 0.7442 - val_mse: 0.7442
# Epoch 168/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8781 - mse: 0.8781 - val_loss: 0.7517 - val_mse: 0.7517
# Epoch 169/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8770 - mse: 0.8770 - val_loss: 0.7598 - val_mse: 0.7598
# Epoch 170/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8842 - mse: 0.8842 - val_loss: 0.7721 - val_mse: 0.7721
# Epoch 171/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8809 - mse: 0.8809 - val_loss: 0.7679 - val_mse: 0.7679
# Epoch 172/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8788 - mse: 0.8788 - val_loss: 0.7655 - val_mse: 0.7655
# Epoch 173/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8843 - mse: 0.8843 - val_loss: 0.7783 - val_mse: 0.7783
# Epoch 174/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8808 - mse: 0.8808 - val_loss: 0.7765 - val_mse: 0.7765
# Epoch 175/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8844 - mse: 0.8844 - val_loss: 0.7925 - val_mse: 0.7925
# Epoch 176/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8801 - mse: 0.8801 - val_loss: 0.7875 - val_mse: 0.7875
# Epoch 177/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8760 - mse: 0.8760 - val_loss: 0.7796 - val_mse: 0.7796
# Epoch 178/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8811 - mse: 0.8811 - val_loss: 0.7721 - val_mse: 0.7721
# Epoch 179/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8806 - mse: 0.8806 - val_loss: 0.7678 - val_mse: 0.7678
# Epoch 180/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8773 - mse: 0.8773 - val_loss: 0.7668 - val_mse: 0.7668
# Epoch 181/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8807 - mse: 0.8807 - val_loss: 0.7607 - val_mse: 0.7607
# Epoch 182/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8793 - mse: 0.8793 - val_loss: 0.7638 - val_mse: 0.7638
# Epoch 183/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8802 - mse: 0.8802 - val_loss: 0.7526 - val_mse: 0.7526
# Epoch 184/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8772 - mse: 0.8772 - val_loss: 0.7567 - val_mse: 0.7567
# Epoch 185/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8749 - mse: 0.8749 - val_loss: 0.7607 - val_mse: 0.7607
# Epoch 186/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8776 - mse: 0.8776 - val_loss: 0.7627 - val_mse: 0.7627
# Epoch 187/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8753 - mse: 0.8753 - val_loss: 0.7526 - val_mse: 0.7526
# Epoch 188/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8759 - mse: 0.8759 - val_loss: 0.7508 - val_mse: 0.7508
# Epoch 189/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8767 - mse: 0.8767 - val_loss: 0.7590 - val_mse: 0.7590
# Epoch 190/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8750 - mse: 0.8750 - val_loss: 0.7627 - val_mse: 0.7627
# Epoch 191/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8776 - mse: 0.8776 - val_loss: 0.7656 - val_mse: 0.7656
# Epoch 192/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8737 - mse: 0.8737 - val_loss: 0.7585 - val_mse: 0.7585
# Epoch 193/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8760 - mse: 0.8760 - val_loss: 0.7547 - val_mse: 0.7547
# Epoch 194/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8773 - mse: 0.8773 - val_loss: 0.7569 - val_mse: 0.7569
# Epoch 195/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8791 - mse: 0.8791 - val_loss: 0.7628 - val_mse: 0.7628
# Epoch 196/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8756 - mse: 0.8756 - val_loss: 0.7571 - val_mse: 0.7571
# Epoch 197/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8761 - mse: 0.8761 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 198/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8750 - mse: 0.8750 - val_loss: 0.7598 - val_mse: 0.7598
# Epoch 199/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8789 - mse: 0.8789 - val_loss: 0.7535 - val_mse: 0.7535
# Epoch 200/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8764 - mse: 0.8764 - val_loss: 0.7573 - val_mse: 0.7573
# Epoch 201/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8761 - mse: 0.8761 - val_loss: 0.7562 - val_mse: 0.7562
# Epoch 202/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8751 - mse: 0.8751 - val_loss: 0.7484 - val_mse: 0.7484
# Epoch 203/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8751 - mse: 0.8751 - val_loss: 0.7495 - val_mse: 0.7495
# Epoch 204/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8718 - mse: 0.8718 - val_loss: 0.7587 - val_mse: 0.7587
# Epoch 205/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8754 - mse: 0.8754 - val_loss: 0.7660 - val_mse: 0.7660
# Epoch 206/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8751 - mse: 0.8751 - val_loss: 0.7542 - val_mse: 0.7542
# Epoch 207/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8759 - mse: 0.8759 - val_loss: 0.7488 - val_mse: 0.7488
# Epoch 208/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8760 - mse: 0.8760 - val_loss: 0.7498 - val_mse: 0.7498
# Epoch 209/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8730 - mse: 0.8730 - val_loss: 0.7444 - val_mse: 0.7444
# Epoch 210/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8797 - mse: 0.8797 - val_loss: 0.7382 - val_mse: 0.7382
# Epoch 211/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8812 - mse: 0.8812 - val_loss: 0.7404 - val_mse: 0.7404
# Epoch 212/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8751 - mse: 0.8751 - val_loss: 0.7409 - val_mse: 0.7409
# Epoch 213/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8760 - mse: 0.8760 - val_loss: 0.7543 - val_mse: 0.7543
# Epoch 214/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8745 - mse: 0.8745 - val_loss: 0.7507 - val_mse: 0.7507
# Epoch 215/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8720 - mse: 0.8720 - val_loss: 0.7454 - val_mse: 0.7454
# Epoch 216/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8785 - mse: 0.8785 - val_loss: 0.7473 - val_mse: 0.7473
# Epoch 217/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8766 - mse: 0.8766 - val_loss: 0.7467 - val_mse: 0.7467
# Epoch 218/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8792 - mse: 0.8792 - val_loss: 0.7538 - val_mse: 0.7538
# Epoch 219/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8800 - mse: 0.8800 - val_loss: 0.7667 - val_mse: 0.7667
# Epoch 220/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8738 - mse: 0.8738 - val_loss: 0.7614 - val_mse: 0.7614
# Epoch 221/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8901 - mse: 0.8901 - val_loss: 0.7538 - val_mse: 0.7538
# Epoch 222/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8819 - mse: 0.8819 - val_loss: 0.7514 - val_mse: 0.7514
# Epoch 223/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8795 - mse: 0.8795 - val_loss: 0.7661 - val_mse: 0.7661
# Epoch 224/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8768 - mse: 0.8768 - val_loss: 0.7595 - val_mse: 0.7595
# Epoch 225/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8746 - mse: 0.8746 - val_loss: 0.7469 - val_mse: 0.7469
# Epoch 226/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8730 - mse: 0.8730 - val_loss: 0.7519 - val_mse: 0.7519
# Epoch 227/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8727 - mse: 0.8727 - val_loss: 0.7716 - val_mse: 0.7716
# Epoch 228/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8730 - mse: 0.8730 - val_loss: 0.7789 - val_mse: 0.7789
# Epoch 229/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8727 - mse: 0.8727 - val_loss: 0.7784 - val_mse: 0.7784
# Epoch 230/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8743 - mse: 0.8743 - val_loss: 0.7689 - val_mse: 0.7689
# Epoch 231/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8753 - mse: 0.8753 - val_loss: 0.7656 - val_mse: 0.7656
# Epoch 232/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8696 - mse: 0.8696 - val_loss: 0.7849 - val_mse: 0.7849
# Epoch 233/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8761 - mse: 0.8761 - val_loss: 0.8028 - val_mse: 0.8028
# Epoch 234/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8778 - mse: 0.8778 - val_loss: 0.7842 - val_mse: 0.7842
# Epoch 235/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8680 - mse: 0.8680 - val_loss: 0.7730 - val_mse: 0.7730
# Epoch 236/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8770 - mse: 0.8770 - val_loss: 0.7755 - val_mse: 0.7755
# Epoch 237/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8711 - mse: 0.8711 - val_loss: 0.7770 - val_mse: 0.7770
# Epoch 238/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8713 - mse: 0.8713 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 239/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8708 - mse: 0.8708 - val_loss: 0.7840 - val_mse: 0.7840
# Epoch 240/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8749 - mse: 0.8749 - val_loss: 0.7820 - val_mse: 0.7820
# Epoch 241/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8687 - mse: 0.8687 - val_loss: 0.7701 - val_mse: 0.7701
# Epoch 242/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8715 - mse: 0.8715 - val_loss: 0.7651 - val_mse: 0.7651
# Epoch 243/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8808 - mse: 0.8808 - val_loss: 0.7714 - val_mse: 0.7714
# Epoch 244/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8711 - mse: 0.8711 - val_loss: 0.7616 - val_mse: 0.7616
# Epoch 245/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8697 - mse: 0.8697 - val_loss: 0.7600 - val_mse: 0.7600
# Epoch 246/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8703 - mse: 0.8703 - val_loss: 0.7594 - val_mse: 0.7594
# Epoch 247/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8705 - mse: 0.8705 - val_loss: 0.7670 - val_mse: 0.7670
# Epoch 248/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8739 - mse: 0.8739 - val_loss: 0.7540 - val_mse: 0.7540
# Epoch 249/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8696 - mse: 0.8696 - val_loss: 0.7587 - val_mse: 0.7587
# Epoch 250/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8703 - mse: 0.8703 - val_loss: 0.7558 - val_mse: 0.7558
# Epoch 251/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8702 - mse: 0.8702 - val_loss: 0.7588 - val_mse: 0.7588
# Epoch 252/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8699 - mse: 0.8699 - val_loss: 0.7615 - val_mse: 0.7615
# Epoch 253/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8700 - mse: 0.8700 - val_loss: 0.7591 - val_mse: 0.7591
# Epoch 254/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8704 - mse: 0.8704 - val_loss: 0.7596 - val_mse: 0.7596
# Epoch 255/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8704 - mse: 0.8704 - val_loss: 0.7716 - val_mse: 0.7716
# Epoch 256/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8701 - mse: 0.8701 - val_loss: 0.7780 - val_mse: 0.7780
# Epoch 257/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8693 - mse: 0.8693 - val_loss: 0.7726 - val_mse: 0.7726
# Epoch 258/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8674 - mse: 0.8674 - val_loss: 0.7646 - val_mse: 0.7646
# Epoch 259/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8751 - mse: 0.8751 - val_loss: 0.7634 - val_mse: 0.7634
# Epoch 260/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8698 - mse: 0.8698 - val_loss: 0.7668 - val_mse: 0.7668
# Epoch 261/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8637 - mse: 0.8637 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 262/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8741 - mse: 0.8741 - val_loss: 0.7849 - val_mse: 0.7849
# Epoch 263/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8751 - mse: 0.8751 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 264/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8709 - mse: 0.8709 - val_loss: 0.7600 - val_mse: 0.7600
# Epoch 265/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8677 - mse: 0.8677 - val_loss: 0.7659 - val_mse: 0.7659
# Epoch 266/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8691 - mse: 0.8691 - val_loss: 0.7614 - val_mse: 0.7614
# Epoch 267/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8665 - mse: 0.8665 - val_loss: 0.7518 - val_mse: 0.7518
# Epoch 268/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8689 - mse: 0.8689 - val_loss: 0.7503 - val_mse: 0.7503
# Epoch 269/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8662 - mse: 0.8662 - val_loss: 0.7557 - val_mse: 0.7557
# Epoch 270/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8749 - mse: 0.8749 - val_loss: 0.7529 - val_mse: 0.7529
# Epoch 271/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8682 - mse: 0.8682 - val_loss: 0.7621 - val_mse: 0.7621
# Epoch 272/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8676 - mse: 0.8676 - val_loss: 0.7679 - val_mse: 0.7679
# Epoch 273/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8692 - mse: 0.8692 - val_loss: 0.7698 - val_mse: 0.7698
# Epoch 274/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8689 - mse: 0.8689 - val_loss: 0.7659 - val_mse: 0.7659
# Epoch 275/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8619 - mse: 0.8619 - val_loss: 0.7591 - val_mse: 0.7591
# Epoch 276/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8730 - mse: 0.8730 - val_loss: 0.7584 - val_mse: 0.7584
# Epoch 277/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8737 - mse: 0.8737 - val_loss: 0.7541 - val_mse: 0.7541
# Epoch 278/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8708 - mse: 0.8708 - val_loss: 0.7536 - val_mse: 0.7536
# Epoch 279/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8709 - mse: 0.8709 - val_loss: 0.7424 - val_mse: 0.7424
# Epoch 280/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8678 - mse: 0.8678 - val_loss: 0.7546 - val_mse: 0.7546
# Epoch 281/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8713 - mse: 0.8713 - val_loss: 0.7568 - val_mse: 0.7568
# Epoch 282/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8620 - mse: 0.8620 - val_loss: 0.7461 - val_mse: 0.7461
# Epoch 283/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8739 - mse: 0.8739 - val_loss: 0.7463 - val_mse: 0.7463
# Epoch 284/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8777 - mse: 0.8777 - val_loss: 0.7436 - val_mse: 0.7436
# Epoch 285/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8653 - mse: 0.8653 - val_loss: 0.7616 - val_mse: 0.7616
# Epoch 286/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8727 - mse: 0.8727 - val_loss: 0.7664 - val_mse: 0.7664
# Epoch 287/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8708 - mse: 0.8708 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 288/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8663 - mse: 0.8663 - val_loss: 0.7518 - val_mse: 0.7518
# Epoch 289/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8689 - mse: 0.8689 - val_loss: 0.7483 - val_mse: 0.7483
# Epoch 290/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8671 - mse: 0.8671 - val_loss: 0.7522 - val_mse: 0.7522
# Epoch 291/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8691 - mse: 0.8691 - val_loss: 0.7578 - val_mse: 0.7578
# Epoch 292/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8700 - mse: 0.8700 - val_loss: 0.7502 - val_mse: 0.7502
# Epoch 293/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8643 - mse: 0.8643 - val_loss: 0.7602 - val_mse: 0.7602
# Epoch 294/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8670 - mse: 0.8670 - val_loss: 0.7578 - val_mse: 0.7578
# Epoch 295/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8637 - mse: 0.8637 - val_loss: 0.7479 - val_mse: 0.7479
# Epoch 296/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8666 - mse: 0.8666 - val_loss: 0.7485 - val_mse: 0.7485
# Epoch 297/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8631 - mse: 0.8631 - val_loss: 0.7594 - val_mse: 0.7594
# Epoch 298/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8723 - mse: 0.8723 - val_loss: 0.7691 - val_mse: 0.7691
# Epoch 299/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8653 - mse: 0.8653 - val_loss: 0.7638 - val_mse: 0.7638
# Epoch 300/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8627 - mse: 0.8627 - val_loss: 0.7607 - val_mse: 0.7607
# Epoch 301/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8640 - mse: 0.8640 - val_loss: 0.7599 - val_mse: 0.7599
# Epoch 302/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8661 - mse: 0.8661 - val_loss: 0.7575 - val_mse: 0.7575
# Epoch 303/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8661 - mse: 0.8661 - val_loss: 0.7720 - val_mse: 0.7720
# Epoch 304/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8644 - mse: 0.8644 - val_loss: 0.7748 - val_mse: 0.7748
# Epoch 305/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8677 - mse: 0.8677 - val_loss: 0.7651 - val_mse: 0.7651
# Epoch 306/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8664 - mse: 0.8664 - val_loss: 0.7672 - val_mse: 0.7672
# Epoch 307/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8705 - mse: 0.8705 - val_loss: 0.7618 - val_mse: 0.7618
# Epoch 308/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8661 - mse: 0.8661 - val_loss: 0.7620 - val_mse: 0.7620
# Epoch 309/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8624 - mse: 0.8624 - val_loss: 0.7623 - val_mse: 0.7623
# Epoch 310/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8626 - mse: 0.8626 - val_loss: 0.7633 - val_mse: 0.7633
# Epoch 311/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8672 - mse: 0.8672 - val_loss: 0.7744 - val_mse: 0.7744
# Epoch 312/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8651 - mse: 0.8651 - val_loss: 0.7678 - val_mse: 0.7678
# Epoch 313/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8619 - mse: 0.8619 - val_loss: 0.7622 - val_mse: 0.7622
# Epoch 314/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8632 - mse: 0.8632 - val_loss: 0.7596 - val_mse: 0.7596
# Epoch 315/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8710 - mse: 0.8710 - val_loss: 0.7560 - val_mse: 0.7560
# Epoch 316/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8636 - mse: 0.8636 - val_loss: 0.7678 - val_mse: 0.7678
# Epoch 317/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8663 - mse: 0.8663 - val_loss: 0.7751 - val_mse: 0.7751
# Epoch 318/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8681 - mse: 0.8681 - val_loss: 0.7802 - val_mse: 0.7802
# Epoch 319/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8699 - mse: 0.8699 - val_loss: 0.7643 - val_mse: 0.7643
# Epoch 320/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8641 - mse: 0.8641 - val_loss: 0.7658 - val_mse: 0.7658
# Epoch 321/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8576 - mse: 0.8576 - val_loss: 0.7564 - val_mse: 0.7564
# Epoch 322/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8649 - mse: 0.8649 - val_loss: 0.7574 - val_mse: 0.7574
# Epoch 323/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8649 - mse: 0.8649 - val_loss: 0.7544 - val_mse: 0.7544
# Epoch 324/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8632 - mse: 0.8632 - val_loss: 0.7582 - val_mse: 0.7582
# Epoch 325/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8600 - mse: 0.8600 - val_loss: 0.7567 - val_mse: 0.7567
# Epoch 326/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8624 - mse: 0.8624 - val_loss: 0.7578 - val_mse: 0.7578
# Epoch 327/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8635 - mse: 0.8635 - val_loss: 0.7625 - val_mse: 0.7625
# Epoch 328/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8625 - mse: 0.8625 - val_loss: 0.7573 - val_mse: 0.7573
# Epoch 329/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8604 - mse: 0.8604 - val_loss: 0.7621 - val_mse: 0.7621
# Epoch 330/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8606 - mse: 0.8606 - val_loss: 0.7712 - val_mse: 0.7712
# Epoch 331/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8661 - mse: 0.8661 - val_loss: 0.7682 - val_mse: 0.7682
# Epoch 332/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8547 - mse: 0.8547 - val_loss: 0.7565 - val_mse: 0.7565
# Epoch 333/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8679 - mse: 0.8679 - val_loss: 0.7533 - val_mse: 0.7533
# Epoch 334/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8660 - mse: 0.8660 - val_loss: 0.7503 - val_mse: 0.7503
# Epoch 335/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8580 - mse: 0.8580 - val_loss: 0.7561 - val_mse: 0.7561
# Epoch 336/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8613 - mse: 0.8613 - val_loss: 0.7552 - val_mse: 0.7552
# Epoch 337/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8603 - mse: 0.8603 - val_loss: 0.7430 - val_mse: 0.7430
# Epoch 338/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8609 - mse: 0.8609 - val_loss: 0.7501 - val_mse: 0.7501
# Epoch 339/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8641 - mse: 0.8641 - val_loss: 0.7594 - val_mse: 0.7594
# Epoch 340/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8647 - mse: 0.8647 - val_loss: 0.7546 - val_mse: 0.7546
# Epoch 341/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8624 - mse: 0.8624 - val_loss: 0.7645 - val_mse: 0.7645
# Epoch 342/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8581 - mse: 0.8581 - val_loss: 0.7626 - val_mse: 0.7626
# Epoch 343/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8582 - mse: 0.8582 - val_loss: 0.7594 - val_mse: 0.7594
# Epoch 344/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8600 - mse: 0.8600 - val_loss: 0.7540 - val_mse: 0.7540
# Epoch 345/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8586 - mse: 0.8586 - val_loss: 0.7525 - val_mse: 0.7525
# Epoch 346/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8577 - mse: 0.8577 - val_loss: 0.7580 - val_mse: 0.7580
# Epoch 347/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8600 - mse: 0.8600 - val_loss: 0.7573 - val_mse: 0.7573
# Epoch 348/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8579 - mse: 0.8579 - val_loss: 0.7587 - val_mse: 0.7587
# Epoch 349/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8629 - mse: 0.8629 - val_loss: 0.7612 - val_mse: 0.7612
# Epoch 350/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8572 - mse: 0.8572 - val_loss: 0.7540 - val_mse: 0.7540
# Epoch 351/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8590 - mse: 0.8590 - val_loss: 0.7478 - val_mse: 0.7478
# Epoch 352/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8692 - mse: 0.8692 - val_loss: 0.7441 - val_mse: 0.7441
# Epoch 353/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8714 - mse: 0.8714 - val_loss: 0.7379 - val_mse: 0.7379
# Epoch 354/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8666 - mse: 0.8666 - val_loss: 0.7507 - val_mse: 0.7507
# Epoch 355/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8639 - mse: 0.8639 - val_loss: 0.7534 - val_mse: 0.7534
# Epoch 356/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8596 - mse: 0.8596 - val_loss: 0.7419 - val_mse: 0.7419
# Epoch 357/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8577 - mse: 0.8577 - val_loss: 0.7431 - val_mse: 0.7431
# Epoch 358/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8614 - mse: 0.8614 - val_loss: 0.7583 - val_mse: 0.7583
# Epoch 359/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8584 - mse: 0.8584 - val_loss: 0.7582 - val_mse: 0.7582
# Epoch 360/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8542 - mse: 0.8542 - val_loss: 0.7557 - val_mse: 0.7557
# Epoch 361/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8691 - mse: 0.8691 - val_loss: 0.7553 - val_mse: 0.7553
# Epoch 362/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8578 - mse: 0.8578 - val_loss: 0.7608 - val_mse: 0.7608
# Epoch 363/1000
# ...
# Epoch 881/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7991 - mse: 0.7991 - val_loss: 0.7138 - val_mse: 0.7138
# Epoch 882/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7953 - mse: 0.7953 - val_loss: 0.7025 - val_mse: 0.7025
# Epoch 883/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7960 - mse: 0.7960 - val_loss: 0.6987 - val_mse: 0.6987
# Epoch 884/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7981 - mse: 0.7981 - val_loss: 0.6920 - val_mse: 0.6920
# Epoch 885/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7917 - mse: 0.7917 - val_loss: 0.6997 - val_mse: 0.6997
# Epoch 886/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7911 - mse: 0.7911 - val_loss: 0.7067 - val_mse: 0.7067
# Epoch 887/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7926 - mse: 0.7926 - val_loss: 0.7126 - val_mse: 0.7126
# Epoch 888/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7933 - mse: 0.7933 - val_loss: 0.7084 - val_mse: 0.7084
# Epoch 889/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7904 - mse: 0.7904 - val_loss: 0.7046 - val_mse: 0.7046
# Epoch 890/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7920 - mse: 0.7920 - val_loss: 0.7010 - val_mse: 0.7010
# Epoch 891/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7951 - mse: 0.7951 - val_loss: 0.6999 - val_mse: 0.6999
# Epoch 892/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7958 - mse: 0.7958 - val_loss: 0.7013 - val_mse: 0.7013
# Epoch 893/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7910 - mse: 0.7910 - val_loss: 0.7242 - val_mse: 0.7242
# Epoch 894/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7954 - mse: 0.7954 - val_loss: 0.7223 - val_mse: 0.7223
# Epoch 895/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7946 - mse: 0.7946 - val_loss: 0.7173 - val_mse: 0.7173
# Epoch 896/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7917 - mse: 0.7917 - val_loss: 0.7187 - val_mse: 0.7187
# Epoch 897/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7916 - mse: 0.7916 - val_loss: 0.7245 - val_mse: 0.7245
# Epoch 898/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7950 - mse: 0.7950 - val_loss: 0.7233 - val_mse: 0.7233
# Epoch 899/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7936 - mse: 0.7936 - val_loss: 0.7208 - val_mse: 0.7208
# Epoch 900/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7908 - mse: 0.7908 - val_loss: 0.7107 - val_mse: 0.7107
# Epoch 901/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7927 - mse: 0.7927 - val_loss: 0.7037 - val_mse: 0.7037
# Epoch 902/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7924 - mse: 0.7924 - val_loss: 0.7003 - val_mse: 0.7003
# Epoch 903/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7909 - mse: 0.7909 - val_loss: 0.6980 - val_mse: 0.6980
# Epoch 904/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7894 - mse: 0.7894 - val_loss: 0.6936 - val_mse: 0.6936
# Epoch 905/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7916 - mse: 0.7916 - val_loss: 0.6930 - val_mse: 0.6930
# Epoch 906/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7949 - mse: 0.7949 - val_loss: 0.6864 - val_mse: 0.6864
# Epoch 907/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7939 - mse: 0.7939 - val_loss: 0.7016 - val_mse: 0.7016
# Epoch 908/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7910 - mse: 0.7910 - val_loss: 0.7059 - val_mse: 0.7059
# Epoch 909/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7895 - mse: 0.7895 - val_loss: 0.7067 - val_mse: 0.7067
# Epoch 910/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7977 - mse: 0.7977 - val_loss: 0.6946 - val_mse: 0.6946
# Epoch 911/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7892 - mse: 0.7892 - val_loss: 0.7019 - val_mse: 0.7019
# Epoch 912/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7875 - mse: 0.7875 - val_loss: 0.7097 - val_mse: 0.7097
# Epoch 913/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7994 - mse: 0.7994 - val_loss: 0.7182 - val_mse: 0.7182
# Epoch 914/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7881 - mse: 0.7881 - val_loss: 0.6997 - val_mse: 0.6997
# Epoch 915/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7982 - mse: 0.7982 - val_loss: 0.6954 - val_mse: 0.6954
# Epoch 916/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7922 - mse: 0.7922 - val_loss: 0.6989 - val_mse: 0.6989
# Epoch 917/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7977 - mse: 0.7977 - val_loss: 0.7145 - val_mse: 0.7145
# Epoch 918/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7932 - mse: 0.7932 - val_loss: 0.7053 - val_mse: 0.7053
# Epoch 919/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7946 - mse: 0.7946 - val_loss: 0.7137 - val_mse: 0.7137
# Epoch 920/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7888 - mse: 0.7888 - val_loss: 0.7010 - val_mse: 0.7010
# Epoch 921/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7997 - mse: 0.7997 - val_loss: 0.6980 - val_mse: 0.6980
# Epoch 922/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7988 - mse: 0.7988 - val_loss: 0.7072 - val_mse: 0.7072
# Epoch 923/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7876 - mse: 0.7876 - val_loss: 0.7006 - val_mse: 0.7006
# Epoch 924/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7891 - mse: 0.7891 - val_loss: 0.7068 - val_mse: 0.7068
# Epoch 925/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7861 - mse: 0.7861 - val_loss: 0.7127 - val_mse: 0.7127
# Epoch 926/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7878 - mse: 0.7878 - val_loss: 0.7217 - val_mse: 0.7217
# Epoch 927/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7887 - mse: 0.7887 - val_loss: 0.7138 - val_mse: 0.7138
# Epoch 928/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7877 - mse: 0.7877 - val_loss: 0.7111 - val_mse: 0.7111
# Epoch 929/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7911 - mse: 0.7911 - val_loss: 0.6984 - val_mse: 0.6984
# Epoch 930/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7899 - mse: 0.7899 - val_loss: 0.6983 - val_mse: 0.6983
# Epoch 931/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7855 - mse: 0.7855 - val_loss: 0.7106 - val_mse: 0.7106
# Epoch 932/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7874 - mse: 0.7874 - val_loss: 0.7084 - val_mse: 0.7084
# Epoch 933/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7859 - mse: 0.7859 - val_loss: 0.7002 - val_mse: 0.7002
# Epoch 934/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7874 - mse: 0.7874 - val_loss: 0.7001 - val_mse: 0.7001
# Epoch 935/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7851 - mse: 0.7851 - val_loss: 0.7079 - val_mse: 0.7079
# Epoch 936/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7865 - mse: 0.7865 - val_loss: 0.7188 - val_mse: 0.7188
# Epoch 937/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7921 - mse: 0.7921 - val_loss: 0.7269 - val_mse: 0.7269
# Epoch 938/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7871 - mse: 0.7871 - val_loss: 0.7066 - val_mse: 0.7066
# Epoch 939/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7884 - mse: 0.7884 - val_loss: 0.7073 - val_mse: 0.7073
# Epoch 940/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7876 - mse: 0.7876 - val_loss: 0.7124 - val_mse: 0.7124
# Epoch 941/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7881 - mse: 0.7881 - val_loss: 0.7068 - val_mse: 0.7068
# Epoch 942/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7838 - mse: 0.7838 - val_loss: 0.7141 - val_mse: 0.7141
# Epoch 943/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7878 - mse: 0.7878 - val_loss: 0.7026 - val_mse: 0.7026
# Epoch 944/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7848 - mse: 0.7848 - val_loss: 0.6997 - val_mse: 0.6997
# Epoch 945/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7860 - mse: 0.7860 - val_loss: 0.6972 - val_mse: 0.6972
# Epoch 946/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7831 - mse: 0.7831 - val_loss: 0.7085 - val_mse: 0.7085
# Epoch 947/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7851 - mse: 0.7851 - val_loss: 0.7048 - val_mse: 0.7048
# Epoch 948/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7912 - mse: 0.7912 - val_loss: 0.7024 - val_mse: 0.7024
# Epoch 949/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7815 - mse: 0.7815 - val_loss: 0.7172 - val_mse: 0.7172
# Epoch 950/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7868 - mse: 0.7868 - val_loss: 0.7221 - val_mse: 0.7221
# Epoch 951/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7828 - mse: 0.7828 - val_loss: 0.7082 - val_mse: 0.7082
# Epoch 952/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7820 - mse: 0.7820 - val_loss: 0.7066 - val_mse: 0.7066
# Epoch 953/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7948 - mse: 0.7948 - val_loss: 0.7125 - val_mse: 0.7125
# Epoch 954/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7833 - mse: 0.7833 - val_loss: 0.6975 - val_mse: 0.6975
# Epoch 955/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7934 - mse: 0.7934 - val_loss: 0.6916 - val_mse: 0.6916
# Epoch 956/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7882 - mse: 0.7882 - val_loss: 0.6882 - val_mse: 0.6882
# Epoch 957/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7829 - mse: 0.7829 - val_loss: 0.6968 - val_mse: 0.6968
# Epoch 958/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7898 - mse: 0.7898 - val_loss: 0.7067 - val_mse: 0.7067
# Epoch 959/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7841 - mse: 0.7841 - val_loss: 0.6856 - val_mse: 0.6856
# Epoch 960/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7837 - mse: 0.7837 - val_loss: 0.6859 - val_mse: 0.6859
# Epoch 961/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7853 - mse: 0.7853 - val_loss: 0.6902 - val_mse: 0.6902
# Epoch 962/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7806 - mse: 0.7806 - val_loss: 0.6979 - val_mse: 0.6979
# Epoch 963/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7828 - mse: 0.7828 - val_loss: 0.7143 - val_mse: 0.7143
# Epoch 964/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7865 - mse: 0.7865 - val_loss: 0.7149 - val_mse: 0.7149
# Epoch 965/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7822 - mse: 0.7822 - val_loss: 0.6992 - val_mse: 0.6992
# Epoch 966/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7822 - mse: 0.7822 - val_loss: 0.6986 - val_mse: 0.6986
# Epoch 967/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7864 - mse: 0.7864 - val_loss: 0.7050 - val_mse: 0.7050
# Epoch 968/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7822 - mse: 0.7822 - val_loss: 0.7103 - val_mse: 0.7103
# Epoch 969/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7826 - mse: 0.7826 - val_loss: 0.7052 - val_mse: 0.7052
# Epoch 970/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7823 - mse: 0.7823 - val_loss: 0.6943 - val_mse: 0.6943
# Epoch 971/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7830 - mse: 0.7830 - val_loss: 0.7001 - val_mse: 0.7001
# Epoch 972/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7801 - mse: 0.7801 - val_loss: 0.6985 - val_mse: 0.6985
# Epoch 973/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7812 - mse: 0.7812 - val_loss: 0.7111 - val_mse: 0.7111
# Epoch 974/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7821 - mse: 0.7821 - val_loss: 0.7063 - val_mse: 0.7063
# Epoch 975/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7826 - mse: 0.7826 - val_loss: 0.6916 - val_mse: 0.6916
# Epoch 976/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7871 - mse: 0.7871 - val_loss: 0.6952 - val_mse: 0.6952
# Epoch 977/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7796 - mse: 0.7796 - val_loss: 0.6954 - val_mse: 0.6954
# Epoch 978/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7787 - mse: 0.7787 - val_loss: 0.6880 - val_mse: 0.6880
# Epoch 979/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7792 - mse: 0.7792 - val_loss: 0.6930 - val_mse: 0.6930
# Epoch 980/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7811 - mse: 0.7811 - val_loss: 0.6988 - val_mse: 0.6988
# Epoch 981/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7789 - mse: 0.7789 - val_loss: 0.6938 - val_mse: 0.6938
# Epoch 982/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7807 - mse: 0.7807 - val_loss: 0.6949 - val_mse: 0.6949
# Epoch 983/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7804 - mse: 0.7804 - val_loss: 0.6862 - val_mse: 0.6862
# Epoch 984/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7836 - mse: 0.7836 - val_loss: 0.6914 - val_mse: 0.6914
# Epoch 985/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7769 - mse: 0.7769 - val_loss: 0.6995 - val_mse: 0.6995
# Epoch 986/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7787 - mse: 0.7787 - val_loss: 0.7084 - val_mse: 0.7084
# Epoch 987/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7802 - mse: 0.7802 - val_loss: 0.6988 - val_mse: 0.6988
# Epoch 988/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7812 - mse: 0.7812 - val_loss: 0.6931 - val_mse: 0.6931
# Epoch 989/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7810 - mse: 0.7810 - val_loss: 0.6932 - val_mse: 0.6932
# Epoch 990/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7781 - mse: 0.7781 - val_loss: 0.7058 - val_mse: 0.7058
# Epoch 991/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7796 - mse: 0.7796 - val_loss: 0.7089 - val_mse: 0.7089
# Epoch 992/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7790 - mse: 0.7790 - val_loss: 0.7147 - val_mse: 0.7147
# Epoch 993/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7812 - mse: 0.7812 - val_loss: 0.7068 - val_mse: 0.7068
# Epoch 994/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7764 - mse: 0.7764 - val_loss: 0.7068 - val_mse: 0.7068
# Epoch 995/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7795 - mse: 0.7795 - val_loss: 0.7092 - val_mse: 0.7092
# Epoch 996/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7804 - mse: 0.7804 - val_loss: 0.6986 - val_mse: 0.6986
# Epoch 997/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7786 - mse: 0.7786 - val_loss: 0.7023 - val_mse: 0.7023
# Epoch 998/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7753 - mse: 0.7753 - val_loss: 0.7081 - val_mse: 0.7081
# Epoch 999/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7759 - mse: 0.7759 - val_loss: 0.7078 - val_mse: 0.7078
# Epoch 1000/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7764 - mse: 0.7764 - val_loss: 0.7036 - val_mse: 0.7036

# %%
fig, ax = plt.subplots(figsize=(25, 4))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Accuracy')
ax.set_xlabel('Accuracy')
ax.set_ylabel('Epoch')

plt.legend(['Train', 'Test'])
plt.show()

# %%
y_pred = model.predict(X_test, verbose = 0)

print("R Squared Error    :",round(r2_score(y_test, y_pred), 2))
print("Mean Squared Error :",round(mean_squared_error(y_test, y_pred), 2))
print("Mean Absolute Error:",round(mean_absolute_error(y_test, y_pred), 2))
# Out:
# R Squared Error    : 0.92
# Mean Squared Error : 2.2
# Mean Absolute Error: 1.11

# %%
train_predictions = model.predict(X_test, verbose=0).flatten()

train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_test})
train_results['Diff'] = abs(train_results['Actuals'] - train_results['Train Predictions'])
print(train_results.head(5))
print((train_results['Diff'].mean()), '/', (train_results['Diff'].sum()))
print((train_results['Diff'].max()))
# Out:
#     Train Predictions    Actuals      Diff
# 76           7.212936   6.900000  0.312936
# 31          12.462234  11.900000  0.562234
# 57          14.585189  13.200000  1.385189
# 27          19.647978  20.900000  1.252022
# 54          20.057285  20.200001  0.142715
# 1.106065 / 44.242603
# 3.4815826416015625

# %%
features = data.drop(columns=['Sales'])
prediction = model.predict(features, verbose = 0)

fig, ax = plt.subplots(figsize=(25,5))
ax.plot(data['Sales'])
ax.plot(prediction)
plt.legend(['Real', 'Prediction'])
plt.show()

# %%
data_x = data.drop(columns=['price'])

scaler = RobustScaler()
data_x = scaler.fit_transform(data_x)
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
data_x = scaler.fit_transform(data_x)

predictions = (model.predict(data_x, verbose=0)).astype(int).flatten()

data['Overall Prediction'] = pd.DataFrame(predictions)
data

# %% [markdown]
# # 6. Supervised Learning

# %% [markdown]
# ### 6.1. Stacking Algoritms

# %%
import optuna

def objective(trial, data = data):
    
    X = data.drop(columns=['Purchase'])
    Y = data['Purchase']

    scaler = RobustScaler()
    X = scaler.fit_transform(X)
    scaler = PowerTransformer(method='yeo-johnson', standardize=True)
    X = scaler.fit_transform(X)

    X_train,X_test,y_train,y_test = train_test_split(data, Y, test_size=0.2, random_state=42)
    
    param = {
        'tree_method':'gpu_hist',  # this parameter means using the GPU when training our model to speedup the training process
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 1.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.009,0.01,0.012,0.014,0.016,0.018, 0.02]),
        'n_estimators': trial.suggest_categorical('n_estimators', [1000,2000,3000,4000]),
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17,20]),
        'random_state': trial.suggest_categorical('random_state', [24, 48]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    }
    model = XGBRegressor(**param)  
    
    model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=100, verbose=False)
    preds_valid = model.predict(X_test)
    rmse = mean_squared_error(y_test, preds_valid, squared=False)
    return rmse

    
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

study.best_params
# Out:
# [I 2023-05-04 20:23:00,573] A new study created in memory with name: no-name-f5fe31ab-7f32-4fb2-aab0-8552a2191b51

# %%
best_params = {'lambda': 0.0006657878677616344, 
               'alpha': 0.04329935360636625, 
               'colsample_bytree': 1.0, 
               'subsample': 0.5, 
               'learning_rate': 0.018, 
               'n_estimators': 2000, 
               'max_depth': 11, 
               'random_state': 24, 
               'min_child_weight': 41}

adaboost = AdaBoostRegressor(n_estimators = 100, random_state = 42)
bagging = BaggingRegressor(n_jobs = -1)
extraTrees = ExtraTreesRegressor(max_depth = 100, n_jobs = -1, random_state = 42)
gradient = GradientBoostingRegressor(max_depth = 100, n_estimators = 100, learning_rate = .01,  random_state = 0)
randomForest = RandomForestRegressor(max_depth = 100, random_state = 42, n_jobs = -1)
histGradient = HistGradientBoostingRegressor()
# model = XGBRegressor(**best_params)
XGB = XGBRegressor()
knn = KNeighborsRegressor(n_jobs = -1)
decisionTree = DecisionTreeRegressor( max_depth = 100, random_state = 42)
linear = LinearRegression()

model = StackingRegressor([
    ('extraTrees', extraTrees),
    ('histGradient', histGradient),
    ('adaboost', adaboost),
    ('bagging', bagging),
    ('randomforest', randomForest),
    ('XGB', XGB),
    ('decisionTree', decisionTree),
    # ('linear', linear),
    # ('gradient', gradient),
    # ('knn', knn),
])

# %%
model.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('extraTrees',
#                                ExtraTreesRegressor(max_depth=100, n_jobs=-1,
#                                                    random_state=42)),
#                               ('histGradient', HistGradientBoostingRegressor()),
#                               ('adaboost',
#                                AdaBoostRegressor(n_estimators=100,
#                                                  random_state=42)),
#                               ('bagging', BaggingRegressor(n_jobs=-1)),
#                               ('randomforest',
#                                RandomForestRegressor(max_depth=100, n_jobs=-1,
#                                                      random_state=42)),
#                               ('XGB',
#                                XGB...
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...)),
#                               ('decisionTree',
#                                DecisionTreeRegressor(max_depth=100,
#                                                      random_state=42))])

# %%
print("Train Score        :",round((model.score(X_train, y_train)*100), 2),'%')
print("Test Score         :",round((model.score(X_test, y_test)*100), 2),'%')
print("Validationg Score  :",round((model.score(X_val, y_val)*100), 2),'%')

y_pred = model.predict(X_test)

print("R Squared Error    :",round(r2_score(y_test, y_pred), 2))
print("Mean Squared Error :",round(mean_squared_error(y_test, y_pred), 2))
print("Mean Absolute Error:",round(mean_absolute_error(y_test, y_pred), 2))
# Out:
# Train Score        : 99.92 %
# Test Score         : 93.92 %
# Validationg Score  : 97.38 %
# R Squared Error    : 0.94
# Mean Squared Error : 1.7
# Mean Absolute Error: 0.93

# %%
train_predictions = (model.predict(X_test)).flatten()

train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_test})
train_results['Diff'] = abs(train_results['Actuals'] - train_results['Train Predictions'])
print(train_results.head(5))
print((train_results['Diff'].mean()), '/', (train_results['Diff'].sum()))
print((train_results['Diff'].max()))
# Out:
#     Train Predictions    Actuals      Diff
# 76           7.225330   6.900000  0.325330
# 31          12.660975  11.900000  0.760975
# 57          13.299220  13.200000  0.099220
# 27          20.274117  20.900000  0.625883
# 54          20.057935  20.200001  0.142066
# 0.9293852985591166 / 37.17541194236466
# 4.034010942221634

# %%
features = data.drop(columns=['Sales'])
prediction = model.predict(features)

fig, ax = plt.subplots(figsize=(25,5))
ax.plot(data['Sales'])
ax.plot(prediction)
plt.legend(['Real', 'Prediction'])
plt.show()

# %%
data_x = data.drop(columns=['Name', 'Overall'])

scaler = RobustScaler()
data_x = scaler.fit_transform(data_x)
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
data_x = scaler.fit_transform(data_x)

predictions = np.rint(model.predict(data_x)).astype(int).flatten()

data['Overall Prediction'] = pd.DataFrame(predictions)
data
# Out:
#                      Name  Age  Nationality  Overall  Potential  Club  \
# 0                L. Messi   31            6       94         94   212
# 1       Cristiano Ronaldo   33          123       94         94   326
# 2               Neymar Jr   26           20       92         93   436
# 3                  De Gea   27          139       91         93   375
# 4            K. De Bruyne   27           13       91         92   374
# ...                   ...  ...          ...      ...        ...   ...
# 18202        J. Lundstram   19           46       47         65   165
# 18203  N. Christoffersson   19          144       47         63   588
# 18204           B. Worman   16           46       47         67   122
# 18205      D. Walker-Rice   17           46       47         66   587
# 18206           G. Nugent   16           46       46         66   587
#
#        Preferred Foot  International Reputation  Weak Foot  Skill Moves  ...  \
# 0                   0                       5.0        4.0          4.0  ...
# 1                   1                       5.0        4.0          5.0  ...
# 2                   1                       5.0        5.0          5.0  ...
# 3                   1                       4.0        3.0          1.0  ...
# 4                   1                       4.0        5.0          4.0  ...
# ...               ...                       ...        ...          ...  ...
# 18202               1                       1.0        2.0          2.0  ...
# 18203               1                       1.0        2.0          2.0  ...
# 18204               1                       1.0        3.0          2.0  ...
# 18205               1                       1.0        3.0          2.0  ...
# 18206               1                       1.0        3.0          2.0  ...
#
#        GKReflexes  Defending  General  Mental  Passing  Mobility  Power  \
# 0             8.0         29       89      71       87        91     74
# 1            11.0         27       88      73       81        91     83
# 2            11.0         28       85      72       80        94     69
# 3            94.0         16       26      43       39        66     54
# 4            13.0         59       79      81       92        81     76
# ...           ...        ...      ...     ...      ...       ...    ...
# 18202         9.0         45       39      46       43        55     54
# 18203        12.0         19       41      37       30        40     52
# 18204        13.0         19       43      36       30        59     51
# 18205         9.0         24       44      38       39        48     50
# 18206         9.0         44       45      45       44        54     58
#
#        Shooting  Rating  Overall Prediction
# 0            88      94                  94
# 1            88      94                  94
# 2            84      92                  92
# 3            21      92                  89
# 4            85      92                  91
# ...         ...     ...                 ...
# 18202        37      56                  47
# 18203        39      55                  47
# 18204        42      57                  47
# 18205        45      56                  48
# 18206        34      56                  47
#
# [18207 rows x 83 columns]

# %% [markdown]
# ### 6.2. Pycarets

# %%
s = RegressionExperiment()
s.setup(data, target = 'Item_Outlet_Sales', session_id = 123)
# Out:
# <style type="text/css">
# #T_7ccef_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7ccef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ccef_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7ccef_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ccef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ccef_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7ccef_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ccef_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7ccef_row1_col1" class="data row1 col1" >Item_Outlet_Sales</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ccef_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7ccef_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ccef_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7ccef_row3_col1" class="data row3 col1" >(1705, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ccef_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7ccef_row4_col1" class="data row4 col1" >(1705, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ccef_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7ccef_row5_col1" class="data row5 col1" >(1193, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ccef_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7ccef_row6_col1" class="data row6 col1" >(512, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ccef_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7ccef_row7_col1" class="data row7 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ccef_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_7ccef_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ccef_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_7ccef_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7ccef_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_7ccef_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7ccef_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_7ccef_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7ccef_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_7ccef_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7ccef_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_7ccef_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7ccef_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_7ccef_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7ccef_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_7ccef_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7ccef_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_7ccef_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7ccef_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_7ccef_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7ccef_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7ccef_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_7ccef_row18_col1" class="data row18 col1" >5ec3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
print(best)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              17:30:58
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# HuberRegressor()

# %%
s.evaluate_model(best)

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5ef3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5ef3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f5ef3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f5ef3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f5ef3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f5ef3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f5ef3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f5ef3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5ef3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5ef3_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_f5ef3_row0_col1" class="data row0 col1" >590.1542</td>
#       <td id="T_f5ef3_row0_col2" class="data row0 col2" >797415.2204</td>
#       <td id="T_f5ef3_row0_col3" class="data row0 col3" >892.9811</td>
#       <td id="T_f5ef3_row0_col4" class="data row0 col4" >0.7127</td>
#       <td id="T_f5ef3_row0_col5" class="data row0 col5" >0.4866</td>
#       <td id="T_f5ef3_row0_col6" class="data row0 col6" >0.4199</td>
#     </tr>
#   </tbody>
# </table>
#       Item_Weight  Item_Visibility    Item_MRP  Outlet_Establishment_Year  \
# 1134    12.150000         0.021757  165.018402                       1999
# 249      9.800000         0.141406   50.000801                       2007
# 1143     6.135000         0.079327  152.836594                       1997
# 809     12.911574         0.124300   73.469597                       1985
# 657      6.920000         0.038447   63.585201                       2004
# ...           ...              ...         ...                        ...
# 157     17.200001         0.025162  145.941803                       2004
# 1688     9.800000         0.026895  128.401993                       2002
# 1612    16.000000         0.173463  157.697205                       2009
# 954      9.800000         0.013830   45.306000                       1987
# 375     15.700000         0.115032  114.120201                       2009
#
#       Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 1134                    0                         1                         0
# 249                     0                         0                         1
# 1143                    0                         0                         1
# 809                     0                         1                         0
# 657                     0                         1                         0
# ...                   ...                       ...                       ...
# 157                     0                         0                         1
# 1688                    0                         1                         0
# 1612                    0                         0                         1
# 954                     0                         1                         0
# 375                     0                         0                         1
#
#       Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Baking Goods  \
# 1134                         0                     0                       0
# 249                          0                     0                       1
# 1143                         0                     0                       1
# 809                          0                     0                       0
# 657                          0                     0                       0
# ...                        ...                   ...                     ...
# 157                          0                     0                       0
# 1688                         0                     0                       0
# 1612                         0                     0                       0
# 954                          0                     0                       0
# 375                          0                     0                       0
#
#       ...  Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 1134  ...                            1                            0
# 249   ...                            0                            1
# 1143  ...                            1                            0
# 809   ...                            1                            0
# 657   ...                            0                            1
# ...   ...                          ...                          ...
# 157   ...                            0                            1
# 1688  ...                            0                            1
# 1612  ...                            0                            0
# 954   ...                            0                            0
# 375   ...                            0                            0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 1134                            0                          0
# 249                             0                          0
# 1143                            0                          0
# 809                             0                          1
# 657                             0                          0
# ...                           ...                        ...
# 157                             0                          0
# 1688                            0                          0
# 1612                            1                          0
# 954                             1                          0
# 375                             1                          0
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 1134                              1                              0
# 249                               1                              0
# 1143                              1                              0
# 809                               0                              0
# 657                               1                              0
# ...                             ...                            ...
# 157                               1                              0
# 1688                              1                              0
# 1612                              0                              1
# 954                               1                              0
# 375                               0                              1
#
#       Outlet_Type_Supermarket Type3  Overall Prediction  Item_Outlet_Sales  \
# 1134                              0                2658        3302.367920
# 249                               0                1643         506.007996
# 1143                              0                2648        2871.595459
# 809                               0                 313         298.278412
# 657                               0                 883         751.022400
# ...                             ...                 ...                ...
# 157                               0                2694        1765.701660
# 1688                              0                1637        2403.538086
# 1612                              0                2359        2960.146729
# 954                               0                1388        1304.968018
# 375                               0                 915         787.641418
#
#       prediction_label
# 1134       2684.177348
# 249        1572.491272
# 1143       2468.206772
# 809         381.094023
# 657         950.244089
# ...                ...
# 157        2689.931096
# 1688       1719.376834
# 1612       2184.149560
# 954        1318.843237
# 375         782.319502
#
# [512 rows x 38 columns]
